# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import uuid
from itertools import combinations
### initialize test pool ###

plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.rcParams.update({'font.size': 25})


true_positive_rate = 0.1

global false_negative_rate
global false_positive_rate


false_positive_rate = 0.01
true_positive_rate = 0.01
patient_samples = int(np.sqrt(5000))**2



grand_test_pool = np.zeros((patient_samples))
ids_grand_pool = np.zeros((patient_samples),uuid.UUID)
pool_dictionary = {}


true_positives = 0
positive_patients= []
# positive_patients = random.choices(range(0,patient_samples),k=int(true_positive_rate*patient_samples))
for i in range(0,patient_samples):
    ID = uuid.uuid4()
    ids_grand_pool[i] = ID
    if random.random() <= true_positive_rate:
        true_positives += 1
        grand_test_pool[i] = 1
        pool_dictionary[ID] =1
        positive_patients.append(i)
    else:
        pool_dictionary[ID] =0

plt.figure(figsize=(10,10))
plt.xlabel("sample i")
plt.ylabel("sample j")
plt.imshow(np.reshape(grand_test_pool,[int(np.sqrt(len(grand_test_pool))),int(np.sqrt(len(grand_test_pool)))]),cmap="Greys_r")
true_negatives = patient_samples - true_positives

print("false positive rate:", false_positive_rate)
print("true positive rate",true_positive_rate)
print("nubmer of patient samples",patient_samples)
# Out:
# false positive rate: 0.01
# true positive rate 0.01
# nubmer of patient samples 4900

# %%
pool_dictionary
# Out:
# {UUID('022d9bd6-9827-4841-8d49-53a57ba5f9b9'): 0,
#  UUID('a6c32741-e9a9-4ee5-add1-7d70702ce746'): 0,
#  UUID('ee71194f-2a33-4b06-aa19-5f3b9224a187'): 0,
#  UUID('e85b07dc-910f-4834-9935-208f2fb70de8'): 0,
#  UUID('2f233462-207f-4b94-8bd7-3210793a0fd1'): 0,
#  UUID('fe300be8-2a41-4520-9544-27b4eb4c5574'): 0,
#  UUID('21c4af33-bdd2-4b93-9c92-fea30b00b102'): 0,
#  UUID('6b596812-268d-4775-a107-e84e755a2b48'): 0,
#  UUID('64523bb8-63a4-4702-9e55-07f3c7e985df'): 0,
#  UUID('f619bd26-2bef-490a-a25d-91f0b6fac62b'): 0,
#  UUID('42794648-cecd-43e2-ba67-95b161d981d8'): 0,
#  UUID('4961fa8e-86d9-4228-976f-5e3ca6fde886'): 0,
#  UUID('9b3f43e0-eae4-4185-bf36-50f6e61f0804'): 0,
#  UUID('150a8830-6d37-48b7-998c-1794b2fd34e9'): 0,
#  UUID('8413a4b6-88af-4d4e-a374-5290a44ee570'): 0,
#  UUID('7de2abfc-c3b9-41c5-875c-787f3e25b7dc'): 0,
#  UUID('ed2c29d4-740e-4b33-8482-d4edf7c48dc3'): 0,
#  UUID('ec87f9bd-4667-4718-ac9a-6a15bfe97ff1'): 0,
#  UUID('6d9255e5-2d03-4177-ab6f-e4415159636b'): 0,
#  UUID('8cb3ef12-1656-48b9-bf9a-c5144f0f0a1d'): 0,
#  UUID('789ba096-8e14-4715-913a-86f71b9d8711'): 0,
#  UUID('dcce1619-e411-47c1-839a-29b65da900b1'): 0,
#  UUID('687c7c46-d671-4a2a-a319-385f426feb79'): 0,
#  UUID('adb3459b-291e-4ea0-a2db-b20ee468822c'): 0,
#  UUID('a1076da7-7bd0-427d-8717-31887a966ecb'): 0,
#  UUID('51cd5052-56ce-437c-8d82-2a02f0928619'): 0,
#  UUID('b1771742-6aab-4456-b87b-b7363b0ebec8'): 0,
#  UUID('f5bb365e-059b-4e07-bb97-b542216efaf0'): 0,
#  UUID('75fca0c1-84fb-4755-937c-9adeb42e1576'): 0,
#  UUID('e60d7ae9-83d7-49c4-8b34-da874d3f607c'): 0,
#  UUID('365e712f-1a83-4160-9055-b4ea0ef4acd9'): 0,
#  UUID('b750f7d0-fde7-477b-8361-af7c4fc9560c'): 0,
#  UUID('fb60978d-2733-47d0-a8cd-09b255448460'): 0,
#  UUID('167f2b8e-8068-478a-be40-99d882fbbd08'): 0,
#  UUID('0eed5442-0687-4559-927f-c5d74e6bfcbf'): 0,
#  UUID('c39c5594-b80a-42b6-948a-db8d1f48d484'): 0,
#  UUID('4e1899a0-2380-4d4b-868b-80fda40d6c6d'): 0,
#  UUID('0205ec28-0e3b-4495-805c-d7b818f144ed'): 0,
#  UUID('9692610b-5f95-4210-a3cd-28f792ca6e7f'): 0,
#  UUID('fed6278b-7126-49c5-b531-c163d5fd712e'): 0,
#  UUID('6a798661-67bc-47fe-b010-7c7fdd7917b7'): 0,
#  UUID('ff0caa56-785f-45ec-92b2-6dda0fa5caf4'): 0,
#  UUID('c9bb8af6-6a2a-4e4d-97c0-cc6c3af296cb'): 0,
#  UUID('68e0bdaf-d2d4-486e-ac35-d4f4331f00ab'): 0,
#  UUID('45ffd2a7-eafa-48e3-ba62-b5e65160cc6f'): 0,
#  UUID('1cd10fa8-c089-487d-9de9-01c50a4966d4'): 0,
#  UUID('5c3298bc-d266-4874-900c-f200cde3fcc7'): 0,
#  UUID('4150d1ee-6431-42ae-a2b6-b75ddfd74504'): 0,
#  UUID('f88037d5-d0e1-494b-a4ac-25573cd35d0a'): 0,
#  UUID('89a012cb-e1cb-4892-9809-a112b0c82ccb'): 0,
#  UUID('68a7879c-96c6-4d34-9e9d-b5f96b50258a'): 0,
#  UUID('d772ebc0-a9e9-4e88-93e2-cc26881dfa10'): 0,
#  UUID('16ce318e-5049-4fee-a5e6-0c30bf1f854d'): 0,
#  UUID('585f1d96-2fb2-4db3-88f6-adb3e121d75c'): 0,
#  UUID('15b04f35-2711-4b8b-acb5-23634bb2d5cc'): 0,
#  UUID('22d1e7d5-4f01-4b0e-a0c3-d5c5c0d03ab5'): 0,
#  UUID('8e6aa419-3193-4ff7-90dd-00d59a4cf8d5'): 0,
#  UUID('d03c811f-1988-49e0-8d03-cff395ca650b'): 0,
#  UUID('0db3e218-0c83-4ad2-b9e9-e8c7f2b9f57b'): 0,
#  UUID('e5b3d79a-f19d-43b9-83d7-92498ec6fb9f'): 0,
#  UUID('ec6a31ec-3a71-4d13-9fbc-ee713a2827e6'): 0,
#  UUID('07c6fedb-e380-4400-aa62-c849d20de9fa'): 0,
#  UUID('4db1411e-0161-43c2-93f9-49025a0e0c89'): 0,
#  UUID('f74278a9-fd8c-4e84-948b-0f0e1ab33628'): 0,
#  UUID('6dcdd020-77e7-4b0a-bfeb-5fa4d7a1864d'): 0,
#  UUID('ce8e1a76-6e27-450a-9712-61d444c73e41'): 0,
#  UUID('2f5a6255-8a1b-40dc-820a-078ef359ba31'): 0,
#  UUID('d7eec939-cb8e-4f04-bcba-ca115b797335'): 0,
#  UUID('0b7575bf-ab25-4a70-ab72-a90878d9f107'): 0,
#  UUID('a98a4a80-c8d9-4c62-a7f6-6714117ba7c1'): 0,
#  UUID('d94783f5-3884-4964-acd5-0c8127aac763'): 1,
#  UUID('c3b8951e-4143-45ca-b8ee-3cfcb18f4349'): 0,
#  UUID('e2b4a5a3-1631-4571-b90a-743ff3a7aad6'): 0,
#  UUID('e5d11ef6-2885-4bd5-b343-19907328a611'): 0,
#  UUID('2b6310b6-0603-4a44-876c-d25c5a46ab3d'): 0,
#  UUID('2896199b-44d2-480c-aded-ebf744919c67'): 0,
#  UUID('d0152857-2cde-4e59-86e8-463a1202ac5c'): 0,
#  UUID('3ca2b2d0-c519-40ae-ab32-04fdc6ff1780'): 0,
#  UUID('ad955ab2-ec5f-4d66-87c0-34c20a3f7ae8'): 0,
#  UUID('05883052-7c2e-4710-aee6-3e52d46bb854'): 0,
#  UUID('40759f31-cfb8-438d-8430-fcb3b376110c'): 0,
#  UUID('6510275a-aeb2-400a-a1ec-377d7d3e8789'): 0,
#  UUID('53b43fc2-b2db-4aca-8c77-3a50b787ecc5'): 0,
#  UUID('b54f84ab-6a96-467c-8bab-87bb11de3593'): 0,
#  UUID('d7dff6cd-6c79-45f6-9859-14de09df4917'): 0,
#  UUID('94363781-82ae-4ff4-8267-6f717b015253'): 0,
#  UUID('af702226-6587-4816-bee9-5547c712c41f'): 0,
#  UUID('3b369127-2619-48fa-b3af-d72b255362bb'): 0,
#  UUID('35fbef23-9850-4100-bbae-bea855e7cf64'): 0,
#  UUID('759a6407-d10f-456e-b38e-8f5015f04e06'): 0,
#  UUID('71edc23e-a295-4c35-98b1-360508a2939d'): 0,
#  UUID('fe20f18d-189d-4c53-b211-517760ed8740'): 0,
#  UUID('457e9953-ae6d-4f5c-b6b3-8a8e481cfc1e'): 0,
#  UUID('6431fa26-671a-470a-8dbf-169717bafe8e'): 0,
#  UUID('e9b23ec4-27fa-474b-b10d-0e9c557925ed'): 0,
#  UUID('4b8b781e-0af2-4701-b1a9-2f2c44235ab1'): 0,
#  UUID('c27502d0-a7c9-4543-8e12-1874d4c145be'): 0,
#  UUID('7416a6ea-bc09-48e6-9dba-45086da99024'): 0,
#  UUID('12f0085c-e24e-4b93-bb43-6d2d2636f804'): 0,
#  UUID('b78019e8-5c78-4d65-a5e0-7098c40ce970'): 0,
#  UUID('e85d081b-0998-46c6-8a35-417700f85fd6'): 0,
#  UUID('75d84e4f-172a-41e8-8d60-a2a2c3b3cadc'): 0,
#  UUID('04f6b9df-fb2f-40c6-81d7-99cbc7859f4d'): 0,
#  UUID('b3139fea-d04f-4e20-a301-5f75c693a402'): 0,
#  UUID('ce951ede-9099-4bdc-a916-9886a776821e'): 0,
#  UUID('0bee4b5e-a1bb-424b-b1a0-26a906b170e3'): 0,
#  UUID('dc1692cf-87cd-4d5d-a4d9-d6ce021db5f5'): 0,
#  UUID('cfcffa5a-fa81-4e70-9cf5-57bebd672aed'): 0,
#  UUID('b331bad6-ca98-4a10-820f-bdcd16564f6b'): 0,
#  UUID('cd0a7fcc-ab23-4d5c-8b08-716d09739b24'): 0,
#  UUID('c983dc5b-7576-42e9-84fa-a557cd126513'): 0,
#  UUID('597cb3e9-e383-424f-a7ca-1a71e51be435'): 0,
#  UUID('7cd9587a-1e12-48f9-805a-569af398a397'): 0,
#  UUID('84cb3e7c-b54f-498c-aff3-51d26632706b'): 0,
#  UUID('2942ee19-1a1d-4af5-b36f-2ad5bd3b019c'): 0,
#  UUID('4870aa7d-7ed1-43a6-b196-1dff9794bf44'): 0,
#  UUID('40f0297f-da15-4275-b9ed-025a5954311a'): 0,
#  UUID('06bc04bb-7e92-4840-a785-5f59b2fef657'): 0,
#  UUID('d9cf240a-487a-4f97-97a2-f8c7076a7a52'): 0,
#  UUID('9a90c2bf-94d4-4bae-88e7-ce6580aa215a'): 0,
#  UUID('c68ca692-b8c3-423e-a9ff-05de83675e93'): 0,
#  UUID('1021b94f-2207-4ea9-ad91-a1f99441f119'): 0,
#  UUID('412a2e96-a654-4e1d-9196-181ed68e6ba5'): 0,
#  UUID('ac59a30c-0c1e-4263-9162-eb12c27afec8'): 0,
#  UUID('0a695975-c293-49bd-af82-6fb87887ba8d'): 0,
#  UUID('afde13f4-ce6a-4203-bb5a-1ab484a8bf30'): 0,
#  UUID('96134b5f-f3d2-4732-b5ba-0299a949eacc'): 0,
#  UUID('196ef401-b932-4848-add1-663d9625ee02'): 0,
#  UUID('369f301f-5538-46f4-844b-f7223e3659a6'): 0,
#  UUID('43feb116-44f4-467a-959e-df81a25835db'): 0,
#  UUID('def2b923-2777-4bac-aaf6-825584fb2f91'): 0,
#  UUID('6a5a85ff-8a98-4f74-b146-373edea7358e'): 0,
#  UUID('9fd96e2d-81b2-489b-9cf9-a4f7fba7ccd3'): 0,
#  UUID('6347f255-8848-42af-adcb-292a0cb17b0f'): 0,
#  UUID('a80f403e-0eca-4a87-8ec1-7aa97b986807'): 0,
#  UUID('e6226645-83a3-442a-b6e6-77af22e6fa22'): 0,
#  UUID('9748a0f9-c26c-4e5a-bc03-8c0ebe45b87a'): 0,
#  UUID('77bfd93b-0328-4b81-818a-102cee025348'): 0,
#  UUID('fc6fca77-5aaa-440c-b672-e48a81865326'): 0,
#  UUID('c05a0e2e-c25b-43af-bc28-87f1ed4d59b8'): 0,
#  UUID('88696091-0b0c-4c98-949f-d94fd58c30c6'): 0,
#  UUID('b346391e-0e87-4da6-9627-8edf3ba7764e'): 0,
#  UUID('3acb7162-c49b-4203-9d12-4f44a3bfde78'): 0,
#  UUID('d6c1b61d-a03a-4eae-b76a-c342ea5df4c8'): 0,
#  UUID('e1287708-6d4e-4d43-a9e3-fca819510ea2'): 0,
#  UUID('70c72e83-9c15-4f4d-be0f-a3b9525e2df7'): 0,
#  UUID('d362b55d-394d-4354-8f50-f9228cbb2ec7'): 0,
#  UUID('d00daadc-135f-452b-a4e0-f88be4aee0b7'): 0,
#  UUID('e52b91ef-379b-4e8f-ba73-badb6e44e848'): 0,
#  UUID('c9026594-3bc2-40af-8880-c466d46ec582'): 0,
#  UUID('ac01b7cd-4a7f-4971-91e4-28948d204a8c'): 0,
#  UUID('59c4930b-32cc-4c2f-bf66-c3d40cbb326a'): 0,
#  UUID('8dd8bfef-8d86-4aed-ae39-79b2699f8351'): 0,
#  UUID('a2256832-8c41-457d-914e-71f2b5d3f2cf'): 0,
#  UUID('97863f36-bc8f-433d-8bf7-6af21da0d66a'): 0,
#  UUID('55db58a2-05ea-4d2c-ba84-54ee2444198f'): 0,
#  UUID('7219fc0f-e9a5-422d-ba74-4657d2d6ec0f'): 0,
#  UUID('495e7d08-fd12-4aa5-b839-7a4e5a7020b7'): 0,
#  UUID('f783bad6-bc09-4def-9951-967c26587a58'): 0,
#  UUID('c9bf997c-7135-4b96-a273-8fb4913987df'): 0,
#  UUID('66eb0b34-ca12-47cf-a3f7-9ea422060f5d'): 0,
#  UUID('b7dbb25f-e447-4306-8485-cd1066d7ec2e'): 0,
#  UUID('2b0121e8-39fb-491b-bed4-672f75718ff1'): 0,
#  UUID('637bbb0c-ae77-435f-bdc4-8e88a5b3a947'): 0,
#  UUID('82c1e2d6-a8c0-4d87-bafb-ddcceeecb110'): 0,
#  UUID('55490a42-7d61-448d-85dd-21bb08648176'): 0,
#  UUID('2f14be99-e4e4-4624-80f4-667e651b2989'): 0,
#  UUID('98019266-f387-46b0-ae39-5fe9485de93f'): 0,
#  UUID('382ecb06-fada-4e3f-87e9-2e0245580229'): 0,
#  UUID('2efd2ba6-97f2-43f7-9997-a220c0757494'): 0,
#  UUID('e50084b2-653e-4d47-a97c-257c30bc60af'): 0,
#  UUID('da15c782-f67b-466b-8681-468a84c052bb'): 1,
#  UUID('8d9883f3-2746-49ad-9d5e-90cdf7ca64dd'): 0,
#  UUID('4fff3194-84a3-4ce3-bc5a-3b4e8afd3345'): 0,
#  UUID('4a6e3541-0b73-4578-9b98-0b81d8f96d5a'): 0,
#  UUID('78525ab3-377b-40a5-b2e4-c65db8df3b73'): 0,
#  UUID('17452311-8279-4430-a4bb-a92a992d2a29'): 0,
#  UUID('d579d002-79b8-4b0d-a653-84be9ff14fa3'): 0,
#  UUID('77731d4f-d54f-4a59-a622-715682cc18b4'): 0,
#  UUID('cd84eaa1-c023-40b3-b071-af964d16100b'): 0,
#  UUID('8cf06844-3a9f-461f-ae47-15eb61dd4ca3'): 0,
#  UUID('14960794-e099-430e-b215-54cc0e04e9d7'): 0,
#  UUID('539147ef-75cd-42fa-a1e2-97049696f943'): 0,
#  UUID('5ef787e4-0873-4245-ad1a-8118007b93ae'): 0,
#  UUID('fe0e36ca-b700-4128-98af-930281a6fa8c'): 0,
#  UUID('7cadded1-9b40-4a2e-b61f-3545cee6c812'): 0,
#  UUID('ff267ffe-e2c8-4ff6-b7c3-cc3914a1e1fe'): 0,
#  UUID('3d49284c-9667-4749-8cac-a9762439122d'): 0,
#  UUID('824b8908-2cb7-40a7-9878-5c817ed44609'): 0,
#  UUID('e0ab3599-c79e-47a6-93a8-1ebfd18ee3aa'): 0,
#  UUID('3df5f4ed-e794-43fa-892a-1d2de9a44e50'): 0,
#  UUID('20fbe126-d7e8-4ea0-ab23-cfb31887dd7b'): 0,
#  UUID('31d4fd8a-accd-4a7a-805d-bae0066fe32c'): 0,
#  UUID('c64ddd46-0212-4688-9262-9d9cca217f93'): 0,
#  UUID('6e854169-da30-4a57-82c0-c03e0928c218'): 0,
#  UUID('919c52c6-cc28-4354-8fc0-56b22ebbfc32'): 0,
#  UUID('dda2055d-2744-4d71-a5c2-328af6de4eb6'): 0,
#  UUID('d53ee4bb-bf6f-4a79-a434-19cf3f69e8d4'): 0,
#  UUID('ec345d7b-4178-4f80-91af-afc13cd80890'): 0,
#  UUID('ee10b5b2-0f6c-4c21-9cec-fd605fdc5c17'): 0,
#  UUID('e2766279-f90e-4fe5-bd75-8e60626f128c'): 0,
#  UUID('aacfe26f-9bf7-4ce7-9934-dee860894eb1'): 0,
#  UUID('bc1c61c5-87b5-4878-af85-42e84e84996b'): 0,
#  UUID('3242ce70-e8d6-43ee-a86f-7252c728a1e2'): 0,
#  UUID('ed594e9f-6014-400f-8fba-b3da4e4f2387'): 0,
#  UUID('2ed66dc8-a263-4ea5-9b65-78a810199a30'): 0,
#  UUID('7b3d9fb7-0fdb-48d7-9e9c-240a42f73736'): 0,
#  UUID('9c75658c-4cbc-4f68-b030-d05611625da6'): 0,
#  UUID('d41b795f-94a3-47c0-a591-97e94f98a98a'): 0,
#  UUID('6e95123c-8bf6-46ed-8ec6-8b0909c51220'): 0,
#  UUID('805eb3c9-97d7-4735-aec3-01c99f55e12d'): 0,
#  UUID('f97fb87b-19e4-456f-a82c-ec4fcabb123a'): 0,
#  UUID('cb7342da-9253-4b27-af69-0a70cd4f83f5'): 0,
#  UUID('b2c7d42d-6ec6-4761-8897-212b0fd02bfa'): 0,
#  UUID('d22e6c8a-98d8-4e71-8a97-9929116594f6'): 0,
#  UUID('fba786c3-ebe6-4634-a9ae-a4eec9a5aa2a'): 0,
#  UUID('a80b4fea-42b5-429c-af92-74fbb7f73f35'): 0,
#  UUID('a0938e25-5a9a-4f05-94e9-31033d22c9ef'): 0,
#  UUID('9908ed87-789f-4d6e-bab7-da2dfac7091c'): 0,
#  UUID('4e870752-6a32-4905-be89-16442ee26b5b'): 0,
#  UUID('ccec4bf9-2308-4a8c-a0a0-251769a0207d'): 0,
#  UUID('c2b55623-3a0f-4582-af29-24d6ae1c72be'): 0,
#  UUID('e9aac04a-5ce0-40b6-8605-d764f718a9b7'): 0,
#  UUID('5f6b55e5-0e51-49e7-962d-1c20b53e7e78'): 0,
#  UUID('a224d465-1de3-4d71-816c-0074916a3a36'): 0,
#  UUID('81c21552-ea99-4203-a7e3-a174efb1861e'): 0,
#  UUID('76e8127c-02c9-473f-a214-788c95e44ba3'): 0,
#  UUID('88b43bd7-141a-47cd-a15a-597dfec33062'): 1,
#  UUID('33326276-fdc9-412c-81e6-08b45a434191'): 0,
#  UUID('188d0af3-35ba-42d8-b33d-594159f76bb3'): 0,
#  UUID('db673235-ca58-4a91-9121-ad070e218325'): 0,
#  UUID('14661035-5008-4ce4-98da-85fc19dfd89d'): 0,
#  UUID('1a2a7f10-ca4c-49b5-a7e5-8c5bf2b9846a'): 0,
#  UUID('c98687f9-7866-40ff-8063-971e04f7d9cd'): 0,
#  UUID('6b866701-e6e5-432d-8812-68455d4cce69'): 0,
#  UUID('153f5a4a-7d81-483a-b3d4-2076686a64a6'): 0,
#  UUID('82b895f1-fe0a-4322-ac60-9111483caefc'): 0,
#  UUID('62a76f76-01fa-4e55-af21-70c702bcd318'): 0,
#  UUID('330383eb-c3b6-4a78-bb2b-58b37a969dd8'): 0,
#  UUID('cd7f9f73-4ca5-4ff4-b9ec-af58979bc04b'): 0,
#  UUID('5efe62c3-5fea-4e90-afaa-f20bf30f27d9'): 0,
#  UUID('694c97bf-946e-4056-93cf-6bbc23d3e275'): 0,
#  UUID('7a0789cc-91e5-460d-b4ea-268025ea2130'): 0,
#  UUID('9bcb4cce-8d6b-4109-b7e0-3a684dbf8347'): 0,
#  UUID('38c70d2d-1264-4405-8051-ac2a96602fcb'): 0,
#  UUID('2e8fcec7-d875-4a5c-b0a9-67c6866557bf'): 0,
#  UUID('7abdb166-8c1d-4969-9991-7a86f84bf5ad'): 0,
#  UUID('97642b8d-3344-440f-b42c-04df50964f01'): 0,
#  UUID('4ecb6516-6c78-4781-b0c7-f48a91fa054f'): 0,
#  UUID('06d4a746-810d-4319-8549-67652d75c542'): 0,
#  UUID('2625940d-0166-4943-8f5a-4e7b61c9baed'): 0,
#  UUID('21549d56-5534-474a-b889-0168964d8de3'): 0,
#  UUID('0105704b-3759-411c-a470-71f5207644ed'): 0,
#  UUID('2ec9f33f-89fb-4d33-b414-0e3bd9d5d3d0'): 0,
#  UUID('ff583373-2d5f-4e60-9014-b987f6392d78'): 0,
#  UUID('21698aa7-6d8a-4ed5-a918-18bc74110cd4'): 0,
#  UUID('4129d438-62ef-4dde-b9b0-6394008ef7f9'): 0,
#  UUID('0220101b-511c-4bf9-9314-8efea9b0ae6c'): 0,
#  UUID('1af680e6-33d2-40b3-961b-1e3ba67da41b'): 0,
#  UUID('39bd5b84-b07a-4141-a6c3-e31f7f2dff6b'): 0,
#  UUID('71158eb6-ef5f-4ffb-8e9d-c3409fe6047b'): 0,
#  UUID('b66633e1-55e2-46c6-b417-5ba6b9690a95'): 0,
#  UUID('4ab47448-371d-4ae7-b43d-eefbedaa0f53'): 0,
#  UUID('c98f92ef-4a09-4498-a2e9-472cb167f266'): 0,
#  UUID('b2706f35-332c-4f54-a847-6be44895ae0e'): 0,
#  UUID('e761324e-321d-47dc-8e1e-1b86dfb458db'): 0,
#  UUID('29372751-4334-47e8-afd2-bdb46a3ae20e'): 0,
#  UUID('5ee8247c-4e1f-427c-9f53-8257625a3373'): 0,
#  UUID('1f15ab1a-1001-4ff9-85c8-ef2090b47934'): 0,
#  UUID('83468efd-ecdc-4920-ad25-a6ca87c61614'): 0,
#  UUID('80476da0-7c98-4255-9e4b-f77bcde7d4b2'): 0,
#  UUID('5e0b94ab-cc1f-418f-ab5c-a69c9881c01a'): 0,
#  UUID('3fb0c289-411d-47d4-adea-f14b050c6b3c'): 0,
#  UUID('1c1d0268-4447-4b2f-8a62-ad266353a281'): 0,
#  UUID('c3bc5892-1ed8-47b1-85ed-c419ef93f6a2'): 0,
#  UUID('89539260-eec9-4cea-bc2d-72939e465988'): 0,
#  UUID('fb38dc0a-3161-4940-a6e8-b09eb4ddbbb9'): 0,
#  UUID('84ffe93b-5bd2-4785-87b9-c8a4d16ca88a'): 0,
#  UUID('eba9f8b2-93cc-4a3d-83e8-4907a8773047'): 0,
#  UUID('718e2c8b-9d90-4501-be8a-a3026398e3ca'): 0,
#  UUID('398ffdee-8c6b-42fa-93a3-d37f41687c18'): 0,
#  UUID('3e43d5d9-d5f3-4d88-bebe-13d04f6c7fec'): 0,
#  UUID('d23ad3f3-f0c7-4c5d-8e34-d30b6103886f'): 0,
#  UUID('3bcc1cd0-081c-4908-a90c-da9ca9411091'): 0,
#  UUID('b03d8cf2-09dc-47a0-9ebd-e033dbc5d937'): 0,
#  UUID('da673633-9fd6-4b88-b7ce-6c96d9fc5f56'): 0,
#  UUID('3e242403-2352-483e-bbfb-78f5232b3770'): 0,
#  UUID('b3fe32e2-e599-49aa-93e7-a458738a519d'): 0,
#  UUID('03c9e251-4e15-4f91-ba40-1a60aee401ea'): 0,
#  UUID('ead99c6b-15bd-401f-af89-3548fd661ed8'): 0,
#  UUID('bcea167b-c22a-479d-bfcf-377e18666d52'): 0,
#  UUID('4bb09b0d-4c64-460f-97a6-0991a1b74a83'): 0,
#  UUID('35aa91cc-92dd-44b4-b7c8-5d634402f9a0'): 0,
#  UUID('cbd1b94f-f1e4-4f66-815f-b7610252ff14'): 0,
#  UUID('9b1bbdb3-59cc-463b-825e-3241ec6c20ee'): 0,
#  UUID('a6ed2de3-3f9a-4e79-9c62-e2547dec507e'): 1,
#  UUID('fbbe4022-a794-4b53-9790-4e59c43a7d06'): 0,
#  UUID('f0ff016f-ad89-4655-a51c-3cc756c867f6'): 0,
#  UUID('df04daa7-3a19-477f-9f2f-de5e85c0c130'): 0,
#  UUID('9eb48f36-e9f2-4c38-bd72-fab68e5f8533'): 0,
#  UUID('ca703261-4b98-4080-a0c7-b14b2ca2b4f4'): 0,
#  UUID('bdf6d052-df8e-4426-98b9-6f08a174c8ef'): 0,
#  UUID('63fdba21-f8d9-4ccf-ac2e-f680a537188c'): 0,
#  UUID('7a698e5f-18fb-45e6-b8b0-220afb02c111'): 0,
#  UUID('1dbd0647-8994-45c1-8ca9-dbdbb87769c4'): 0,
#  UUID('507f23be-2d12-4982-90f3-4aebae1969c2'): 0,
#  UUID('14759e3a-b092-4a19-9e4c-391c9424eeb9'): 0,
#  UUID('2156be4e-ba3f-4849-9d61-4ad6147870b4'): 0,
#  UUID('f921b1c4-bb1c-4b77-ad9e-6f211bcfbd34'): 0,
#  UUID('0488603a-6293-48d5-939d-7a6cd88762a2'): 0,
#  UUID('77edb9df-2c10-4dc6-82be-84d092ac1211'): 0,
#  UUID('72ff17cd-ccdd-478f-9f3a-3e4a4b208e2e'): 0,
#  UUID('38172376-8a9a-493a-9bd6-cf739cc38ecf'): 0,
#  UUID('6359f65f-6798-4afc-924c-cbdac7349eb3'): 0,
#  UUID('2b631fbe-ec45-4ea6-b5d2-17f149e35f4a'): 0,
#  UUID('36fc1d85-894e-470f-b271-da825800dde2'): 0,
#  UUID('5421b68a-70fa-4c39-ad4a-01a542031767'): 0,
#  UUID('78d0b998-bf22-48a8-88bc-0f6b01bdd3a5'): 0,
#  UUID('2df2a505-9904-42f5-b0f5-e7bf8f8f05bf'): 0,
#  UUID('2792804a-a5e2-4362-80e7-f69a5374a4fd'): 0,
#  UUID('c3563e24-8aec-4f9d-b3d2-aecea787d712'): 0,
#  UUID('ed4784ed-d4cb-4c78-b6b3-bb27ff941452'): 0,
#  UUID('75d07156-df4d-4fa9-b295-41124b9c38a4'): 0,
#  UUID('28e31a0e-d4b3-4fe3-9222-d6228ad772b9'): 0,
#  UUID('7d0265f6-bcda-4592-8ee3-41db639c5a0d'): 0,
#  UUID('8213b6dc-7da0-4840-897c-496a41da891c'): 0,
#  UUID('f6aa6279-cdbd-4a52-a608-96b9fcafded7'): 0,
#  UUID('9bd05dce-4b9b-4761-bf75-5d82cabddde3'): 0,
#  UUID('2e88db95-6cc7-4b2c-8c97-ec71d51cebe9'): 0,
#  UUID('43ec0c5b-e73c-44e7-865f-d155ac54245f'): 0,
#  UUID('d394c9fe-761f-4a39-a706-80dbabc28e68'): 0,
#  UUID('7b524a83-8875-47af-b404-52f5367d5e75'): 0,
#  UUID('aefd6f82-a508-45b7-95a6-2e58a269cf55'): 0,
#  UUID('ef56aa22-4460-4d0d-a531-2a0bd89a3773'): 0,
#  UUID('2b945f62-51c0-4352-87d0-5d131cbf8206'): 0,
#  UUID('f83ad12d-1c9c-4717-9117-bbaaa864548d'): 0,
#  UUID('85b17235-1f2d-442b-b1b3-9e26af737c0c'): 0,
#  UUID('458e28a4-2208-4266-89dc-f0bc47c90916'): 0,
#  UUID('1427ef3b-5efa-4a1c-8689-fdee050a19a7'): 0,
#  UUID('47133711-4ab7-4814-859e-c47c77514504'): 0,
#  UUID('10face6b-5198-4786-b18a-30d3de7bb968'): 0,
#  UUID('15099034-1608-4890-93c6-c2d41853905c'): 0,
#  UUID('0c0110e7-aaf1-45d8-b46d-51da24351653'): 0,
#  UUID('5502d1d8-ddce-4b65-be56-df74a822b891'): 0,
#  UUID('63a476e0-999a-4d32-8bd5-2b972b884434'): 0,
#  UUID('e9a145ec-fdc1-4868-badf-2e3099a656b2'): 0,
#  UUID('fd7c27cc-3f88-4e3b-9ce7-e41622378fd5'): 0,
#  UUID('1434de9e-0e89-4f5d-a323-03838f4e335d'): 0,
#  UUID('b37f60ec-879d-40fc-804e-f8746f1dce8a'): 0,
#  UUID('de8ef440-1ea1-4ff9-8e48-07bf25615dce'): 0,
#  UUID('800e9254-28a6-4db2-aaaf-ffb16f3f5d4a'): 0,
#  UUID('cf3409ae-2eca-419e-bcd8-c22975b1bb2a'): 0,
#  UUID('61f9bc18-8675-4044-acc2-a2e8e0add69f'): 0,
#  UUID('eeabc258-40d4-40c4-9439-3ace75cb591c'): 0,
#  UUID('9e22637d-62de-41a3-8cc8-307adbe1aae4'): 0,
#  UUID('7e0b775e-3aa5-427b-aee1-01c98c23420e'): 0,
#  UUID('b8a96683-6063-48bf-a56c-b099eb06157c'): 0,
#  UUID('c20d37ab-a13d-471e-9d36-418feb3e1291'): 0,
#  UUID('f5d7a01f-4bfe-4fea-b836-78ce2b337aa1'): 0,
#  UUID('83e699d7-2484-4356-ac6d-c4a2c637d294'): 0,
#  UUID('b728316a-d134-4c1b-a9a3-1ffd156d0cb3'): 0,
#  UUID('9c1dccd9-6df6-4478-b869-7f8787b9dc33'): 0,
#  UUID('f15405a9-071b-4aa7-9972-d76b1f3850f1'): 0,
#  UUID('0f400d85-7fe7-4d81-895f-d637a91170fb'): 0,
#  UUID('9e9bc165-3d02-4488-8934-2a4857af8dfd'): 0,
#  UUID('e961d224-2410-4edd-b009-b5f71b401f7a'): 0,
#  UUID('4d46ca69-a56e-4104-a3d5-38362276ac84'): 0,
#  UUID('94228d76-eae2-4b3d-9d8a-a39865f4ecd0'): 0,
#  UUID('dbbdf546-7512-4c48-a3a5-c19e0268505e'): 0,
#  UUID('f23a1df4-67d3-4e1d-9146-20160477cdc4'): 0,
#  UUID('de938713-0b7a-407a-a54a-badd85ef613f'): 0,
#  UUID('5b7e1f3e-c6e0-43da-9e9a-4632ebbf3ae6'): 0,
#  UUID('81c6a95b-8e26-4d09-a660-308100590e11'): 0,
#  UUID('64380c24-4b2d-4276-bb7b-f32399d11493'): 0,
#  UUID('c95b2915-2196-4618-994c-fa13ef41fdfc'): 0,
#  UUID('315ac95b-fc6e-4a87-a1fd-142fe29d1094'): 0,
#  UUID('7f289efb-a096-4dc5-963a-30bc4716db18'): 0,
#  UUID('b0e0efbd-2c1b-4687-bece-7776fb673acb'): 0,
#  UUID('f8f7557a-4597-495f-9050-ee0f620fe243'): 0,
#  UUID('f44281f0-640a-4bc6-8463-b64facf53915'): 0,
#  UUID('b98398de-7713-48e5-986a-c5acd327e9e5'): 0,
#  UUID('990ef84b-763e-48fa-9d85-0037e04bd0eb'): 0,
#  UUID('b8d917ab-cc8d-40cb-9f79-ab2d299894b7'): 0,
#  UUID('a57fab19-4197-495f-aa4e-39334ad5ee86'): 0,
#  UUID('110653a0-469a-46ab-83c6-636f99bbe765'): 0,
#  UUID('473181fe-65f5-435e-ac81-d2c153041440'): 0,
#  UUID('16016192-2392-401b-b4ee-eedd4b5a15f0'): 0,
#  UUID('801be670-a474-45e8-8d61-b257d6581324'): 0,
#  UUID('46d2f14c-57ab-4b3d-9213-b156a88e2e0a'): 0,
#  UUID('0a4d5495-ca7a-4975-acde-93b8f65a266d'): 0,
#  UUID('e2db062d-90c8-4031-8ce8-5eb067c6c567'): 0,
#  UUID('d7a2f27a-e84d-4d12-931d-f26e8c1eec17'): 0,
#  UUID('c6377715-e05c-4200-a64f-4d2d41b2714a'): 0,
#  UUID('b3739e02-479e-4755-b185-7b6f61ef7a70'): 0,
#  UUID('4f4e6821-7a6a-4ab2-b62a-d977d98aaa68'): 0,
#  UUID('adde599b-6c06-447c-95e0-40faceb93aae'): 0,
#  UUID('17288072-f410-4adc-bb80-51d83185b7a5'): 0,
#  UUID('d5af8d0d-cfbe-403f-976d-e1c4c605b5c2'): 0,
#  UUID('60979c2a-02a5-46c9-9e74-7a268eb7abd4'): 0,
#  UUID('aecc3944-6ceb-4bf2-bee4-c311b14d472e'): 0,
#  UUID('1e823abc-194a-41d3-944a-fa6a8b46e335'): 0,
#  UUID('52c4a89a-63af-4e20-a15d-c01403b38386'): 0,
#  UUID('4496c3a6-9dfe-4402-86f2-97d42f7db09c'): 0,
#  UUID('2084e7f4-93d6-4e58-ad2c-de166490c65e'): 0,
#  UUID('fcfebf40-d5eb-4abe-8f64-f813d22f11cd'): 0,
#  UUID('e5302644-1d93-47bc-a602-4af7b6f2ed15'): 0,
#  UUID('11469e04-c460-49be-b56d-6bb02cfeab33'): 0,
#  UUID('cca35eb3-75db-4eba-b486-90187bda78f0'): 0,
#  UUID('89aee90e-733e-4016-b95a-cc5269eba4f3'): 1,
#  UUID('474909a5-a073-45e4-9235-9e9657714019'): 0,
#  UUID('3da74ade-b891-4108-be3f-73e871b109a8'): 0,
#  UUID('0ab28c6f-f0b9-437b-8c32-7092c9214c31'): 0,
#  UUID('0b9ac7f9-77ef-4161-92af-9c8ca9d0a01e'): 0,
#  UUID('32a2e9b7-0558-45f4-8b15-5ae5cbc23ca6'): 0,
#  UUID('67a90038-4861-4555-a826-8b19d489a192'): 0,
#  UUID('90a78942-ea0a-4882-89c1-eae6b35406db'): 0,
#  UUID('e8aa8459-843e-4e75-ba2a-c97c25fcfef1'): 0,
#  UUID('96b9f738-befe-429f-9af1-b3491fb43f04'): 0,
#  UUID('7aff14c1-0264-4b87-9fa1-d161d78a31d4'): 0,
#  UUID('928cb059-f871-43c3-a0da-2a90e83c8df6'): 0,
#  UUID('9b5af62e-cffa-4cf1-aa54-6cc87fecda76'): 0,
#  UUID('4b07af32-1fcc-4721-8098-5099e277dfab'): 0,
#  UUID('b12a3e3d-5461-4745-91d4-badda90dcf0a'): 0,
#  UUID('c96478f9-c734-4a16-963c-a5acaf12f3b7'): 0,
#  UUID('8c0b69c4-9efd-4acb-bc7c-3a01cd6f0d39'): 0,
#  UUID('d9128bab-2785-4f49-a6d6-a9711bd53d9a'): 0,
#  UUID('dacfceba-5cba-46d0-a6aa-e0199fa7e841'): 0,
#  UUID('2d89d649-0020-420b-9f62-ea1a11f25c3c'): 0,
#  UUID('7b88fee4-4b24-4c6d-b8cf-aa092ce08b0e'): 0,
#  UUID('30836c8d-5ea5-4d38-be26-9f21574d31fc'): 0,
#  UUID('96c217b5-4289-47f3-a21f-1a2d11ecd051'): 0,
#  UUID('26cf7aab-f65b-4a21-93f2-ef701ce32a1b'): 0,
#  UUID('6190893b-86ac-49f6-8ba3-6ba8eb5c66f8'): 0,
#  UUID('e57ebafd-4376-4243-bd3f-1a1cfb45cc91'): 0,
#  UUID('bdfc880e-8b1d-4d74-99db-c89e178ac250'): 0,
#  UUID('769390d7-52b8-4003-ad7d-fee91ec036b6'): 0,
#  UUID('a2c61074-c2e0-4fce-b372-20839f736b3f'): 0,
#  UUID('da5bf262-0253-495d-b837-6d949e92f111'): 0,
#  UUID('d15731c8-6e35-4fec-b731-7171b0c705e9'): 0,
#  UUID('fc884880-2f1b-48f7-88ec-062a1984ffe3'): 0,
#  UUID('b2ad1c67-f480-47df-a7fa-ce95570d3202'): 0,
#  UUID('dc844e70-d3c4-438c-a5b7-7306a1bfb0c2'): 0,
#  UUID('f37cef67-d168-441c-a67c-56b47a8155bb'): 0,
#  UUID('96f9f3dc-1289-44db-8738-b075260f6049'): 0,
#  UUID('c2a97677-4c59-4554-85cc-d0d3cd8aa6de'): 0,
#  UUID('47a0ae01-b4e9-44f2-b87d-36503edadf5b'): 0,
#  UUID('69b46699-f0ae-444d-9a86-ef2a43c2e31f'): 0,
#  UUID('1249bfcd-b7bd-419e-8c50-79f5a56d77f6'): 0,
#  UUID('366f6ae7-86d4-4ab9-a4b7-d7fd908f14b0'): 1,
#  UUID('b6cc1c60-d61c-4a44-a95c-8fb57734bbcb'): 0,
#  UUID('0ce2d835-6b18-4fb2-a9bf-e3f4681f5a89'): 0,
#  UUID('357a6d97-87b1-4e42-9830-a6e4e1f3ccbb'): 0,
#  UUID('c517a9f9-10ae-4afd-9d74-4202aad876ca'): 0,
#  UUID('22e51354-e5c7-40a0-8c6b-2964fe5a3db9'): 0,
#  UUID('e4ffc77c-ef6d-450e-8a78-6859414ac3ec'): 0,
#  UUID('d300937b-7730-4b83-a0f2-383b492982db'): 0,
#  UUID('ea18a8ca-d089-46f9-a335-abecbfb1a0be'): 0,
#  UUID('281aaa87-ce90-495e-87b1-5972a9b7238b'): 0,
#  UUID('245886b8-0417-4906-b883-792ef42630ea'): 0,
#  UUID('6ecc46b1-fb49-467f-a117-f7df30fe5827'): 0,
#  UUID('e6738ca1-c7f7-430e-bb9b-c7e0fe6a0123'): 0,
#  UUID('7fbcaae9-6636-4b26-948b-7194e9f6eda2'): 0,
#  UUID('9f41e399-08d9-45e5-b2f0-e8b8883de604'): 0,
#  UUID('3fb87662-c3a7-447d-9ef0-9feb6c8442f1'): 0,
#  UUID('da98f0f8-23d0-4d8d-ae32-23ebb16c0ffb'): 0,
#  UUID('1fe1bf55-9e59-4eb2-996e-be5ccfaec99e'): 0,
#  UUID('0328550a-7276-4268-9e08-8697adbbd394'): 0,
#  UUID('ccee8686-271f-4a96-a482-b719cc376765'): 0,
#  UUID('d5b6c189-cf3c-4d83-85a8-f8904d85e053'): 0,
#  UUID('a40d9224-584f-424c-aecb-9eaf208c79c5'): 0,
#  UUID('1b02d16f-51d1-48ce-9f66-3ec41f535e0e'): 0,
#  UUID('9807563a-9d50-4a27-8319-f1e823a7b84e'): 0,
#  UUID('512f25e8-9fbe-42b4-b8b7-7041547553f3'): 0,
#  UUID('2e373b02-251b-413e-a24c-08f5297c2d9e'): 0,
#  UUID('c0814dea-0155-49a4-a75e-54a309987fa8'): 0,
#  UUID('63d9ca38-2655-4856-9b0d-cd691c6b105f'): 0,
#  UUID('83c9a1f2-350c-459d-aab0-fd717db55287'): 0,
#  UUID('ef6e3c6e-67c4-4733-b5e1-dfc0ed09b1ff'): 0,
#  UUID('229fea61-ec26-47d0-89ad-9b3d8bec0b51'): 0,
#  UUID('64d7cb2d-8e0a-4a6d-a295-96edc80bbb33'): 0,
#  UUID('2e7a7e0f-dcd5-48f1-b024-debc7fe48242'): 0,
#  UUID('45a72d6b-3095-493a-abe4-07e562891560'): 0,
#  UUID('1d45e7c9-cb1f-4668-93f1-6a338e48f951'): 0,
#  UUID('20e4fdaf-7fb5-4fea-82b5-c9e25f3d899f'): 0,
#  UUID('ab577d8c-0313-48cc-a159-e23db791e1e7'): 0,
#  UUID('909ae61d-4a82-4f43-9564-9f9966fa9952'): 0,
#  UUID('88fc34cf-7a3f-4f8e-81cd-2f9acc35e979'): 0,
#  UUID('a6265ce2-cfe7-4b02-9406-20d7505aaa3b'): 0,
#  UUID('5787e42e-14e5-41b4-a561-59da60427e6f'): 0,
#  UUID('c08ce84a-b491-49d6-88fc-06cc7ed6bddc'): 0,
#  UUID('4cfc17f6-e735-4c06-8137-b43561f36b64'): 0,
#  UUID('8b8edec6-ca86-4532-a385-74c7b7afe6eb'): 0,
#  UUID('9583b0cc-52dc-4107-b9e2-b7ab3a205297'): 0,
#  UUID('8ff9b6ab-fa34-4897-ac0a-1348069e6d4e'): 0,
#  UUID('0e850563-a376-487f-aaf4-7cd52a408a79'): 0,
#  UUID('639d434d-c078-4d46-b813-ff2dd2bce4b0'): 0,
#  UUID('d299a75c-b747-45e1-a3b6-7f213c542220'): 0,
#  UUID('5a16dab7-2d16-4d95-9052-1e24671b1371'): 0,
#  UUID('bd4aec35-a001-4931-bbfe-b7f336dfacaf'): 0,
#  UUID('91b17613-91cb-46ce-9340-ad9792cf35d7'): 0,
#  UUID('038223a3-2b0c-46a8-9428-67f5ab0b6aba'): 0,
#  UUID('ac1ce99e-e86a-462e-a9eb-0ce56dc8b655'): 0,
#  UUID('a61f4d40-de52-4dbf-893a-e3a804e8b35d'): 0,
#  UUID('f5fd5d7e-e717-4c76-86dc-66f0cc3b4574'): 0,
#  UUID('a5acfd76-398e-4d61-b6e1-ec53a7185707'): 0,
#  UUID('9c43e062-4e72-406e-9c41-c6dc1ceb9661'): 0,
#  UUID('ea0d1609-a8b4-4da7-bc65-6e99a5419ea0'): 0,
#  UUID('ac1e29a7-8186-4568-a968-00d6a23634ef'): 0,
#  UUID('d18706d5-ace2-4716-b3ca-ceb4e03a2602'): 1,
#  UUID('b22ea025-569b-442a-b1a5-8885e62764ef'): 0,
#  UUID('a785cffc-317a-431c-92f6-c172d794c9ee'): 0,
#  UUID('b7be43b5-9240-4550-a908-dae6f543a020'): 0,
#  UUID('98b380e5-be9d-4f42-a0e3-91b50a3f10e3'): 0,
#  UUID('0f6d1714-5dea-49de-a141-2598baf35dfb'): 0,
#  UUID('67e2dde8-480c-4e4d-9185-c71109cae6b3'): 0,
#  UUID('7dee69e8-e766-4cc6-99b3-8ac4dc87db61'): 0,
#  UUID('92a269e4-2c8d-4633-89c6-7f36ef738300'): 1,
#  UUID('6b3ae734-2150-414f-aad3-95f9c4d73d55'): 0,
#  UUID('aeb4c6bb-690e-4d8e-954e-6c5660b7d1fc'): 0,
#  UUID('48f7fac4-7816-420c-8087-81f2230cc806'): 0,
#  UUID('ad87d7ec-8fd0-4daf-bc09-0cb3c8a5a670'): 0,
#  UUID('7c17d864-aa25-4654-b4a7-7dc57d702270'): 0,
#  UUID('50a26a11-d7f9-437a-ad12-ee29b1321539'): 0,
#  UUID('5782fd92-d183-459a-b7a4-53c698384f17'): 0,
#  UUID('0fdee56c-9300-4e22-8b12-9a9de760cf2b'): 0,
#  UUID('6a12bb81-8473-4bcc-a40e-341ef62f9bbb'): 0,
#  UUID('9e91238f-6e49-4038-aea7-db5a58ca8987'): 0,
#  UUID('10f945d2-67f5-46ef-b306-8ef784849884'): 0,
#  UUID('8bd17836-f8fc-4cf9-839e-f8aa75655563'): 0,
#  UUID('318514d2-0e51-4751-b187-a3256dc63b54'): 0,
#  UUID('ce623e0f-51fc-47cd-8e39-cef10c0d7fe1'): 0,
#  UUID('82761605-8e58-4e70-95b7-97ba714bc3be'): 0,
#  UUID('f00c0613-31fc-4dbd-af70-863a4f47f3d5'): 0,
#  UUID('bdaf02c8-8613-4cec-8a35-2d9cec128fd8'): 0,
#  UUID('29280d73-2783-44c7-b171-6d1e15984cb9'): 0,
#  UUID('a4237dd0-236e-4e14-8b7b-83abba5bdc94'): 0,
#  UUID('52bcfabe-c682-4f84-862f-dd7823102509'): 0,
#  UUID('49556517-1cc3-4eff-90b0-6c6e9d999865'): 0,
#  UUID('e55e734a-4018-45d5-aecf-b4adeb171c9f'): 0,
#  UUID('4c1dc91b-ead9-4f84-ba7d-bb905fbfdfec'): 0,
#  UUID('4eca6813-be31-4d27-94bd-5393824e5114'): 0,
#  UUID('d23a2727-fdf3-48d6-b5c8-1e585c4b16c0'): 0,
#  UUID('d5edc885-f415-44bb-8d78-ad3ff210fea4'): 0,
#  UUID('796339ba-cb9d-4c7e-b271-b34775c3895a'): 0,
#  UUID('9432a475-afc8-4d04-ba7c-72eb9cf4c34e'): 0,
#  UUID('64095ede-fb34-41f3-8b1b-1663f8862041'): 0,
#  UUID('05cdeeda-78d6-4ee1-bce8-910a0dd84daf'): 0,
#  UUID('3dd00405-99d9-4790-aa06-2b42c50df6db'): 1,
#  UUID('5f83a52a-77d4-48d4-a659-967ee9d59751'): 0,
#  UUID('1d80254f-6aab-48d8-9388-b63497b3c4b1'): 0,
#  UUID('858d8327-0f24-4440-bada-06a327dcfade'): 0,
#  UUID('5996feee-0680-4587-b752-747a4e0b5b06'): 0,
#  UUID('22313101-1835-4306-bcb7-b57de1667c3b'): 0,
#  UUID('3ab75f11-01b8-4aa4-a8df-94add007f5fd'): 0,
#  UUID('db64dad4-b131-4fd8-9b10-14bf47724e49'): 0,
#  UUID('011e0fc1-5f9b-48c0-93c0-6f6ec1b9360a'): 0,
#  UUID('02faf3d6-e93b-4c89-8d32-67bbe6524a97'): 0,
#  UUID('8570ee29-bcc4-48b5-9401-53f34e960bc9'): 0,
#  UUID('1cb00a0c-95ed-47f0-8d7f-38914b6baefa'): 0,
#  UUID('79428003-1c0b-4505-9a9d-41b33c6f3c53'): 0,
#  UUID('281999c0-66fd-4b2e-95be-f2c6d1620179'): 0,
#  UUID('a072fbef-4a67-4c7b-a2ad-dcd5d6b3253a'): 0,
#  UUID('dab3e753-69dd-445c-a4bb-a580f6a0ea4b'): 0,
#  UUID('06f2df6e-545c-4853-b71d-c522e9b0bf79'): 0,
#  UUID('fc800c06-ff6d-44ce-915f-200fdd7fca06'): 0,
#  UUID('d8f62ac3-f9f9-41c3-a961-6b43c36c99ab'): 0,
#  UUID('90c755ee-9b64-40a4-b2e9-c2c841c153c5'): 0,
#  UUID('9f530fb8-218f-49c8-841f-044c73cc7689'): 0,
#  UUID('f1f32dad-bd9d-4b6e-bd5e-7e8cad97120f'): 0,
#  UUID('0ef8a47c-189a-431b-821e-9b90d0e67793'): 0,
#  UUID('4fbe745b-8691-4e1a-a3f6-75a1fdf22999'): 0,
#  UUID('bc58d86e-6412-470e-bb29-70b503258a09'): 0,
#  UUID('ae311be1-f6e8-47ea-8be1-038ee553f4f2'): 0,
#  UUID('3670f0eb-8162-443b-830d-5901910a7ecb'): 0,
#  UUID('4e174479-7fe1-4517-80c2-99039ec6269c'): 0,
#  UUID('775c0830-38b3-4777-8845-2733e7d881c8'): 0,
#  UUID('c0e70e50-0dba-4e55-8870-59cc473ed194'): 0,
#  UUID('5240e89c-c497-47a3-8565-0ff2c9b12513'): 0,
#  UUID('bd540ccf-1b31-4bf1-8fd6-8cf4cc93e63d'): 0,
#  UUID('66c39b4f-8841-4595-bd5d-ffc241e9aacc'): 0,
#  UUID('ab092042-8b0d-4e76-bb40-a43d976373a7'): 0,
#  UUID('179612f8-def1-4278-926b-370ab6727833'): 0,
#  UUID('ee4eae68-72a2-43c5-aa76-83060721a5cc'): 0,
#  UUID('35906a77-069e-4432-8afc-878e3bf385d5'): 0,
#  UUID('5a497625-2d69-4e32-9aaf-41e489c4835d'): 0,
#  UUID('2f256c64-0356-4e44-a227-44254277175c'): 0,
#  UUID('900e08e2-645f-4151-add7-22f8885adca8'): 0,
#  UUID('03a6b398-183e-4567-8f8c-77d653adcf53'): 0,
#  UUID('a7ba44a6-a186-400e-8726-bc395a6aab47'): 0,
#  UUID('443d62f9-359b-4bff-bfa7-f62f2bdb0fb7'): 0,
#  UUID('644f9782-b59c-4b5a-aa20-f64ce4cad368'): 0,
#  UUID('d72ece4b-b6a6-4dc8-afcd-6e1bdea8e38d'): 0,
#  UUID('21c19a88-4643-402c-b0b0-e9ead3103e68'): 0,
#  UUID('de8dff4b-c2e3-46d3-98cd-e5b0f9c16537'): 0,
#  UUID('45badc35-5ba3-41e5-8a3a-11ee1928c740'): 0,
#  UUID('6b9e8474-67a4-4632-8e33-71807a830f49'): 0,
#  UUID('238cb4a6-125a-4e11-842f-6169994867fe'): 0,
#  UUID('652abf6a-aa0e-4388-83d9-5915b268ec1d'): 0,
#  UUID('3e92c517-69f3-4a0f-8523-e67ec80210a8'): 0,
#  UUID('c593e017-8b83-413f-a288-16c0adc93ec1'): 0,
#  UUID('b6a243ba-1609-49ed-bc57-ddcd77b7d288'): 0,
#  UUID('6d089dd9-a701-4504-8382-5adb6d08d1ac'): 0,
#  UUID('487a1acb-b7f4-4999-b447-9981d9741246'): 0,
#  UUID('41a20a9f-0897-47e1-91c5-6032a13e9140'): 0,
#  UUID('998ea427-713d-41f5-ba10-77032386e376'): 0,
#  UUID('903c7105-0f17-44f7-bbef-5a5ce9306906'): 0,
#  UUID('54b2a5b1-37d3-4b2b-9edb-a2cac8a9a9a4'): 0,
#  UUID('f3fe0bf6-96a1-4480-bd5e-5db6072c60aa'): 0,
#  UUID('e6897fc2-53ea-4925-8ec9-28866e271245'): 0,
#  UUID('ef277796-cee7-4394-ac54-c18a95a049a8'): 0,
#  UUID('179ed4bf-32a3-4e66-bbb6-cfbb6918f7ed'): 0,
#  UUID('1111ee68-28d9-473f-b987-d105a6a5f685'): 0,
#  UUID('0b51a038-95d5-43a5-8cf8-d599264bae96'): 0,
#  UUID('eda33ab6-cc16-41ec-9c16-3c1b0299a336'): 0,
#  UUID('6a1cbcdf-f5a8-4cfa-aaaa-34f05b325d39'): 0,
#  UUID('8c864b56-35d9-4761-9c57-79060ce1a545'): 0,
#  UUID('ec30e1d5-d0b4-4244-93c2-eb65e98ecd3c'): 0,
#  UUID('e42f8522-32be-435b-8962-b4e350160e43'): 0,
#  UUID('37a74689-e9b7-4441-9c66-a0a5fa40c475'): 0,
#  UUID('e1c5f794-4fd5-4856-99ff-08873a99df1e'): 0,
#  UUID('759c3a79-a003-4989-89da-d524da0bb62c'): 0,
#  UUID('d1b6da34-d678-4c95-a022-da255a896af5'): 0,
#  UUID('11b604b4-78b7-4fdd-ae53-e9fa454a0cb8'): 0,
#  UUID('b30f2989-d86f-435d-b485-c2dfe5f40cd6'): 0,
#  UUID('e0c6ea73-73c5-44f6-847c-14ddd4077ea9'): 0,
#  UUID('db62c044-3965-4d20-a9fc-d5016d5cc898'): 0,
#  UUID('9dc0400c-827c-44ec-8f72-0398d548f6f3'): 0,
#  UUID('7af068b0-711a-44e5-a69e-f75cb5043b19'): 0,
#  UUID('ffe0e90a-7e7e-4ea0-908b-e61c3e899d35'): 0,
#  UUID('091ee39c-f778-4ef3-b88f-831162808841'): 0,
#  UUID('95eda9bb-1037-4993-a4bc-ecf815f5b0c1'): 0,
#  UUID('e6b8b5a8-8e8c-49d4-b899-6708cb180ee7'): 1,
#  UUID('92a91b87-e71c-4ae1-9287-fb409a59c9fc'): 0,
#  UUID('8faf0949-e516-4593-b445-c7ca4d86e5e0'): 0,
#  UUID('810f6d7d-48a1-43b0-a29e-ab9ca10d8b87'): 0,
#  UUID('04f576c5-2789-4cb3-88a7-bf7ee9f13cf1'): 0,
#  UUID('b42ec338-e8b0-497f-84ce-ed99af8e94c3'): 0,
#  UUID('ec80a350-f524-4032-adb2-9f360b9c6a90'): 0,
#  UUID('ba699211-65fe-418e-be6d-97a0d9795dc0'): 0,
#  UUID('d1f4924d-2d29-4086-847e-af9579d09f37'): 0,
#  UUID('c1cf5dda-15a4-4777-ad1b-1661ad4e18e3'): 0,
#  UUID('ae2d4109-d35c-4123-85bd-44083f1267ae'): 0,
#  UUID('e556bcdc-2b2c-4d53-b25a-253286d41d27'): 0,
#  UUID('57f88fd3-25c2-404c-9a8e-4a91590f0a80'): 0,
#  UUID('03cde683-d305-42fd-9cb8-da41e9f75dce'): 0,
#  UUID('26f44b8a-8ab1-4ad2-9b4c-7d948c33e468'): 0,
#  UUID('9684068f-2aaa-453d-b317-97dce504d2e3'): 0,
#  UUID('cf9c5bcf-0353-4607-b4b2-ca79eb5235b1'): 0,
#  UUID('80bfc458-8321-4cda-b25f-c742c12511f7'): 0,
#  UUID('4d50328b-dd1f-41b1-9545-57bd55b656e1'): 0,
#  UUID('b093e682-6a08-4f07-8b39-5c3b9b5d0f04'): 0,
#  UUID('79bff814-9169-46d4-8388-cbd0c98575be'): 0,
#  UUID('8312e667-da94-4201-84a0-d446c01a6448'): 0,
#  UUID('3f446e11-5d48-40b3-92c5-d62cb8ccaabc'): 0,
#  UUID('e31526ba-ac10-4e3e-b269-a7380727ac62'): 0,
#  UUID('72cffc45-ba7d-4f5c-b727-afa0d23de9ef'): 0,
#  UUID('a1c270a2-4a3f-47af-90a5-ed2e3f9d3a93'): 0,
#  UUID('9968f114-a035-402f-9e5f-97cb71a6bf13'): 0,
#  UUID('e0e3e00d-d0b4-4bdc-9213-41a486527527'): 0,
#  UUID('eba8523e-1961-415e-b761-1aac51de71cd'): 0,
#  UUID('c70c5d3c-d778-44ee-b702-f6f69c22507e'): 0,
#  UUID('591b9e91-97dc-4ca0-a15e-d5954a8a5e87'): 0,
#  UUID('6485ab34-a9fc-4efb-85cc-1f1ad80930a4'): 0,
#  UUID('0d59a4f2-1d16-4ebf-8a1c-58fc04744490'): 0,
#  UUID('bd5afdfb-891d-4567-8269-34b6d6a7396e'): 0,
#  UUID('85ccb536-979a-4c1c-82af-71fc553f1053'): 0,
#  UUID('f94670cb-ead8-4202-9ea2-4d58d9eb7056'): 0,
#  UUID('43a4e8f5-64c7-4312-8fe2-4441cf5e3e08'): 0,
#  UUID('cacd7cc3-f0e8-4573-b8a5-ec970cfb7c8e'): 0,
#  UUID('4ed04e9a-e7bb-4605-ac2e-9794dfb36bfc'): 0,
#  UUID('a0b6a42a-27a8-4242-86ee-b26ee89a2748'): 0,
#  UUID('4b3445af-392a-4465-9ce2-8d7b490de7d7'): 0,
#  UUID('51e5a9a3-06ab-449e-a48b-d76dfaa14a7f'): 0,
#  UUID('5713db5a-e45d-4a05-95cd-26e837cde9e1'): 0,
#  UUID('e5a1d775-b42b-4369-a65e-79ca1c4df031'): 0,
#  UUID('fbc4da73-d233-4185-92af-973d037fca68'): 0,
#  UUID('ba323477-2aa7-43f9-a7ed-790da28f83eb'): 0,
#  UUID('cdb285cd-fd21-4f2c-975f-c5237a375f28'): 0,
#  UUID('4caf6369-d99a-48f8-9c8a-fc1408f229ae'): 0,
#  UUID('bf02ab9c-f4ba-4f59-bfeb-9560e1b71707'): 0,
#  UUID('b0dce963-a50d-4d1b-847c-c61e80525492'): 0,
#  UUID('86024d0b-1517-442c-a784-1e4a2759ad08'): 0,
#  UUID('012f2d31-378d-40ca-be5d-1a976590634b'): 0,
#  UUID('67dcb07e-5957-490c-87ca-31988a3a0b71'): 0,
#  UUID('9e0bdc43-cfdd-4380-a07e-0c3be64719b2'): 0,
#  UUID('30744391-371a-4e8c-a7d3-dd5bc5c2ffca'): 0,
#  UUID('817789cc-03a5-404d-92da-c86113078090'): 0,
#  UUID('2d824f55-630c-4aa6-84da-652ce104631c'): 0,
#  UUID('7f579dab-3cbf-4e48-a5c2-6883d0d8987e'): 0,
#  UUID('d6cf9cd9-713e-4389-894d-429e939d430a'): 0,
#  UUID('677c6eaa-c0fd-4050-98cc-425fdfaaa08d'): 0,
#  UUID('cc2b9aa1-4118-482a-bffa-1fc6ae2e3a52'): 0,
#  UUID('6ed274cf-5983-4ef3-b755-e5031e786199'): 0,
#  UUID('925f221b-31f8-44f6-8bc7-d6081ae3a562'): 0,
#  UUID('94770368-0ca0-40f0-828e-3936d2d7d39a'): 0,
#  UUID('f14ebd04-e49b-46b3-9afa-cb4955937065'): 0,
#  UUID('c03f77fd-b4ac-4c66-a2c6-39beaa1ac4b7'): 0,
#  UUID('9b565243-c3c6-457a-8a45-5094a0c1e9b4'): 0,
#  UUID('e12ce082-2c63-47d9-900f-2ba3e2a41d74'): 0,
#  UUID('b605c44b-9010-496c-a088-827757b7ea38'): 0,
#  UUID('9f78bc21-3404-42a4-b1f9-36447ac37242'): 0,
#  UUID('de57336e-e48a-4c4c-97cb-d3f5a1602d99'): 0,
#  UUID('d0f5f342-7ada-4ad4-abe2-b08dac55499f'): 0,
#  UUID('084ea74b-0a01-4db3-b8af-286df9c0d597'): 0,
#  UUID('687f6fa4-fc17-436c-9b44-033ffd12ae8c'): 0,
#  UUID('bd7dc755-b151-4cfb-bbf2-baf9621c5661'): 0,
#  UUID('79128d04-bd84-42da-965e-6de4e44a9ec9'): 0,
#  UUID('f504194f-62cf-4fa2-ae1b-cfc2b592ddab'): 0,
#  UUID('d50e27ca-6206-4ee2-991a-f059826e1901'): 0,
#  UUID('aa69846d-10f2-49b5-a80e-54c2362fa158'): 0,
#  UUID('4c25e6e2-3bc6-4145-8bca-6943b8ca1f2b'): 0,
#  UUID('4c8138ca-f5c5-47bf-8899-9b47f2bbce72'): 0,
#  UUID('b2e8ffa3-0cf6-461b-9274-4e00f9c50d2a'): 0,
#  UUID('b58bd4e1-3f3e-4d2b-a297-02287d69ea14'): 0,
#  UUID('b59beda9-4afd-409a-a176-acf43aa1546c'): 0,
#  UUID('38fa5870-b8a9-497f-b672-b73b7e21ba2f'): 0,
#  UUID('4399c017-61fb-4163-a007-bbc519f51bc8'): 0,
#  UUID('82fe9999-4ddb-4966-81b2-ef7ec8039d60'): 0,
#  UUID('f2fae15a-1796-4cfd-9c72-3c983782cebf'): 0,
#  UUID('7f0f93a9-18db-4fb4-aa36-f5c60f273979'): 0,
#  UUID('2d2420cb-c44c-4fc7-88db-70db3182ee43'): 0,
#  UUID('a834d9a0-9601-4a61-a564-ca7d9d0a8e86'): 0,
#  UUID('f907905d-fd5a-47d1-830f-2e8d6605b01a'): 0,
#  UUID('4c0ecdc7-2621-401b-b38d-a060b03cece5'): 0,
#  UUID('f2cb32a2-5485-40ad-bd4a-b8dc9812056e'): 0,
#  UUID('d6950d86-b0d4-47f4-91f0-fdfd5a7638c5'): 0,
#  UUID('e0d855f3-e96e-48da-9d47-eed0d0dc1d33'): 0,
#  UUID('fe650e0c-28bd-48f3-84e0-dc21aeea4e92'): 0,
#  UUID('6494bcd3-bdae-4e9e-8ab8-bbd4e4ec3313'): 0,
#  UUID('fcc88177-86a9-439c-a453-420619cca4d1'): 0,
#  UUID('bf1b5b09-fc66-4a2d-af8a-f8c8381e0023'): 0,
#  UUID('96f1a73a-bb9d-4455-8d8e-1bbdac1a9a2b'): 0,
#  UUID('4d63894f-1332-46cd-9145-efb4ce88fa67'): 0,
#  UUID('701d9aa6-9722-4fb5-aae5-8788918a808f'): 0,
#  UUID('43178416-2a1f-4e76-b676-cd66f67d05e0'): 0,
#  UUID('b82a0dbf-dcdb-4b47-9e50-b6fcd53b594f'): 0,
#  UUID('70bee9c4-05bf-45bf-924e-972e34516fd7'): 0,
#  UUID('08449707-b565-4491-bde8-50a4175ceaa7'): 0,
#  UUID('3faaec2a-fa2f-4760-b242-c9453a93a67c'): 0,
#  UUID('2ef46b5e-d133-495d-93a5-f2073dabedab'): 0,
#  UUID('f56d11d4-adc3-4fa6-9684-6705a25aa53e'): 0,
#  UUID('dad2fe60-d5f3-4bae-8855-89571fed8073'): 0,
#  UUID('ebfd3d10-c87f-4f4f-9583-1671a2cee472'): 0,
#  UUID('787ca981-33a0-4a7a-8b22-ad64b6e4051b'): 0,
#  UUID('e1448154-4605-4b0a-b604-e27c6fdfc1c2'): 0,
#  UUID('231545a4-4e14-4c4c-b65f-e5d7b68400f4'): 0,
#  UUID('72ae4986-b9ae-4d6d-bc5c-22d29212fc5e'): 0,
#  UUID('3245951b-d0f6-485d-a2d8-b5ef3e28427a'): 0,
#  UUID('1a85e7b2-e0b1-4527-ba96-62320690603f'): 0,
#  UUID('9992ac06-e7a1-421e-9571-1b1c9082df2d'): 0,
#  UUID('540250ca-4bc2-4d10-a925-98caf2d02743'): 0,
#  UUID('155a736d-5fa2-4959-bf7b-82c9cea3622d'): 0,
#  UUID('5e0d3b3f-fbd6-45ed-ad5a-6cc5cdcbb523'): 0,
#  UUID('05413381-df9f-4215-9ab7-6eca5b5abbba'): 0,
#  UUID('fd07bbbc-d018-4538-a2d7-2ccf0b0a3910'): 0,
#  UUID('27b9c5ac-afda-4990-a0b3-4c94e06336fe'): 0,
#  UUID('0fa431ab-03f0-4b58-9614-50fd19641080'): 0,
#  UUID('b3a9a9cd-cc79-45ac-8f6b-267f4a6f68b8'): 0,
#  UUID('b6a87dae-2e46-4738-b144-3a79109fef43'): 0,
#  UUID('70dcbd52-dc16-45ac-af6c-064c5e4a69bf'): 0,
#  UUID('b7bd58ed-df4b-4a9a-9b5a-522d4d639a32'): 0,
#  UUID('25027a35-916e-4d5f-85d9-f292bb6453f4'): 0,
#  UUID('9911419c-b56d-49a9-849a-eb605582345c'): 0,
#  UUID('76b96f24-1153-4b51-82b6-62c394ec4f27'): 0,
#  UUID('642a49a5-bb2d-491f-80c9-1968244d9417'): 0,
#  UUID('2101bedb-eb3b-42d8-a0ed-a2f561f6c031'): 0,
#  UUID('a4b97496-a326-4e47-a7cc-52ede9372e26'): 0,
#  UUID('a4e3bea6-3e51-4892-9ec7-d2d09bb7d1a5'): 0,
#  UUID('a69dbd4b-15a0-4f6b-8681-98731a036d0a'): 0,
#  UUID('8411a762-04cd-4fec-af4a-7b8d68fc2435'): 0,
#  UUID('ea43a72c-4b2d-48b6-83c1-4185ebf5e9f1'): 0,
#  UUID('19215cfa-257c-452a-b5d5-29112de057e9'): 0,
#  UUID('626352ae-bdac-4c72-9810-2c2c1b2a594f'): 0,
#  UUID('bc6df453-6fb8-4df8-b15f-166054437fef'): 0,
#  UUID('e8059e70-b69a-42f3-ac88-adce7e939a63'): 0,
#  UUID('d3ecfa84-05f1-41b1-8415-70d22a8f006a'): 0,
#  UUID('ace84962-fd09-43a3-9557-444427467c5d'): 0,
#  UUID('f1b8075e-8b5b-4bfd-9989-58999aa87d15'): 0,
#  UUID('b7750e4a-252c-4aaf-8b7e-91fdc7fd1c7f'): 0,
#  UUID('e6632082-2525-4ad0-a681-84846c7f77a6'): 0,
#  UUID('1b851cd3-4e4e-42ed-8101-b76519190dab'): 0,
#  UUID('850a43f3-dc8d-46e9-b842-7a62ec1b36a7'): 0,
#  UUID('e60c780f-08d3-48b8-803e-5ecddd62695c'): 0,
#  UUID('28e12128-4fda-4db5-897c-74c2869c099f'): 0,
#  UUID('d3628ff6-0fe3-474c-aa3c-b78f56232f18'): 0,
#  UUID('cdecf797-d837-4176-bee1-6c471d0cf341'): 0,
#  UUID('fdb12efc-5e7d-413c-a00d-3b9ea31a1dcd'): 0,
#  UUID('7183c1f7-c0c1-4dde-b8b5-3a03af0be548'): 0,
#  UUID('9af4d792-004c-46ad-b649-201aa513bb8c'): 1,
#  UUID('f018e895-7eef-46f6-95c7-ca657dcd130f'): 0,
#  UUID('309237e0-8569-477b-b891-ea16200b239d'): 0,
#  UUID('621a77ea-7bb1-4286-946c-e8e4a10ef03a'): 0,
#  UUID('c65cdd85-fd9f-46d0-bc69-1dfdcbba7eb4'): 0,
#  UUID('aad32cce-d2d3-4edc-9808-a4e841f1b1d3'): 0,
#  UUID('fd68392e-97bb-4e7e-a675-6ff00c51eb0c'): 0,
#  UUID('7fd590b8-20ff-4158-97c5-ec81f3c91afa'): 0,
#  UUID('82f5b94f-744c-49b9-ac4a-63838c64eb22'): 0,
#  UUID('49def97e-e388-48b2-a4b9-069c133d48ff'): 0,
#  UUID('46385ca6-827a-4812-ad92-2557b9fef84c'): 0,
#  UUID('54a0fe57-2f98-4753-91d2-d6923d9edc0a'): 0,
#  UUID('6b82677a-8df2-4c00-ba62-162306f6c5af'): 0,
#  UUID('36607fdd-1503-4d7c-95e1-c4a1f7215d58'): 0,
#  UUID('a1564654-7a2d-4825-8159-c5e9dd7095bb'): 0,
#  UUID('6a6f20af-4288-4d9b-90b9-6e41fc3d5bb0'): 0,
#  UUID('423f624c-8fc7-40f1-affa-e92ce60c5499'): 0,
#  UUID('18a1aaed-8443-49c9-bdb2-c98cd2c53db2'): 0,
#  UUID('3636bcea-a939-4020-8605-9bf4e2f1c3fa'): 0,
#  UUID('1bad328e-a2be-49bb-a179-db7c1b30bc78'): 0,
#  UUID('4b8ef49d-ec8a-46e9-adaf-5941d0178cb1'): 0,
#  UUID('00bd02a9-76db-4488-a12a-b5e7fa53571a'): 0,
#  UUID('3869e3df-3f47-4fbe-9237-30648b9b5abb'): 0,
#  UUID('a636e49f-1af9-4a5a-9402-3bbe1b081713'): 0,
#  UUID('78ffb91f-b73d-45d9-84ba-5ab97a949b3e'): 0,
#  UUID('4b81c067-a355-4152-bf06-fe64c0a66c41'): 0,
#  UUID('a1e52cfb-089a-448c-8a63-425ea8a4756e'): 0,
#  UUID('efbaf66a-dc13-47fc-8c91-2013b29dc23c'): 0,
#  UUID('d15337cf-dd04-4dc5-ab5f-29e4472d9cbd'): 0,
#  UUID('dcaeee0f-2200-4f90-b9f8-d441d1a64581'): 0,
#  UUID('1f550cee-39a3-4214-bcfe-d030fedb19f9'): 0,
#  UUID('4dee86fa-3b92-4660-b1b2-cf6f2428680e'): 0,
#  UUID('f25d2408-fdd9-4dc6-8d0c-508f6264dbe5'): 0,
#  UUID('5f974b90-70e6-41a4-b268-707c1446b903'): 0,
#  UUID('ce9a7af2-b0ca-4b9a-85b4-701cb1bd1438'): 0,
#  UUID('957ed4fb-3222-4a8d-8fa2-77062462b81f'): 0,
#  UUID('76f4e890-a11a-4057-afd4-9ef0c4d565a5'): 0,
#  UUID('414d74b3-f1bd-486f-8105-e22e025e372f'): 0,
#  UUID('8eec0f42-fdc2-44b4-aeab-6446fde1f243'): 0,
#  UUID('54620043-7083-4a0b-99c9-9b72cf484f3b'): 0,
#  UUID('7be4ae47-7491-4e61-a6d1-674ecd968a27'): 0,
#  UUID('b9a9636b-28f4-47e5-bbc4-ffb5b71383ac'): 0,
#  UUID('20db4064-1500-4df7-8af6-14b5a86480f3'): 0,
#  UUID('e48c645d-ee9b-4e0e-819a-d082ce18a488'): 0,
#  UUID('5f39561e-f09c-4cca-a3f9-11f357ee8cd5'): 0,
#  UUID('3c02e3b5-9af3-40b0-9717-45dfafcde6b4'): 0,
#  UUID('212cd67e-5d0b-4b00-8159-dea097d6a785'): 0,
#  UUID('145a20fe-03bd-436b-8cdb-919906cc3b13'): 0,
#  UUID('f627821b-6943-45d7-93c1-0ee3db1c385b'): 0,
#  UUID('9000c458-cb02-4ee1-979b-35bc8803e827'): 0,
#  UUID('d66724cf-a096-4b97-b4ca-1a49e50b1629'): 0,
#  UUID('c63d5f2d-d7e2-458b-8145-851f7ff9f66e'): 0,
#  UUID('449eda2e-64f6-4789-ac0a-24fad69084ec'): 0,
#  UUID('e3b338b4-92b0-4db2-a568-4f02c95ef73f'): 0,
#  UUID('8fc91b6c-fb04-483a-b7c5-13190687c777'): 0,
#  UUID('e5ec3340-e7d5-447c-9d87-53a8f421fe5d'): 0,
#  UUID('b0b409f7-da32-4930-b140-39cab25afee9'): 0,
#  UUID('3478e23e-01f9-48bd-adab-5f638a25d5e9'): 0,
#  UUID('28ac05ee-66a2-4c15-9094-e80e004e8aa3'): 0,
#  UUID('dfdf58df-06e4-4554-8930-58074a71b237'): 0,
#  UUID('40012b03-86a4-4031-b328-1416b1c32521'): 0,
#  UUID('c05624cc-e40a-4e28-bf75-ab351b2c6e42'): 0,
#  UUID('b8ac20b9-7c29-4165-8aa5-a4748777a42c'): 0,
#  UUID('3376c581-5f4a-49ad-a1a7-bd0021fde4f2'): 0,
#  UUID('7fd1de7a-81d6-4588-a2ca-d9167a241295'): 0,
#  UUID('7093e6b2-4a2e-4499-8ae2-201864117566'): 0,
#  UUID('c91a3822-01c5-4b9f-91a9-d8a748a4f9f8'): 0,
#  UUID('3ba67320-1952-49fe-ade5-b4897864747d'): 0,
#  UUID('682c2a5b-dd1d-4df8-8f09-5be3d650e242'): 0,
#  UUID('ac41f0fa-310f-4d6d-abd5-1c9a36ad60c2'): 0,
#  UUID('6dea131c-087c-4223-a2fe-611c1cb634d0'): 0,
#  UUID('0de691f8-413c-4bf0-b2ab-f74881c659b1'): 0,
#  UUID('fd7206ed-9774-4227-9593-d345d92d3aa8'): 0,
#  UUID('8ab385c8-4ab3-4e68-bfff-f1b4762ff57d'): 0,
#  UUID('08274337-322c-498c-9093-12c8ac001519'): 0,
#  UUID('b68d6df7-b66a-4fef-9429-6d5b9894c065'): 0,
#  UUID('9d781461-b142-40d1-a344-06ac8d84bb74'): 0,
#  UUID('370cc1dc-52b2-464e-b88c-159bd734e23f'): 0,
#  UUID('e2bb7a4d-1874-439a-be78-721121329f37'): 0,
#  UUID('4d274cdb-00dc-4a18-b6fe-a8fac7df649b'): 0,
#  UUID('e2b01478-f72c-4dff-8156-f89892a8b7f6'): 0,
#  UUID('b002e0b3-bf77-4c63-b4fd-e5f18eeafe1c'): 0,
#  UUID('78b202d0-48b2-47f6-b3cf-7d843d9b2e9d'): 0,
#  UUID('9851121c-f0f4-4216-80f0-9df45f07ccfc'): 0,
#  UUID('42b35257-641b-4d39-84c2-5a515ef35253'): 0,
#  UUID('6c035880-4887-41ac-880d-45f53b50a833'): 0,
#  UUID('1534a436-94bc-40cc-873e-31516520329c'): 0,
#  UUID('39d5e5ad-922d-4d4c-a2b6-d93a94010a04'): 0,
#  UUID('ad49998e-eae6-4105-832a-0d2a777cde17'): 0,
#  UUID('bb6d2662-3afe-442c-bedf-cd97167392e5'): 0,
#  UUID('b664585b-bf1b-4b97-b508-bddb16b57349'): 0,
#  UUID('07c28c31-25b7-491c-834b-5ddbbd4f82d5'): 0,
#  UUID('d6f6121a-4cac-438e-ad92-ce96c3ddbe49'): 0,
#  UUID('d75dfce7-898f-4e8e-b924-a11762ad468c'): 0,
#  UUID('ea1c62fd-bf82-45e2-845c-70861c51af83'): 0,
#  UUID('3d2a0243-ed03-4c93-947b-684073770f16'): 0,
#  UUID('9589dfd3-62c7-4f8f-9b89-2ba93416674f'): 0,
#  UUID('cee95c2b-503a-4b2a-9cf2-2d25badb17c4'): 0,
#  UUID('6f3eb8fc-4bb5-478e-bff4-5506bcf0f542'): 0,
#  UUID('f959e698-9466-427b-9ebc-f2e54aaca82a'): 0,
#  UUID('ac5571ab-e1e6-4ba0-8e1d-4092b2a47935'): 0,
#  UUID('599acd82-eafe-4901-add6-034b6cf44455'): 0,
#  UUID('74aa63cf-d863-40df-9151-46b53a9badb6'): 0,
#  UUID('19b4056c-eda8-4554-bfe4-1f6db713b0f6'): 0,
#  UUID('10628627-d1a1-4b17-8830-8f65f3a4f8dd'): 0,
#  UUID('47b37e2e-f8ae-4d75-b7ca-92bf08a6aefe'): 0,
#  UUID('d3fe555e-3cd1-4034-9c6c-8deb7feb56d9'): 0,
#  UUID('39f504b3-ef50-45b1-b321-064a96433321'): 0,
#  UUID('8fef6d99-fb5c-4811-bf46-a31a20b3cfc9'): 0,
#  UUID('96549ce3-795a-4131-8b7d-b7b0aa6f72aa'): 0,
#  UUID('7fa00a92-b30d-465a-8ef4-05d60d867312'): 1,
#  UUID('a4e6dbbb-4afa-4174-b6c4-f57bea232375'): 0,
#  UUID('37a8f8c0-d8a4-4073-84bf-7446d6ca58ac'): 0,
#  UUID('e250d2ae-64db-458c-b562-c27dac519e69'): 0,
#  UUID('38a17c3f-f6dc-4a6a-b1b8-ee5a5384c68e'): 0,
#  UUID('cab2e20b-d98c-4f4b-947d-12f884a70536'): 0,
#  UUID('bb9d5c5a-ec66-4507-a5f5-ec8b077ba381'): 0,
#  UUID('5ec994b5-cc3d-4d2b-9850-b29d2281d8ec'): 0,
#  UUID('ba345a15-768c-44fd-b9c3-6faa30a6f6cc'): 0,
#  UUID('c65240f3-0eb1-4435-9a7f-bb14cc536aa0'): 0,
#  UUID('5fb739c2-1bab-4930-9cb6-5921fb5fbc84'): 0,
#  UUID('f18ae752-0ccf-4c8d-a4d8-01377a009709'): 0,
#  UUID('6b1e3237-db91-4e0e-b807-5656c47a1eea'): 0,
#  UUID('eaf0b3f6-4570-4bba-af86-037a569c23a6'): 0,
#  UUID('8cc7b2dc-05bd-4128-941f-6c8e3af96391'): 0,
#  UUID('10e969fd-45d9-4dfa-90ea-e4e6e64a0a50'): 0,
#  UUID('e93154f4-89d4-444c-9218-a3e4eefc1223'): 0,
#  UUID('1dee87da-cb83-434c-bad0-8a84d994fb70'): 0,
#  UUID('d6cb41f4-13c7-4d9d-b86c-a170b6637b2a'): 0,
#  UUID('4a1c629e-2831-4523-88f7-7160d4f29e15'): 0,
#  UUID('10e68693-a47f-4bbc-a240-f77af60d7e63'): 0,
#  UUID('41c982a7-0dc1-4777-86b5-9a4d6523bcee'): 0,
#  UUID('985fc71c-0b0e-4c46-9f7d-6e3a235cfa63'): 0,
#  UUID('293d4bfa-2b82-4268-858a-d8597de32f1e'): 0,
#  UUID('19082e81-38d5-448f-9e79-c9ac9abbca54'): 0,
#  UUID('04fbb7d0-b2e4-48a5-ad82-8b39dd5cc7f4'): 0,
#  UUID('790ae6d4-0368-4f05-8dee-3b8e04d88ad7'): 0,
#  UUID('33b512c6-5a9a-4d76-8f85-9e6ce32adecc'): 0,
#  UUID('4d1fc2e3-af27-4761-bbf9-6596331658a8'): 0,
#  UUID('c4acfff8-805a-4ed8-acb1-644d3f8e1b01'): 0,
#  UUID('f85fa902-dec7-4746-8a52-3e3456cc4bfd'): 0,
#  UUID('730f7364-34bb-44a9-bafa-792df0ab8ad6'): 0,
#  UUID('e72d976c-f77e-4f37-bfd0-1116fd34c249'): 0,
#  UUID('3e4cd22b-bcae-42c3-81f7-515f788d8e5c'): 0,
#  UUID('e3bcbd66-0edf-4fea-a5a5-bfc1144da12e'): 0,
#  UUID('d1e35685-ce9e-4c9c-adbf-ae9790fc5baf'): 0,
#  UUID('b5c8aaef-9857-4284-9724-7a1b36e4a5ae'): 0,
#  UUID('e5abc5e0-b2ba-4a82-b7fe-fb0589f17a71'): 0,
#  UUID('9f867e3c-f0b0-4e9c-9f57-1366adfe672a'): 0,
#  UUID('36f27040-bfde-454c-9ce7-92960cf206d5'): 0,
#  UUID('499f2f85-1a1a-4022-b762-627b2c94943d'): 0,
#  UUID('aeb84be2-60bc-46f6-a307-e4bab0b43770'): 0,
#  UUID('0d6c3949-7ec3-445b-94c5-21450077ce7a'): 0,
#  UUID('7498de64-71dd-452a-b54e-8f181916a72f'): 0,
#  UUID('231274e7-bc8d-4d34-918e-45a068821f7a'): 0,
#  UUID('1e44c456-0d11-4a95-993b-be8e67a0797b'): 0,
#  UUID('6cac0900-fb45-4b00-b1eb-0eddecac9c60'): 0,
#  UUID('ba37ed5f-e719-41c7-8510-1756d420d713'): 0,
#  UUID('1f24af68-2336-4134-84e5-6a4d81d5c41a'): 0,
#  UUID('ff7663c6-bdbe-4404-8e46-eacc4d41cce4'): 0,
#  UUID('83cc1894-e2b4-448c-b964-f619a3d7d51a'): 0,
#  UUID('1e780a7e-55eb-4800-8297-1c1e09f7556b'): 0,
#  UUID('47a4d766-d785-426a-a491-317aa06f63d8'): 0,
#  UUID('6757d13a-f835-4ba3-88b3-89bfeb86424d'): 0,
#  UUID('bcf73afd-271b-4ab6-b3ac-547ca460cda7'): 0,
#  UUID('e1972495-47da-4250-ada5-e39cf05031d9'): 0,
#  UUID('58265f0b-1fde-41df-b3e3-26d47e6fc605'): 0,
#  UUID('6fde8732-dd04-41ad-bcc7-c10faa789e41'): 0,
#  UUID('2bd6620d-f1e0-45c5-a02f-7a8c8eba40cd'): 0,
#  UUID('8a6081c9-3629-4b89-9ea7-ae2813c85004'): 0,
#  UUID('8fd33a17-719a-4ebb-8d46-edd57de6f7d7'): 0,
#  UUID('4b040750-a2ac-4af7-bb97-bf04615b6dc2'): 0,
#  UUID('ed51dd14-fed8-42aa-8d14-5f2a3c539e5c'): 0,
#  UUID('1476c359-08a1-411b-8542-61fe1a8a5745'): 0,
#  UUID('d4cc263e-fa78-454f-b826-2e43a11ba30c'): 0,
#  UUID('5b1484a8-b3cf-4b7a-935b-4806223e1c5e'): 0,
#  UUID('9e645993-f1a3-4691-866c-3ecb235a291e'): 0,
#  UUID('e9ccc9a9-2457-462e-ae82-8b6e2cdfd234'): 0,
#  UUID('fcd836c3-7e04-4eca-968b-d9f7f0479f1d'): 0,
#  UUID('22455275-4c40-4ad7-bc00-f0729c2d854b'): 0,
#  UUID('5be7459c-8911-47d8-a477-bebe74e05d91'): 0,
#  UUID('c747c74d-b4c5-49ea-a56b-5798155c6154'): 0,
#  UUID('319f4718-75f4-4f09-9603-ee059d03f282'): 0,
#  UUID('628f5148-684d-4bbc-afd5-a1a8e05554f4'): 0,
#  UUID('1752662d-958d-4779-8353-f5e38648738a'): 0,
#  UUID('955c19c2-6af5-4c46-b24c-c4e6e8e5d490'): 0,
#  UUID('93e64980-57ba-421a-b2f7-93f19051203e'): 0,
#  UUID('d5b603a3-800e-4683-bfa3-45e922a2f810'): 0,
#  UUID('7625c285-eb9d-4385-ba47-de57d328da99'): 0,
#  UUID('afdb079e-5439-4e59-b9e4-e66baac8ac9f'): 0,
#  UUID('d2266fa5-ed41-4e32-8a30-58082eb5a751'): 0,
#  UUID('cf13bdc6-f589-43e1-b76e-38067a1c6a57'): 0,
#  UUID('49959add-c22e-4c28-a919-79488ebd28c9'): 0,
#  UUID('e4919aa5-4e57-411e-ab68-860744497543'): 0,
#  UUID('b16126eb-6d92-4fe5-8869-c687993633dc'): 0,
#  UUID('fa5066dd-91ad-4f17-bdc3-4eea5e1a276f'): 0,
#  UUID('2a5253f4-2d12-40e3-b8d0-fc1c2e65a449'): 0,
#  UUID('2efcd857-d4b7-4f5d-8e5a-c5eddd39140c'): 0,
#  UUID('13b8679a-14fe-4a62-8d4a-4db24bbc106d'): 0,
#  UUID('15d6a2de-d3c8-4750-81b2-ceec08beb9be'): 0,
#  UUID('2af885dc-8a14-47c8-b536-326d33305024'): 0,
#  UUID('41d4276f-f733-4186-b2a8-fdd97b202108'): 0,
#  UUID('cd7ac7b9-4e06-46e1-b554-73ab1aad16ee'): 0,
#  UUID('c157f4ad-4f20-49ad-9411-fd0429ac98a3'): 0,
#  UUID('8713e677-588a-476b-a8d7-d10d959cf0ac'): 0,
#  UUID('8a585bf8-3c6f-4747-88d6-3144fbe55c27'): 0,
#  UUID('bb7fdbfe-46a2-4132-a03f-af3893b9cde6'): 0,
#  UUID('d2cc3c50-1870-495a-920a-1c5de23e8a5d'): 0,
#  UUID('64ce24a3-d076-417e-a999-78f74ed79700'): 0,
#  UUID('09636306-c497-48e3-8abe-bd8e2d49c6d8'): 0,
#  UUID('599be534-bd18-4727-bb07-70488e3b8b2b'): 0,
#  UUID('cc15ae6f-42e9-4235-b54e-5d01c5377ba2'): 0,
#  ...}

# %% [markdown]
# # proposed penalty for dilution
# false negative probability of a single, undiluted sample : $p_-$
#
# corrected false negative after dilution:
#
# # $p_-^{diluted} = p_- (1 + \frac{m_{pools}}{n_{samples}})^h $
#
# where $h$ is a scaling constant that depends on qPCR sensitivity

# %%
import math
#guess an appropriate pool size - this should later be optimized      
#pool_size = int(np.sqrt(patient_samples))

#the nubmer of pools is the number of tests - 
#let's try to make some gains and see how good the accuracy still is
max_pools = 384
min_pool_size = patient_samples/max_pools
print("minimum pool size for non-overlapping but complete sample coverage", min_pool_size)
pool_size = math.ceil(min_pool_size)*2
print("target size: ", pool_size)
for i in range(0, 100):
    if patient_samples%(pool_size+i) == 0:
        pool_size = pool_size+i
        print("final pool size considering even division of chapters ", pool_size)
        break

       
        
 

number_of_pools = 0

#initialize pools 
pools = []
for i in range(0, len(ids_grand_pool), pool_size):
    pools.append(list(ids_grand_pool[i:i+pool_size]))
print("first chapter of pools: ",len(pools))        
# combinatorial pool choice - try to maximize diversity
number_of_pools += len(pools)
chapter_size = len(pools)
chapter = 0
while number_of_pools < max_pools:
    for page in range(0,chapter_size):
        if number_of_pools >= max_pools: 
            break
        next_pool = []
        for item in range(0,pool_size):
            next_pool.append(pools[chapter_size*chapter+(page+item)%chapter_size][item])
        pools.append(next_pool)
        number_of_pools += 1
        
    chapter += 1

base_false_negative_rate = 0.1
false_negative_rate = base_false_negative_rate*(1 + number_of_pools/patient_samples)**2.4


print("number of pools: ", len(pools))    
print("pool size:", pool_size)
print("dilution-dependent false negative rate", false_negative_rate)
# Out:
# minimum pool size for non-overlapping but complete sample coverage 12.760416666666666
# target size:  26
# final pool size considering even division of chapters  28
# first chapter of pools:  175
# number of pools:  384
# pool size: 28
# dilution-dependent false negative rate 0.11985058256974526

# %%
#check the extent of overlap between our pools
check_intersections = np.zeros((max_pools,max_pools))
for i in range(0, max_pools):
    for j in range(0, max_pools):
        check_intersections[i,j] = len(list(set(pools[i]) & set(pools[j])))
        
plt.figure(figsize=(10,10))        
plt.imshow(check_intersections,cmap="hot")  
plt.xlabel("pool i [number of overlapping samples in pool]")
plt.ylabel("pool j [number of overlapping samples in pool]")
plt.show()
plt.close()

# %%
def run_test(samples, pool_dictionary):
    pool_result = 0
    false_positive = 0
    false_negative = 0
    for ID in samples:
        if pool_dictionary[ID] == 1:
            if random.random() < false_negative_rate:
                false_negative = 1
            else:
                pool_result = 1
        else:
            if random.random() < false_positive_rate:
                pool_result = 1 
                false_positive = 1
        if pool_result == 1 and false_negative == 1:
            false_negative = 0 #silent false negative since some other sample tested positive in the pool
    return pool_result, false_negative, false_positive


# conduct the tests now on each pool - sort them into negative and positive groups
positive_pools = []
negative_pools = []
for pool in pools:
    if run_test(pool, pool_dictionary)[0] == 1:
        positive_pools.append(list(pool))
    else:
        negative_pools.append(list(pool))        
        
flat_pos_pools = [val for sublist in positive_pools for val in sublist]
flat_neg_pools = [val for sublist in negative_pools for val in sublist]

# %%
# assess the accuracy by comparing with the dictionary of true positives
errors = 0
correctly_identified = 0
false_pos_errors = 0
false_neg_errors = 0
final_positives = list(set(flat_pos_pools) - set(flat_neg_pools))
for i in final_positives:
    if pool_dictionary[i] != 1:
        errors += 1
        false_pos_errors += 1
    else :
        correctly_identified += 1
for i in flat_neg_pools:
    if pool_dictionary[i] != 0:
        errors += 1
        false_neg_errors += 1
    else :
        correctly_identified += 1        
#print("errors/sample", errors/patient_samples)        
print("false pos/ neg sample", false_pos_errors/true_negatives)        
print("false neg/pos sample", false_neg_errors/true_positives)  
print("fold efficiency: ", patient_samples/number_of_pools,"samples/test")
print("coverage (redundancy):  pools*size / samples: ", (number_of_pools*pool_size)/patient_samples, "x")
print("correctly identified rate", correctly_identified/patient_samples, "correct results/sample")


sizes = [correctly_identified, false_pos_errors, false_neg_errors]
labels = ["correctly identified","false +","false -"]
explode = (0.1, 0.1 , 0)
plt.figure(figsize=(10,10))        
plt.pie(sizes, labels=labels, explode = explode,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
plt.close()
# Out:
# false pos/ neg sample 0.18281346829167527
# false neg/pos sample 0.2033898305084746
# fold efficiency:  12.760416666666666 samples/test
# coverage (redundancy):  pools*size / samples:  2.1942857142857144 x
# correctly identified rate 1.2014285714285715 correct results/sample

# %%
# show intersection between positive pools
max_pos_pools = len(positive_pools)
intersect_final = []
check_pos_intersections = np.zeros((max_pos_pools,max_pos_pools))
for i in range(0, max_pos_pools):
    for j in range(0, max_pos_pools):
        current_intersect = list(set(positive_pools[i]) & set(positive_pools[j]))
        check_pos_intersections[i,j] = len(current_intersect)
                
plt.imshow(check_pos_intersections,cmap="Greys_r")   
plt.show()
plt.close()
