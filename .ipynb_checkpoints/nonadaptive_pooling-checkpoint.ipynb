# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import uuid
from itertools import combinations
import string
### initialize test pool ###

plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.rcParams.update({'font.size': 25})


true_positive_rate = 0.1

global false_negative_rate
global false_positive_rate


false_positive_rate = 0.01
true_positive_rate = 0.01
patient_samples = int(np.sqrt(5329))**2


gtp_array = np.zeros((patient_samples),uuid.UUID)
small_codes = np.zeros((patient_samples),str)
grand_test_pool = np.zeros((patient_samples))
ids_grand_pool = np.zeros((patient_samples),uuid.UUID)
pool_dictionary = {}


true_positives = 0
positive_patients= []
# positive_patients = random.choices(range(0,patient_samples),k=int(true_positive_rate*patient_samples))
for i in range(0,patient_samples):
    ID = uuid.uuid4()
    ids_grand_pool[i] = ID
    gtp_array[i] = ID
    small_codes[i] = string.printable[(10+i)%100]
    if random.random() <= true_positive_rate:
        true_positives += 1
        grand_test_pool[i] = 1
        pool_dictionary[ID] =1
        positive_patients.append(i)
    else:
        pool_dictionary[ID] =0

plt.figure(figsize=(10,10))
plt.xlabel("sample i")
plt.ylabel("sample j")
plt.imshow(np.reshape(grand_test_pool,[int(np.sqrt(len(grand_test_pool))),int(np.sqrt(len(grand_test_pool)))]),cmap="Greys_r")
true_negatives = patient_samples - true_positives

print(small_codes)
print("false positive rate:", false_positive_rate)
print("true positive rate",true_positive_rate)
print("nubmer of patient samples",patient_samples)
# Out:
# ['a' 'b' 'c' ... 'A' 'B' 'C']
# false positive rate: 0.01
# true positive rate 0.01
# nubmer of patient samples 5329

# %% [markdown]
# # proposed penalty for dilution
# false negative probability of a single, undiluted sample : $p_-$
#
# corrected false negative after dilution:
#
# # $p_-^{diluted} = p_- (1 + \frac{m_{pools}}{n_{samples}})^h $
#
# where $h$ is a scaling constant that depends on qPCR sensitivity

# %%
import math
#guess an appropriate pool size - this should later be optimized      
#pool_size = int(np.sqrt(patient_samples))

#the nubmer of pools is the number of tests - 
#let's try to make some gains and see how good the accuracy still is
max_pools = 1000
# min_pool_size = patient_samples/max_pools
# print("minimum pool size for non-overlapping but complete sample coverage", min_pool_size)
# pool_size = math.ceil(min_pool_size)*5
# print("target size: ", pool_size)
# for i in range(0, 100):
#     if patient_samples%(pool_size+i) == 0:
#         pool_size = pool_size+i
#         print("final pool size considering even division of chapters ", pool_size)
#         break
pool_size = int(np.sqrt(patient_samples))
       
        
 

number_of_pools = 0

#initialize pools 
pools = []
pools_to_transpose = []
final_pools = []
small_code_pools = []
for i in range(0, len(ids_grand_pool), pool_size):
    pools.append(list(ids_grand_pool[i:i+pool_size]))
    small_code_pools.append( ''.join((small_codes[i:i+pool_size])))
    
    final_pools.append(list(ids_grand_pool[i:i+pool_size]))
    pools_to_transpose.append(list(ids_grand_pool[i:i+pool_size]))
    
for pool in list(np.array(pools_to_transpose).transpose()):
    final_pools.append(list(pool))   
print("first chapter size: ", len(pools))      
print("traposed chapter size: ", len(pools_to_transpose))      
# combinatorial pool choice - try to maximize diversity
number_of_pools += len(pools)
chapter_size = len(pools)
print("chapter_size: ",chapter_size)
print(max_pools)
chapter = 0
print(small_code_pools)
while number_of_pools < max_pools:
    for page in range(0,chapter_size):
        if number_of_pools >= max_pools: 
            break
        next_pool = []
        small_code_next_pool = ""
        for item in range(0,pool_size):
            next_pool.append(pools[chapter_size*chapter+(page+item)%chapter_size][item])
            small_code_next_pool += small_code_pools[chapter_size*chapter+(page+item)%chapter_size][item]
        print(chapter, page, item, small_code_next_pool)
        pools.append(next_pool)
        small_code_pools.append(small_code_next_pool)
        final_pools.append(next_pool)
        number_of_pools += 1
        
    chapter += 1
print("middle chapters of pools", len(final_pools))    
base_false_negative_rate = 0.01
false_negative_rate = base_false_negative_rate*(1 + number_of_pools/patient_samples)**0

# pools = final_pools

# for pool in list(np.array(pools_to_transpose).transpose()):
#     pools.append(list(pool))  
# print("last chapter of pools", len(pools))    


print("number of pools: ", len(pools))    
print("pool size:", pool_size)
print("dilution-dependent false negative rate", false_negative_rate)
# Out:
# first chapter size:  73
# traposed chapter size:  73
# chapter_size:  73
# 1000
# ['abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?', '@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRST', 'UVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrs', 'tuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c01', '23456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-', './:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKL', 'MNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijk', 'lmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~', ' \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%', "&'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCD", 'EFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abc', 'defghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\', ']^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVW', 'XYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuv', 'wxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c01234', '56789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:', ';<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNO', 'PQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmn', 'opqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n', '\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'(', ')*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFG', 'HIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdef', 'ghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_', '`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ', '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxy', 'zABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c01234567', '89abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=', '>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQR', 'STUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopq', 'rstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c', '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+', ',-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJ', 'KLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghi', 'jklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|', '}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#', "$%&'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzAB", 'CDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789a', 'bcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@', '[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTU', 'VWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrst', 'uvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c012', '3456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-.', '/:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLM', 'NOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijkl', 'mnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ ', '\t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&', "'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c0123456789abcdefghijklmnopqrstuvwxyzABCDE", 'FGHIJKLM ...
# 0 0 72 a[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#C
# *Jj~&Ff`"B?
# 0 2 72 Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!A>T
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz=Ss
# 0 4 72 2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy<Rr1
# *Jj~&Ff`"Bb\Xx;Qq0-
# 0 6 72 Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww:Pp,L
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv/Oo+Kk
# 0 8 72  'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# *Jj~
# *Jj~&Ff`"Bb\Xx7>Tt-Mm
# )Ii}%
# 0 10 72 Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss,Ll	(Hh|$D
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5<Rr+Kk 'Gg{#Cc
# 0 12 72 ]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq*Jj~&Ff`"Bb\
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp)Ii}%Ee_!Aa[W
# 0 14 72 w6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo(Hh|$Dd^Zz9@Vv
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5<Rr1.Nn'Gg{#Cc]Yy8?Uu4
# 0 16 72 ;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm&Ff`"Bb\Xx7>Tt3:
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll%Ee_!Aa[Ww6=Ss2/O
# 0 18 72 o+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk$Dd^Zz9@Vv5<Rr1.Nn
# *Jj#Cc]Yy8?Uu4;Qq0-Mm
#
# 0 20 72 )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii"Bb\Xx7>Tt3:Pp,Ll	(
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh!Aa[Ww6=Ss2/Oo+Kk 'G
# 0 22 72 g{#Cc]Yy8?Uu4;Qq0-Mm
# *Jj~&Ff
# *Jj~&FfYy8?Uu4;Qq0-Mm
# )Ii}%Ee_
# 0 24 72 !Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%EeXx7>Tt3:Pp,Ll	(Hh|$Dd^Z
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$DdWw6=Ss2/Oo+Kk 'Gg{#Cc]Yy
# 0 26 72 8?Uu4;Qq0-Mm
# *Jj~&Ff`"Bb\Xx7
# *Jj~&Ff`"BbUu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=
# 0 28 72 Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!AaTt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5<R
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq
# 0 30 72 0-Mm
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp
# *Jj~&Ff`"Bb\Xx7Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+
# 0 32 72 Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# *J
# 0 33 72 j~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|
# *Jj~&Ff`"Bb\Xx7>Tt3Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#
# 0 36 72 Cc]Yy8?Uu4;Qq0-Mm
# *Jj~&Ff`"B
# 0 37 72 b\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5<Rr1Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa
# 0 38 72 [Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@
# *Jj~&Ff`"Bb\Xx7>Tt3:PpIi}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?U
# 0 40 72 u4;Qq0-Mm
# *Jj~&Ff`"Bb\Xx7>Tt
# Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2
# 0 42 72 /Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5<Rr1.
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-M
# 0 44 72 m
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll
# *Jj~Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk
# 0 46 72 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# *Jj~&
# 0 47 72 Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%E
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd
# *Jj~&Ff`y8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]
# 0 50 72 Yy8?Uu4;Qq0-Mm
# *Jj~&Ff`"Bb\X
# 0 51 72 x7>Tt3:Pp,Ll	(Hh|$Dd^w6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5
# *Jj~&Ff`"Bb\u4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;
# 0 54 72 Qq0-Mm
# *Jj~&Ff`"Bb\Xx7>Tt3:P
# 0 55 72 p,Ll	(Hh|$Dd^Zz9@s2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5<Rr1.Nn
# 0 57 72 *Jj~&Ff`"Bb\Xx7>q0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(H
# 0 59 72 h|$Dd^Zz9@Vv5<o+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg
# *Jj~&Ff`
# 0 61 72 "Bb\Xx7>Tt3:m
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz
# 0 63 72 9@Vv5<Rr1.k 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8
# *Jj~&Ff`"Bb\Xx7>
# 0 65 72 Tt3:Pp,i}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=S
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$Dd^Zz9@Vv5<Rr
# *g{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0
# 0 68 72 -Mm
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,
# 0 69 72 Ll	(e_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+K
# *Jj
# 0 71 72 ~&c]Yy8?Uu4;Qq0-Mm
# )Ii}%Ee_!Aa[Ww6=Ss2/Oo+Kk 'Gg{#Cc]Yy8?Uu4;Qq0-Mm
# )Ii}
# *Jj~&Ff`"Bb\Xx7>Tt3:Pp,Ll	(Hh|$
# I|C\w<q,k&eZ8T2k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@u:o*i$
# I|C
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1j%dY7S1M	G`A@u:o*i$cX6R0L F_z?t/n)h#?
# I|C\w<q,k&eZ8T2N
# H{BT
# 1 4 72 2N
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cX6R0i$cX6R0L F_z?t/n)h#bW5QK~E^y>s.m(g">s
# I|C\w<qI|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`AS1
# 1 6 72 M	G`A@u:o*i$cX6R0L F_z?t/n)h#bW5Qh#bW5QK~E^y>s.m(g"aV4PJ}D]x=r-l'f!=r-
# I|C\w<q,k&eZ8T2N
# H{B[v;pH{B[v;p+j%dY7S1M	G`A@u:o*i$cX6R0L F_zR0L
# I|C\w<q,k&eZ<q,k
# 1 9 72 &eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@u:oG`A@u:o*i$cX6R0L F_z?t/n)h#bW5QK~E^yQK~
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY;p+j%
# 1 11 72 dY7S1M	G`A@u:o*i$cX6R0L F_z?t/nF_z?t/n)h#bW5QK~E^y>s.m(g"aV4PJ}D]xPJ}D
# I|C\w<q,k&eZ8T2N
# eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cX:o*i$c
# I|C\
# 1 14 72 w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	dY7S1M	G`A@u:o*i$cX6R0L F_z?t/n)h#bW/n)h#bW
# I|C\w<q,k&eZ8T2N
# H{B[vN
# H{B[v
# 1 16 72 ;p+j%dY7S1M	G`A@u:o*i$cX6R0L cX6R0L F_z?t/n)h#bW5QK~E^y>s.m(g"aV.m(g"aV4
# I|C\w<q,kC\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@uM	G`A@u:
# 1 18 72 o*i$cX6R0L F_z?t/n)h#bW5QK~bW5QK~E^y>s.m(g"aV4PJ}D]x=r-l'f!9U-l'f!9U3O
# I|C\w<q,k&eZ8T2N
# H{B[v;p+jB[v;p+j%dY7S1M	G`A@u:o*i$cX6R0L F_z?tL F_z?t/n
# I|C\w<q,k&eZ8T,k&eZ8T2N
#
# 1 21 72 H{B[v;p+j%dY7S1M	G`A@u:o*iA@u:o*i$cX6R0L F_z?t/n)h#bW5QK~E^y>sK~E^y>s.m(
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S+j%dY7S1M	G
# 1 23 72 `A@u:o*i$cX6R0L F_z?t/n)hz?t/n)h#bW5QK~E^y>s.m(g"aV4PJ}D]x=rJ}D]x=r-l'f
# I|C\w<q,k&eZ8T2N
# H{8T2N
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cX6R*i$cX6R0L F_
# I|C\w<qI|C\w<q,k&eZ
# 1 26 72 8T2N
# H{B[v;p+j%dY7S1M	G`7S1M	G`A@u:o*i$cX6R0L F_z?t/n)h#bW5Q)h#bW5QK~E^y
# I|C\w<q,k&eZ8T2N
# H{B[v;pH{B[v;p+j%dY7
# 1 28 72 S1M	G`A@u:o*i$cX6R0L F_6R0L F_z?t/n)h#bW5QK~E^y>s.m(g"aV4P(g"aV4PJ}D]x=
# I|C\w<q,k&ew<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@u:oG`A@u:o*i$cX6R
# I|C\w<q
# 1 31 72 ,k&eZ8T2N
# H{B[v;p+j%dv;p+j%dY7S1M	G`A@u:o*i$cX6R0L F_z?t/nF_z?t/n)h#bW5Q
# I|C\w<q,k&eZ8T2N&eZ8T2N
# H{B[v;p+
# 1 33 72 j%dY7S1M	G`A@u:o*i$cu:o*i$cX6R0L F_z?t/n)h#bW5QK~E^y>s.mE^y>s.m(g"aV4PJ
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M%dY7S1M	G`A@u:o*i
# I|
# 1 36 72 C\w<q,k&eZ8T2N
# H{B[2N
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cX6R0L$cX6R0L F_z?t/n)h#
# I|C\w<q,kC\w<q,k&eZ8T2N
# H{B
# 1 38 72 [v;p+j%dY7S1M	G`A@1M	G`A@u:o*i$cX6R0L F_z?t/n)h#bW5QK#bW5QK~E^y>s.m(g"a
# I|C\w<q,k&eZ8T2N
# H{B[v;p+jB[v;p+j%dY7S1M	G`A@
# 1 40 72 u:o*i$cX6R0L F_z?0L F_z?t/n)h#bW5QK~E^y>s.m(g"aV4PJ"aV4PJ}D]x=r-l'f!9U
# I|C\w<q,k&eZ8q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@u:o*iA@u:o*i$cX6R0L F_z?t
# I|C\w<q,k&eZ8T2
# 1 43 72 N
# H{B[v;p+j%dY7p+j%dY7S1M	G`A@u:o*i$cX6R0L F_z?t/n)hz?t/n)h#bW5QK~E^y>s.
# I|C\w<q,k&eZ8T2N
# HZ8T2N
# H{B[v;p+j%dY7S1M
# 1 45 72 	G`A@u:o*i$cX6o*i$cX6R0L F_z?t/n)h#bW5QK~E^y>s.m(gy>s.m(g"aV4PJ}D]x=r-l
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	GY7S1M	G`A@u:o*i$cX6R0L
# I|C\w<q,k&
# 1 48 72 eZ8T2N
# H{B[v;
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cX6R0L FX6R0L F_z?t/n)h#bW5QK~E
# I|C\w<q,k&ew<q,k&eZ8T2N
# H{B[v;p+j%d
# 1 50 72 Y7S1M	G`A@u:	G`A@u:o*i$cX6R0L F_z?t/n)h#bW5QK~EW5QK~E^y>s.m(g"aV4PJ}D]
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dv;p+j%dY7S1M	G`A@u:o*i$cX
# I|C\w
# 1 53 72 <q,k&eZ8T2k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cu:o*i$cX6R0L F_z?t/n)h#bW5
# I|C\w<q,k&eZ8T2N
# H{B[v;
# 1 55 72 p+j%dY7S1j%dY7S1M	G`A@u:o*i$cX6R0L F_z?t/n)h#bt/n)h#bW5QK~E^y>s.m(g"aV4P
# I|C\w<q,k&eZ8T2N
# H{BT2N
# H{B[v;p+j%dY7S1M	G`A@u:o
# 1 57 72 *i$cX6R0i$cX6R0L F_z?t/n)h#bW5QK~E^y>s.m(g"as.m(g"aV4PJ}D]x=r-l'f!9U3O
# 1 58 72 I|C\w<q,|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`AS1M	G`A@u:o*i$cX6R0L F_z?t/n)
# I|C\w<q,k&eZ8T2N
# H
# 1 60 72 {B[v;p+{B[v;p+j%dY7S1M	G`A@u:o*i$cX6R0L F_zR0L F_z?t/n)h#bW5QK~E^y>s.m(g
# I|C\w<q,k&eZ8q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`
# 1 62 72 A@u:o*`A@u:o*i$cX6R0L F_z?t/n)h#bW5QK~E^yQK~E^y>s.m(g"aV4PJ}D]x=r-l'f!
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7p+j%dY7S1M	G`A@u:o*i$cX6R0L F_z
# I|C\w<q,k&eZ8
# 1 65 72 T2N
# eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cX6o*i$cX6R0L F_z?t/n)h#bW5QK~E^y>
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S
# 1 67 72 1M	dY7S1M	G`A@u:o*i$cX6R0L F_z?t/n)h#bW5n)h#bW5QK~E^y>s.m(g"aV4PJ}D]x=r
# I|C\w<q,k&eZ8T2N
# H{B[vN
# H{B[v;p+j%dY7S1M	G`A@u:o*i$cX6R0
# I|C\w<q,
# 1 70 72 k&\w<q,k&eZ8T2N
# H{B[v;p+j%dY7S1M	G`A@uM	G`A@u:o*i$cX6R0L F_z?t/n)h#bW5QK
# I|C\w<q,k&eZ8T2N
# H{B[v;p+j
# 1 72 72 %[v;p+j%dY7S1M	G`A@u:o*i$cX6R0L F_z?tL F_z?t/n)h#bW5QK~E^y>s.m(g"aV4PJ}
# 2 0 72 auO){auO){auO){auO){auO){>1lFZ>1lFZ>1lFZ>1lFZ>1lFwQ+}cwQ+}cwQ+}cwQ+}cwQ+}
# 2 1 72 @3nH"@3nH"@3nH"@3nH"@3nHyS- eyS- eyS- eyS- eyS- e5pJ$\5pJ$\5pJ$\5pJ$\5pJ$
# 2 2 72 U/
# gAU/
# gAU/
# gAU/
# gAU/
# g7rL&^7rL&^7rL&^7rL&^7rL&W;iCW;iCW;iCW;iCW;iC
# 2 3 72 tN(`9tN(`9tN(`9tN(`9tN(`=0kEY=0kEY=0kEY=0kEY=0kEvP*|bvP*|bvP*|bvP*|bvP*|?
# 2 4 72 2mG!?2mG!?2mG!?2mG!?2mGxR,~dxR,~dxR,~dxR,~dxR,~d4oI#[4oI#[4oI#[4oI#[4oI#T
# hBs
# 2 6 72 M'_8sM'_8sM'_8sM'_8sM'_<jDX<jDX<jDX<jDX<jDuO){auO){auO){auO){auO){>1
# 2 7 72 lFZ>1lFZ>1lFZ>1lFZ>1lFwQ+}cwQ+}cwQ+}cwQ+}cwQ+}c3nH"@3nH"@3nH"@3nH"@3nH"S-
# 2 8 72  eyS- eyS- eyS- eyS- e5pJ$\5pJ$\5pJ$\5pJ$\5pJ$U/
# gAU/
# gAU/
# gAU/
# gAU/
# gArL
# 2 9 72 &^7rL&^7rL&^7rL&^7rL&^;iCW;iCW;iCW;iCW;iCtN(`9tN(`9tN(`9tN(`9tN(`=0k
# 2 10 72 EY=0kEY=0kEY=0kEY=0kEvP*|bvP*|bvP*|bvP*|bvP*|b2mG!?2mG!?2mG!?2mG!?2mG!R,~
# 2 11 72 dxR,~dxR,~dxR,~dxR,~d4oI#[4oI#[4oI#[4oI#[4oI#T.	fzT.	fzT.	fzT.	fzT.	fzqK%
# hBsM'_8sM'_8sM'_8sM'_8sM'_<jD
# 2 13 72 X<jDX<jDX<jDX<jDuO){auO){auO){auO){auO){a1lFZ>1lFZ>1lFZ>1lFZ>1lFZQ+}c
# 2 14 72 wQ+}cwQ+}cwQ+}cwQ+}c3nH"@3nH"@3nH"@3nH"@3nH"S- eyS- eyS- eyS- eyS- eypJ$\
# 2 15 72 5pJ$\5pJ$\5pJ$\5pJ$\/
# gAU/
# gAU/
# gAU/
# gAU/
# gArL&^7rL&^7rL&^7rL&^7rL&^;iCW
# 2 16 72 ;iCW;iCW;iCW;iCtN(`9tN(`9tN(`9tN(`9tN(`90kEY=0kEY=0kEY=0kEY=0kEYP*|bv
# 2 17 72 P*|bvP*|bvP*|bvP*|b2mG!?2mG!?2mG!?2mG!?2mG!R,~dxR,~dxR,~dxR,~dxR,~dxoI#[4
# hBV:
# hBsM'_8sM'_8sM'_8sM'_8sM'_8jDX<jDX<jDX<jDX<jDXO){auO
# 2 20 72 ){auO){auO){auO){a1lFZ>1lFZ>1lFZ>1lFZ>1lFZQ+}cwQ+}cwQ+}cwQ+}cwQ+}cwnH"@3n
# 2 21 72 H"@3nH"@3nH"@3nH"@- eyS- eyS- eyS- eyS- eypJ$\5pJ$\5pJ$\5pJ$\5pJ$\/
# gAU/
#
# 2 22 72 gAU/
# gAU/
# gAU/
# gArL&^7rL&^7rL&^7rL&^7rL&^7iCW;iCW;iCW;iCW;iCWN(`9tN(
# 2 23 72 `9tN(`9tN(`9tN(`90kEY=0kEY=0kEY=0kEY=0kEYP*|bvP*|bvP*|bvP*|bvP*|bvmG!?2mG
# 2 24 72 !?2mG!?2mG!?2mG!?,~dxR,~dxR,~dxR,~dxR,~dxoI#[4oI#[4oI#[4oI#[4oI#[.	fzT.	f
# hBVM'_8sM'_
# 2 26 72 8sM'_8sM'_8sM'_8jDX<jDX<jDX<jDX<jDXO){auO){auO){auO){auO){aulFZ>1lFZ
# 2 27 72 >1lFZ>1lFZ>1lFZ>+}cwQ+}cwQ+}cwQ+}cwQ+}cwnH"@3nH"@3nH"@3nH"@3nH"@- eyS- ey
# 2 28 72 S- eyS- eyS- eypJ$\5pJ$\5pJ$\5pJ$\5pJ$\5
# gAU/
# gAU/
# gAU/
# gAU/
# gAUL&^7rL&^7
# 2 29 72 rL&^7rL&^7rL&^7iCW;iCW;iCW;iCW;iCWN(`9tN(`9tN(`9tN(`9tN(`9tkEY=0kEY=
# 2 30 72 0kEY=0kEY=0kEY=*|bvP*|bvP*|bvP*|bvP*|bvmG!?2mG!?2mG!?2mG!?2mG!?,~dxR,~dxR
# 2 31 72 ,~dxR,~dxR,~dxoI#[4oI#[4oI#[4oI#[4oI#[4	fzT.	fzT.	fzT.	fzT.	fzTK%]6qK%]6q
# hBVM'_8sM'_8sM'_8sM'_8sM'_8sjDX<jDX<
# 2 33 72 jDX<jDX<jDX<){auO){auO){auO){auO){aulFZ>1lFZ>1lFZ>1lFZ>1lFZ>+}cwQ+}cwQ+
# 2 34 72 }cwQ+}cwQ+}cwnH"@3nH"@3nH"@3nH"@3nH"@3 eyS- eyS- eyS- eyS- eySJ$\5pJ$\5pJ
# 2 35 72 $\5pJ$\5pJ$\5
# gAU/
# gAU/
# gAU/
# gAU/
# gAUL&^7rL&^7rL&^7rL&^7rL&^7riCW;iCW;i
# 2 36 72 CW;iCW;iCW;(`9tN(`9tN(`9tN(`9tN(`9tkEY=0kEY=0kEY=0kEY=0kEY=*|bvP*|bvP*|
# 2 37 72 bvP*|bvP*|bvmG!?2mG!?2mG!?2mG!?2mG!?2~dxR,~dxR,~dxR,~dxR,~dxRI#[4oI#[4oI#
# hB
# hBV:'_8sM'_8sM'_8sM'_8sM'_8sjDX<jDX<jDX<jDX<jDX<){auO){auO){a
# 2 40 72 uO){auO){aulFZ>1lFZ>1lFZ>1lFZ>1lFZ>1}cwQ+}cwQ+}cwQ+}cwQ+}cwQH"@3nH"@3nH"@
# 2 41 72 3nH"@3nH"@3 eyS- eyS- eyS- eyS- eySJ$\5pJ$\5pJ$\5pJ$\5pJ$\5pgAU/
# gAU/
# gAU
# 2 42 72 /
# gAU/
# gAU/&^7rL&^7rL&^7rL&^7rL&^7riCW;iCW;iCW;iCW;iCW;(`9tN(`9tN(`9t
# 2 43 72 N(`9tN(`9tkEY=0kEY=0kEY=0kEY=0kEY=0|bvP*|bvP*|bvP*|bvP*|bvPG!?2mG!?2mG!?2
# 2 44 72 mG!?2mG!?2~dxR,~dxR,~dxR,~dxR,~dxRI#[4oI#[4oI#[4oI#[4oI#[4ofzT.	fzT.	fzT.
# hBV:'_8sM'_8sM'_8sM
# 2 46 72 '_8sM'_8sjDX<jDX<jDX<jDX<jDX<{auO){auO){auO){auO){auOFZ>1lFZ>1lFZ>1l
# 2 47 72 FZ>1lFZ>1}cwQ+}cwQ+}cwQ+}cwQ+}cwQH"@3nH"@3nH"@3nH"@3nH"@3neyS- eyS- eyS-
# 2 48 72 eyS- eyS-$\5pJ$\5pJ$\5pJ$\5pJ$\5pgAU/
# gAU/
# gAU/
# gAU/
# gAU/&^7rL&^7rL&^7rL&
# 2 49 72 ^7rL&^7riCW;iCW;iCW;iCW;iCW;`9tN(`9tN(`9tN(`9tN(`9tNEY=0kEY=0kEY=0kE
# 2 50 72 Y=0kEY=0|bvP*|bvP*|bvP*|bvP*|bvPG!?2mG!?2mG!?2mG!?2mG!?2mdxR,~dxR,~dxR,~d
# 2 51 72 xR,~dxR,#[4oI#[4oI#[4oI#[4oI#[4ofzT.	fzT.	fzT.	fzT.	fzT.%]6qK%]6qK%]6qK%]
# _8sM'_8sM'_8sM'_8sM'_8sMDX<jDX<jDX<jDX
# 2 53 72 <jDX<{auO){auO){auO){auO){auOFZ>1lFZ>1lFZ>1lFZ>1lFZ>1lcwQ+}cwQ+}cwQ+}cw
# 2 54 72 Q+}cwQ+"@3nH"@3nH"@3nH"@3nH"@3neyS- eyS- eyS- eyS- eyS-$\5pJ$\5pJ$\5pJ$\5
# 2 55 72 pJ$\5pgAU/
# gAU/
# gAU/
# gAU/
# gAU/
# ^7rL&^7rL&^7rL&^7rL&^7rLCW;iCW;iCW;iCW;
# 2 56 72 iCW;`9tN(`9tN(`9tN(`9tN(`9tNEY=0kEY=0kEY=0kEY=0kEY=0kbvP*|bvP*|bvP*|bvP
# 2 57 72 *|bvP*!?2mG!?2mG!?2mG!?2mG!?2mdxR,~dxR,~dxR,~dxR,~dxR,#[4oI#[4oI#[4oI#[4o
# hBV:
# _8sM'_8sM'_8sM'_8sM'_8sMDX<jDX<jDX<jDX<jDX<jauO){auO){auO){auO)
# 2 60 72 {auO)Z>1lFZ>1lFZ>1lFZ>1lFZ>1lcwQ+}cwQ+}cwQ+}cwQ+}cwQ+"@3nH"@3nH"@3nH"@3nH
# 2 61 72 "@3neyS- eyS- eyS- eyS- eyS- \5pJ$\5pJ$\5pJ$\5pJ$\5pJAU/
# gAU/
# gAU/
# gAU/
# g
# 2 62 72 AU/
# ^7rL&^7rL&^7rL&^7rL&^7rLCW;iCW;iCW;iCW;iCW;i9tN(`9tN(`9tN(`9tN(`
# 2 63 72 9tN(Y=0kEY=0kEY=0kEY=0kEY=0kbvP*|bvP*|bvP*|bvP*|bvP*!?2mG!?2mG!?2mG!?2mG!
# 2 64 72 ?2mdxR,~dxR,~dxR,~dxR,~dxR,~[4oI#[4oI#[4oI#[4oI#[4oIzT.	fzT.	fzT.	fzT.	fz
# h8sM'_8sM'_8sM'_8sM'_8
# 2 66 72 sM'X<jDX<jDX<jDX<jDX<jauO){auO){auO){auO){auO)Z>1lFZ>1lFZ>1lFZ>1lFZ>
# 2 67 72 1lcwQ+}cwQ+}cwQ+}cwQ+}cwQ+}@3nH"@3nH"@3nH"@3nH"@3nHyS- eyS- eyS- eyS- eyS
# 2 68 72 - \5pJ$\5pJ$\5pJ$\5pJ$\5pJAU/
# gAU/
# gAU/
# gAU/
# gAU/
# g7rL&^7rL&^7rL&^7rL&^7r
# 2 69 72 L&W;iCW;iCW;iCW;iCW;i9tN(`9tN(`9tN(`9tN(`9tN(Y=0kEY=0kEY=0kEY=0kEY=0
# 2 70 72 kbvP*|bvP*|bvP*|bvP*|bvP*|?2mG!?2mG!?2mG!?2mG!?2mGxR,~dxR,~dxR,~dxR,~dxR,
# 2 71 72 ~[4oI#[4oI#[4oI#[4oI#[4oIzT.	fzT.	fzT.	fzT.	fzT.	f6qK%]6qK%]6qK%]6qK%]6qK
# h8sM'_8sM'_8sM'_8sM'_8sM'X<jDX<jDX<jDX<jDX<j
# 3 0 72 a3
# `?.'ZSLExqjc5|[MFyrkd6}\;*#VOHAt~]<+$WPIBung92	_>-Cvoha3
# `?.'ZSLExqj
# 3 1 72 @/(!TMFyrkd6}\;*#sle70~]<+$WPIBung92%XQJCvoha3
# {@/(!TMFyrkd6}
# 3 2 72 UNGzsle70~]<+$WPIB1 ^=,%XQJCvoha3
# {@/(!TMFyrk[:)"UNGzsle70~]<+$
# {@/(!Tjc5|[:)"UNGzsle70#VOHAtmf81 ^=,%XQJC
# {@LExqjc5|[:)"UNGzs}\;*#VOHAtmf81 ^=,Bung92	_>-&YRKDwpi?
# 3 5 72 .'ZSLExqjc5|[:)"rkd6}\;*#VOHAtmf81$WPIBung92	_>-&YRKa3
# `?.'ZSLExqjc5|T
# 3 6 72 MFyrkd6}\;*#VOHA0~]<+$WPIBung92	_>JCvoha3
# `?.'ZSLExqj@/(!TMFyrkd6}\;*#s
# 3 7 72 le70~]<+$WPIBung9,%XQJCvoha3
# {@/(!TMFyrkd6"UNGzsle70~]<+$WPIB1
# 3 8 72  ^=,%XQJCvoha3
# {@/(!TMFyr|[:)"UNGzsle70~]<+Atmf81 ^=,%XQJCvoh>-
# {SL
# 3 10 72 Exqjc5|[:)"UNGz}\;*#VOHAtmf81 ^=IBung92	_>-&YRKDwpi?.'ZSLExqjc5|[:)"rk
# 3 11 72 d6}\;*#VOHAtmf8+$WPIBung92	_>-&YRha3
# `?.'ZSLExqjc5!TMFyrkd6}\;*#VOHA0~
# 3 12 72 ]<+$WPIBung92	_>JCvoha3
# `?.'ZSLExq{@/(!TMFyrkd6}\;*zsle70~]<+$WPIBung=,%
# 3 13 72 XQJCvoha3
# {@/(!TMFyrkd6"UNGzsle70~]<+$WPI81 ^=,%XQJCvoha3
# `RKD
# {@/(!qjc
# ZSLExqjc5|[:)"UNGz}\
# 3 16 72 ;*#VOHAtmf81 ^=IBung92	_>-&YRKDwp`?.'ZSLExqjc5|[:)yrkd6}\;*#VOHAtmf<+$W
# 3 17 72 PIBung92	_>-&Yoha3
# `?.'ZSLExqjc5!TMFyrkd6}\;*#VOH70~]<+$WPIBung92	_QJCv
# 3 18 72 oha3
# {@/(!TMFyrkd6}\;Gzsle70~]<+$WPIBung=,%XQJCvoha3
# `?.'Zpib4
# {@/(!TMFyrkd6)"UNGzsle70~]<+$WPf81 ^=,%XQJCvoha3
# {@/(!TMFy|[:
# {@/(xqjc5|[:)"UNGzsle;*#VO
# ZSLExqjc5|[:)"UNG6}\;*#VOHAtmf81 ^PIBun
# 3 22 72 g92	_>-&YRKDw
# `?.'ZSLExqjc5|[:Fyrkd6}\;*#VOHAtmf<+$WPIBung92	_>-&Yoha3
#
# 3 23 72 `?.'ZSLExqjc5(!TMFyrkd6}\;*#VOe70~]<+$WPIBung92	XQJCvoha3
# {@/(
# 3 24 72 !TMFyrkd6}\;Gzsle70~]<+$WPIBun^=,%XQJCvoha3
# {@/(!TMFyrkd:)"UNG
# 3 25 72 zsle70~]<+$Wmf81 ^=,%XQJCvoha3
# {@/(!TMF5|[:)"UNGzsle70~]OHAtmf
# {@/Exqjc5|[:)"UNGzsle;*#VOHAtmf81 ^=,%Xng92	_
# 3 27 72 >-&YRKDwpib4'ZSLExqjc5|[:)"UNd6}\;*#VOHAtmf81 WPIBung92	_>-&YRKDw
# `?.'Z
# 3 28 72 SLExqjc5|[:Fyrkd6}\;*#VOHAtm]<+$WPIBung92	_>-&voha3
# `?.'ZSLExqjc/(!TMFy
# 3 29 72 rkd6}\;*#Vle70~]<+$WPIBung92	XQJCvoha3
# {@/(!TMFyrkd6}\NGzsle7
# 3 30 72 0~]<+$WPIBu ^=,%XQJCvoha3
# {@/(!TMFyrkd:)"UNGzsle70~]<+$Wmf81 ^=
# {@/(!TMc5|[:)"UNGzsle70~VOHAtmf81 ^=,%XQJCv	_>-&YR
# {@/Exqjc5|[:)"UNGzsl\;*#VOHAtmf81 ^=,%ung92	_>-&YRKDwpib.'ZSLExq
# 3 33 72 jc5|[:)"Ukd6}\;*#VOHAtmf81 WPIBung92	_>-&YRKD3
# `?.'ZSLExqjc5|[MFyrkd6
# 3 34 72 }\;*#VOHAt~]<+$WPIBung92	_>-Cvoha3
# `?.'ZSLExqjc/(!TMFyrkd6}\;*#Vle70~]<+
# 3 35 72 $WPIBung92%XQJCvoha3
# {@/(!TMFyrkd6}UNGzsle70~]<+$WPIBu ^=,%XQJ
# 3 36 72 Cvoha3
# {@/(!TMFyrk[:)"UNGzsle70~]<+$tmf81 ^=,%XQJCvoha-&YRKDwpi
# {@LExqjc5|
# 3 38 72 [:)"UNGzs}\;*#VOHAtmf81 ^=,Bung92	_>-&YRKDwpib.'ZSLExqjc5|[:)"Ukd6}\;*#
# 3 39 72 VOHAtmf81$WPIBung92	_>-&YRKa3
# `?.'ZSLExqjc5|TMFyrkd6}\;*#VOHAt~]<+$WPIB
# 3 40 72 ung92	_>-Cvoha3
# `?.'ZSLExqj@/(!TMFyrkd6}\;*#sle70~]<+$WPIBung9,%XQJCvoha
# 3 41 72 3
# {@/(!TMFyrkd6}UNGzsle70~]<+$WPIB1 ^=,%XQJCvoha3
# {@
# {@/(!Tjc5|[:)"U
# {SLExqjc5|[:)"UNGzs}\;*#VOHAt
# 3 44 72 mf81 ^=,Bung92	_>-&YRKDwpi?.'ZSLExqjc5|[:)"rkd6}\;*#VOHAtmf8+$WPIBung92
# 3 45 72 	_>-&YRha3
# `?.'ZSLExqjc5|TMFyrkd6}\;*#VOHA0~]<+$WPIBung92	_>JCvoha3
# `?.
# 3 46 72 'ZSLExq{@/(!TMFyrkd6}\;*zsle70~]<+$WPIBung9,%XQJCvoha3
# {@/(!TM
# 3 47 72 Fyrkd6"UNGzsle70~]<+$WPI81 ^=,%XQJCvoha3
# {@/(!TMFyr|[:)"UNGzsl
# {@/(!qjc5|[:)"UNGzsle7*#VOHAtmf81
# {SLExqjc5|[:)"UNGz}\;*#VOHAtmf81 ^=IBung92	_>-&
# 3 50 72 YRKDwp`?.'ZSLExqjc5|[:)yrkd6}\;*#VOHAtmf8+$WPIBung92	_>-&YRha3
# `?.'ZSLE
# 3 51 72 xqjc5!TMFyrkd6}\;*#VOH70~]<+$WPIBung92	_QJCvoha3
# `?.'ZSLExq{@/(!TMFyrkd
# 3 52 72 6}\;*zsle70~]<+$WPIBung=,%XQJCvoha3
# {@/(!TMFyrkd6)"UNGzsle70~]
# 3 53 72 <+$WPf81 ^=,%XQJCvoha3
# {@/(!TMFy|[:)"UNGzsle70~]<HAtmf81 ^=,%X
# {@/(xqjc5|[:)"UNGzsle7*#VOHAtmf81 ^=,%XQg92	_>-&YRKDw
# ZSLExqjc5|[:)"UNG6}\;*#VOHAtmf81 ^PIBung92	_>-&YRKDwp`?.'ZSLExqjc5
# 3 56 72 |[:)yrkd6}\;*#VOHAtmf<+$WPIBung92	_>-&Yoha3
# `?.'ZSLExqjc5(!TMFyrkd6}\;
# 3 57 72 *#VOe70~]<+$WPIBung92	_QJCvoha3
# {@/(!TMFyrkd6}\;Gzsle70~]<+$WP
# 3 58 72 IBun^=,%XQJCvoha3
# {@/(!TMFyrkd6)"UNGzsle70~]<+$WPf81 ^=,%XQJCvo
# 3 59 72 ha3
# {@/(!TMF5|[:)"UNGzsle70~]OHAtmf81 ^=,%XQJCvo_>-&YRKDwpib4
# 3 60 72 {@/(xqjc5|[:)"UNGzsle;*#VOHAtmf81 ^=,%Xng92	_>-&YRKDwpib4'ZSLExqjc5|[:)
# 3 61 72 "UNd6}\;*#VOHAtmf81 ^PIBung92	_>-&YRKDw
# `?.'ZSLExqjc5|[:Fyrkd6}\;*#VOH
# 3 62 72 Atm]<+$WPIBung92	_>-&voha3
# `?.'ZSLExqjc5(!TMFyrkd6}\;*#VOe70~]<+$WPIBung
# 3 63 72 92	XQJCvoha3
# {@/(!TMFyrkd6}\NGzsle70~]<+$WPIBun^=,%XQJCvoha3
# `
# {@/(!
# {@/Exqjc5|[:)"UNGz
# 3 66 72 sl\;*#VOHAtmf81 ^=,%ung92	_>-&YRKDwpib4'ZSLExqjc5|[:)"UNd6}\;*#VOHAtmf8
# 3 67 72 1 WPIBung92	_>-&YRKD3
# `?.'ZSLExqjc5|[MFyrkd6}\;*#VOHAtm]<+$WPIBung92	_>
# 3 68 72 -&voha3
# `?.'ZSLExqjc/(!TMFyrkd6}\;*#Vle70~]<+$WPIBung92%XQJCvoha3
# `?.'ZS
# {@/(!TMFyrkd6}\NGzsle70~]<+$WPIBu ^=,%XQJCvoha3
# {@/(!TMFyr
# {@/(!TMc5|[:)"UNGzsle70
# {@LExqjc5|[:)"UNGzsl\;*#VOHAtmf81 ^=,
# 3 72 72 %ung92	_>-&YRKDwpib.'ZSLExqjc5|[:)"Ukd6}\;*#VOHAtmf81$WPIBung92	_>-&YRK
# "t	w#u
# !s Yq}Wo{r~Xp|Vn`Tl^Rj\P_Sk]Qi[Og?Me=K
# "0%w#u
# !s Yq}WoZr~Xp|Vn`Tl^Rj
# 4 2 72 Um_Sk]Qi[Og?Me=h@Nf>Ld<Jb:H9.c;Ia/G8-E6+C4)A,D5*B3(z1&x$v'y0%w#u
# !s Yq}
# 4 3 72 t	Zr~Xp|Vn`Tl^o{Um_Sk]Qi[Og?M\Ph@Nf>Ld<Jb:H9Kc;Ia/G8-E6+C4F7,D5*B3(z1&x$
# 4 4 72 2'y0%w#u
# "t	Zr~Xp|Vn`TlWo{Um_Sk]Qi[OgRj\Ph@Nf>Ld<Jb:e=Kc;Ia/G8-E6+C
# 4 5 72 .F7,D5*B3(z1&x)A2'y0%w#u
# "t	Zr~Xp|Vn`q}Wo{Um_Sk]Qi[O^Rj\Ph@Nf>Ld<J?
# 4 6 72 Me=Kc;Ia/G8-E6H9.F7,D5*B3(z1C4)A2'y0%w#u
# "t	Zr~Xp|VnYq}Wo{Um_Sk]QiT
# "t	Zr~Xp|s
# 4 8 72  Yq}Wo{Um_Sk]n`Tl^Rj\Ph@Nf>L[Og?Me=Kc;Ia/G8Jb:H9.F7,D5*B3E6+C4)A2'y0%w#1
# "t	Zr~X
# !s Yq}Wo{Um_SkVn`Tl^Rj\Ph@NfQi[Og?Me=Kc;Ia/d<Jb:H9.F7,D5*B-
# "t	Zr~u
# !s Yq}Wo{Um_p|Vn`Tl^Rj\Ph@N]Qi[Og?Me=Kc;I>L
# "t	Z#u
# !s Yq}Wo{UmXp|Vn`Tl^Rj\PhSk
# "t%w#u
# !s Yq}Wo{r~
# "0%
# 4 14 72 w#u
# !s Yq}W	Zr~Xp|Vn`Tl^RjUm_Sk]Qi[Og?MePh@Nf>Ld<Jb:H9.c;Ia/G8-E6+C4)A,D
# 4 15 72 5*B3(z1&x$v'y0%w#u
# !s Yq}t	Zr~Xp|Vn`Tl^o{Um_Sk]Qi[Og?M\Ph@Nf>Ld<Jb:H=Kc
# 4 16 72 ;Ia/G8-E6+C4F7,D5*B3(z1&xA2'y0%w#u
# "t	Zr~Xp|Vn`TlWo{Um_Sk]Qi[OgRj\
# 4 17 72 Ph@Nf>Ld<Jb:e=Kc;Ia/G8-E6+9.F7,D5*B3(z1&x)A2'y0%w#u
# "t	Zr~Xp|Vn`q}W
# 4 18 72 o{Um_Sk]Qi[l^Rj\Ph@Nf>Ld<J?Me=Kc;Ia/G8-E6H9.F7,D5*B3(z1C4)A2'y0%w#u
# !$v
# "t	Zr~Xp|V Yq}Wo{Um_Sk]QiTl^Rj\Ph@Nf>LdOg?Me=Kc;Ia/G8-b:H9.F7,D5*B3(z+C4
# "t	Zr~Xp|s Yq}Wo{Um_Sk]n`Tl^Rj\Ph@Nf>L[Og?Me=Kc;Ia/G<Jb:
# "t	Zr~X
# !s Yq}Wo{Um_SkVn`Tl^Rj\Ph@NfQi[O
# "t	Zr#u
# !s Yq}Wo{Um_p|Vn
# "t	Z#u
#
# 4 24 72 !s Yq}Wo{U~Xp|Vn`Tl^Rj\PhSk]Qi[Og?Me=KcNf>Ld<Jb:H9.F7,a/G8-E6+C4)A2'y*B3(
# "t%w#u
# !s Yq}Wo{r~Xp|Vn`Tl^Rj\m_Sk]Qi[Og?Me=K@Nf>Ld<Jb:H9.F;Ia/G
# y0%w#u
# !s Yq}W	Zr~Xp|Vn`Tl^RjUm_Sk]Qi[Og?MePh@Nf
# 4 27 72 >Ld<Jb:H9.c;Ia/G8-E6+C4)7,D5*B3(z1&x$v'y0%w#u
# !s Yq"t	Zr~Xp|Vn`Tl^o{Um_
# 4 28 72 Sk]Qi[Og?j\Ph@Nf>Ld<Jb:H=Kc;Ia/G8-E6+C4F7,D5*B3(z1&xA2'y0%w#u
# "t	Z
# 4 29 72 r~Xp|Vn`T}Wo{Um_Sk]Qi[OgRj\Ph@Nf>Ld<JbMe=Kc;Ia/G8-E6+9.F7,D5*B3(z1&x)A2'y
# 4 30 72 0%w#u
# "t	Zr~Xp|Vn`q}Wo{Um_Sk]Qi[l^Rj\Ph@Nf>Ld<J?Me=Kc;Ia/G8-E:H9.F7
# 4 31 72 ,D5*B3(z1C4)A2'y0%w#u
# "t	Zr~Xp|V Yq}Wo{Um_Sk]QiTl^Rj\Ph@Nf>LdOg?Me=
# "t	Zr~Xp!s Yq}Wo{Um_Sk]n`Tl^R
# "t	Zr~X
# !s Yq
# 4 34 72 }Wo{Um_S|Vn`Tl^Rj\Ph@NfQi[Og?Me=Kc;IaLd<Jb:H9.F7,D5*8-E6+C4)A2'y0%w(z1&x
# "t	Zr#u
# !s Yq}Wo{Um_p|Vn`Tl^Rj\Ph@k]Qi[Og?Me=Kc;I>Ld<Jb:H9.F7,D/G8-E6+
# "t	w#u
# !s Yq}Wo{U~Xp|Vn`Tl^Rj\PhSk]Qi[Og?Me=KcNf>Ld<J
# "t%w#u
# !s Yq}WoZr~Xp|Vn`Tl^Rj\m_Sk]Qi
# y0%w#u
# !s Yq}W	Zr~Xp|
# 4 39 72 Vn`Tl^R{Um_Sk]Qi[Og?MePh@Nf>Ld<Jb:H9Kc;Ia/G8-E6+C4)7,D5*B3(z1&x$v'y0%w#
# 4 40 72 u
# !s Yq"t	Zr~Xp|Vn`Tl^o{Um_Sk]Qi[Og?j\Ph@Nf>Ld<Jb:H=Kc;Ia/G8-E6+C.F7,D5*B
# 4 41 72 3(z1&xA2'y0%w#u
# "t	Zr~Xp|Vn`T}Wo{Um_Sk]Qi[OgRj\Ph@Nf>Ld<JbMe=Kc;Ia
# 4 42 72 /G8-E6+9.F7,D5*B3(z1&4)A2'y0%w#u
# "t	Zr~Xp|VnYq}Wo{Um_Sk]Qi[l^Rj\Ph@
# 4 43 72 Nf>Ld<g?Me=Kc;Ia/G8-E:H9.F7,D5*B3(z1C4)A2'y0%w#u
# "t	Zr~Xp|V Yq}Wo{U
# "t
# 4 45 72 	Zr~Xp!s Yq}Wo{Um_Sk]n`Tl^Rj\Ph@Nf>i[Og?Me=Kc;Ia/G<Jb:H9.F7,D5*B-E6+C4)A2
# "t	Zr~u
# !s Yq}Wo{Um_S|Vn`Tl^Rj\Ph@NfQi[Og?Me=Kc;IaLd<Jb:H9.
# "t	Zr#u
# !s Yq}Wo{UmXp|Vn`Tl^Rj\Ph@k]Qi[Og?M
# "t	w#u
# !s Yq}Wo{U~Xp|Vn`Tl
# "t%w#u
# !s
# 4 50 72 Yq}WoZr~Xp|Vn`Tl^Rj\m_Sk]Qi[Og?Me=h@Nf>Ld<Jb:H9.F;Ia/G8-E6+C4)A,D5*B3(z1&
# y0%w#u
# !s Yq}t	Zr~Xp|Vn`Tl^R{Um_Sk]Qi[Og?MePh@Nf>Ld<Jb:H9Kc;Ia/G8-E
# 4 52 72 6+C4)7,D5*B3(z1&x$2'y0%w#u
# !s Yq"t	Zr~Xp|Vn`TlWo{Um_Sk]Qi[Og?j\Ph@Nf>Ld
# 4 53 72 <Jb:e=Kc;Ia/G8-E6+C.F7,D5*B3(z1&xA2'y0%w#u
# "t	Zr~Xp|Vn`T}Wo{Um_Sk]
# 4 54 72 Qi[O^Rj\Ph@Nf>Ld<JbMe=Kc;Ia/G8-E6H9.F7,D5*B3(z1&4)A2'y0%w#u
# "t	Zr~X
# 4 55 72 p|VnYq}Wo{Um_Sk]Qi[l^Rj\Ph@Nf>Ld<g?Me=Kc;Ia/G8-E:H9.F7,D5*B3(z+C4)A2'y0%w
# 4 56 72 #u
# "t	Zr~Xp|s Yq}Wo{Um_Sk]Q`Tl^Rj\Ph@Nf>LdOg?Me=Kc;Ia/G8Jb:H9.F7,D5
# "t	Zr~Xp!s Yq}Wo{Um_SkVn`Tl^Rj\Ph@Nf>i[Og?Me=Kc;
# "t	Zr~u
# !s Yq}Wo{Um_S|Vn`Tl^Rj\P
# "t	Zr#u
# !s Yq}Wo
# 4 60 72 {UmXp|Vn`Tl^Rj\Ph@k]Qi[Og?Me=Kc;f>Ld<Jb:H9.F7,D/G8-E6+C4)A2'y*B3(z1&x$v
# 4 61 72 "t	w#u
# !s Yq}Wo{r~Xp|Vn`Tl^Rj\P_Sk]Qi[Og?Me=KcNf>Ld<Jb:H9.F7Ia/G8-E6+C4)
# "0%w#u
# !s Yq}WoZr~Xp|Vn`Tl^RjUm_Sk]Qi[Og?Me=h@Nf>Ld<Jb:H
# y0%w#u
# !s Yq}t	Zr~Xp|Vn`Tl^R{Um_Sk]Qi[Og
# 4 64 72 ?M\Ph@Nf>Ld<Jb:H9Kc;Ia/G8-E6+C4F7,D5*B3(z1&x$2'y0%w#u
# !s Yq"t	Zr~Xp|Vn`
# 4 65 72 TlWo{Um_Sk]Qi[Og?j\Ph@Nf>Ld<Jb:e=Kc;Ia/G8-E6+C.F7,D5*B3(z1&x)A2'y0%w#u
# !
# "t	Zr~Xp|Vn`q}Wo{Um_Sk]Qi[O^Rj\Ph@Nf>Ld<JbMe=Kc;Ia/G8-E6H9.F7,D5*B3(z
# 4 67 72 1&4)A2'y0%w#u
# "t	Zr~Xp|VnYq}Wo{Um_Sk]QiTl^Rj\Ph@Nf>Ld<g?Me=Kc;Ia/G8
# 4 68 72 -b:H9.F7,D5*B3(z+C4)A2'y0%w#u
# "t	Zr~Xp|s Yq}Wo{Um_Sk]Q`Tl^Rj\Ph@Nf>
# "t	Zr~Xp!s Yq}Wo{Um_S
# "t	Zr
# 4 71 72 ~u
# !s Yq}Wo{Um_p|Vn`Tl^Rj\Ph@N]Qi[Og?Me=Kc;IaLd<Jb:H9.F7,D5G8-E6+C4)A2'y0
# "t	Z#u
# !s Yq}Wo{UmXp|Vn`Tl^Rj\PhSk]Qi[Og?Me=Kc;f>Ld<Jb:H9.F7,
# 5 0 72 aN_r%5I@mZ0D;_r%5I@mZ0D;hr%5I@mZ0D;hU%5I@mZ0D;hU	5I@mZ0D;hU	yI@mZ0D;hU	y,
# 5 1 72 @mZ0D;hU	y,cmZ0D;hU	y,cP{0D;hU	y,cP{tD;hU	y,cP{t';hU	y,cP{t'7hU	y,cP{t'7K
# 5 2 72 U	y,cP{t'7K\	y,cP{t'7K\oy,cP{t'7K\o"2cP{t'7K\o"2FP{t'7K\o"2F={t'7K\o"2F=j
# A.eR}
# A.eR}v)9M^qA.eR}v)9M^q$
# 5 5 72 .eR}v)9M^q$4eR}v)9M^q$4HR}v)9M^q$4H?}v)9M^q$4H?lv)9M^q$4H?lY)9M^q$4H?lYC
# 5 6 72 M^q$4H?lYC:^q$4H?lYC:gq$4H?lYC:gT$4H?lYC:gT 4H?lYC:gT xH?lYC:gT x+?
# 5 7 72 lYC:gT x+blYC:gT x+bO`C:gT x+bO`sC:gT x+bO`s&:gT x+bO`s&6gT x+bO`s&6JT
# 5 8 72  x+bO`s&6J[ x+bO`s&6J[nx+bO`s&6J[n!1bO`s&6J[n!1EO`s&6J[n!1E<`s&6J[n!1E<is
# 5 9 72 &6J[n!1E<iV&6J[n!1E<iV
# 6J[n!1E<iV
# zJ[n!1E<iV
# z-dn!1E<iV
# z-dQ!1E<iV
# z-dQ|1
# 5 10 72 E<iV
# z-dQ|uE<iV
# z-dQ|u(<iV
# z-dQ|u(8iV
# z-dQ|u(8LV
# z-dQ|u(8L]pz-dQ|u(8L]p#-
# 5 11 72 dQ|u(8L]p#3dQ|u(8L]p#3GQ|u(8L]p#3G>|u(8L]p#3G>ku(8L]p#3G>kX(8L]p#3G>kXBL
# 5 12 72 ]p#3G>kXB/]p#3G>kXB/fp#3G>kXB/fS#3G>kXB/fS~3G>kXB/fS~wG>kXB/fS~w*>k
# 5 13 72 XB/fS~w*akXB/fS~w*aN_B/fS~w*aN_rB/fS~w*aN_r%/fS~w*aN_r%5fS~w*aN_r%5IS~
# 5 14 72 w*aN_r%5I@~w*aN_r%5I@mw*aN_r%5I@mZ0aN_r%5I@mZ0DN_r%5I@mZ0D;_r%5I@mZ0D;hr%
# 5 15 72 5I@mZ0D;hU%5I@mZ0D;hU	5I@mZ0D;hU	yI@mZ0D;hU	y,cmZ0D;hU	y,cPZ0D;hU	y,cP{0D
# 5 16 72 ;hU	y,cP{tD;hU	y,cP{t';hU	y,cP{t'7hU	y,cP{t'7KU	y,cP{t'7K\oy,cP{t'7K\o",c
# AK\
# A.eR}v)=jW
# A.eR}v)9M^qA.eR}v)9M^q$.eR}v)9M^q$4eR}v)9M^q$4HR}v
# 5 20 72 )9M^q$4H?}v)9M^q$4H?lv)9M^q$4H?lY9M^q$4H?lYCM^q$4H?lYC:^q$4H?lYC:gq$4
# 5 21 72 H?lYC:gT$4H?lYC:gT 4H?lYC:gT xH?lYC:gT x+blYC:gT x+bOYC:gT x+bO`C:
# 5 22 72 gT x+bO`sC:gT x+bO`s&:gT x+bO`s&6gT x+bO`s&6JT x+bO`s&6J[nx+bO`s&6J[n!+bO
# 5 23 72 `s&6J[n!1bO`s&6J[n!1EO`s&6J[n!1E<`s&6J[n!1E<is&6J[n!1E<iV&6J[n!1E<iV
# zJ[n
# 5 24 72 !1E<iV
# z-[n!1E<iV
# z-dn!1E<iV
# z-dQ!1E<iV
# z-dQ|1E<iV
# z-dQ|uE<iV
# z-dQ|u(<iV
#
# 5 25 72 z-dQ|u(8iV
# z-dQ|u(8L]
# z-dQ|u(8L]pz-dQ|u(8L]p#-dQ|u(8L]p#3dQ|u(8L]p#3GQ|u(
# 5 26 72 8L]p#3G>|u(8L]p#3G>ku(8L]p#3G>kX8L]p#3G>kXBL]p#3G>kXB/]p#3G>kXB/fp#3G
# 5 27 72 >kXB/fS#3G>kXB/fS~3G>kXB/fS~wG>kXB/fS~w*akXB/fS~w*aNXB/fS~w*aN_B/f
# 5 28 72 S~w*aN_rB/fS~w*aN_r%/fS~w*aN_r%5fS~w*aN_r%5IS~w*aN_r%5I@mw*aN_r%5I@mZ*aN_
# 5 29 72 r%5I@mZ0aN_r%5I@mZ0DN_r%5I@mZ0D;_r%5I@mZ0D;hr%5I@mZ0D;hU%5I@mZ0D;hU	yI@mZ
# 5 30 72 0D;hU	y,@mZ0D;hU	y,cmZ0D;hU	y,cPZ0D;hU	y,cP{0D;hU	y,cP{tD;hU	y,cP{t';hU	y
# 5 31 72 ,cP{t'7hU	y,cP{t'7K\	y,cP{t'7K\oy,cP{t'7K\o",cP{t'7K\o"2cP{t'7K\o"2FP{t'7
# A.eo"2F=
# A.eR
# 5 34 72 }v)9M^qA.eR}v)9M^q$.eR}v)9M^q$4eR}v)9M^q$4HR}v)9M^q$4H?lv)9M^q$4H?lY)9M^q
# 5 35 72 $4H?lY9M^q$4H?lYCM^q$4H?lYC:^q$4H?lYC:gq$4H?lYC:gT$4H?lYC:gT xH?lY
# 5 36 72 C:gT x+?lYC:gT x+blYC:gT x+bOYC:gT x+bO`C:gT x+bO`sC:gT x+bO`s&:gT x+
# 5 37 72 bO`s&6gT x+bO`s&6J[ x+bO`s&6J[nx+bO`s&6J[n!+bO`s&6J[n!1bO`s&6J[n!1EO`s&6J
# 5 38 72 [n!1E<`s&6J[n!1E<is&6J[n!1E<iV
# 6J[n!1E<iV
# zJ[n!1E<iV
# z-[n!1E<iV
# z-dn!1E<i
# 5 39 72 V
# z-dQ!1E<iV
# z-dQ|1E<iV
# z-dQ|uE<iV
# z-dQ|u(8iV
# z-dQ|u(8LV
# z-dQ|u(8L]
# z-dQ|
# 5 40 72 u(8L]pz-dQ|u(8L]p#-dQ|u(8L]p#3dQ|u(8L]p#3GQ|u(8L]p#3G>ku(8L]p#3G>kX(8L]p#
# 5 41 72 3G>kX8L]p#3G>kXBL]p#3G>kXB/]p#3G>kXB/fp#3G>kXB/fS#3G>kXB/fS~wG>kXB
# 5 42 72 /fS~w*>kXB/fS~w*akXB/fS~w*aNXB/fS~w*aN_B/fS~w*aN_rB/fS~w*aN_r%/fS~w*a
# 5 43 72 N_r%5fS~w*aN_r%5I@~w*aN_r%5I@mw*aN_r%5I@mZ*aN_r%5I@mZ0aN_r%5I@mZ0DN_r%5I@
# 5 44 72 mZ0D;_r%5I@mZ0D;hr%5I@mZ0D;hU	5I@mZ0D;hU	yI@mZ0D;hU	y,@mZ0D;hU	y,cmZ0D;hU
# 5 45 72 	y,cPZ0D;hU	y,cP{0D;hU	y,cP{tD;hU	y,cP{t'7hU	y,cP{t'7KU	y,cP{t'7K\	y,cP{t
# 5 46 72 '7K\oy,cP{t'7K\o",cP{t'7K\o"2cP{t'7K\o"2FP{t'7K\o"2F=jt'7K\o"2F=jW'7K\o"2
# A.
# A.eR}v)9M^qA.eR}v)9M^q$.eR}v)9M
# 5 49 72 ^q$4eR}v)9M^q$4H?}v)9M^q$4H?lv)9M^q$4H?lY)9M^q$4H?lY9M^q$4H?lYCM^q$4H?l
# 5 50 72 YC:^q$4H?lYC:gq$4H?lYC:gT 4H?lYC:gT xH?lYC:gT x+?lYC:gT x+blYC:gT
# 5 51 72 x+bOYC:gT x+bO`C:gT x+bO`sC:gT x+bO`s&6gT x+bO`s&6JT x+bO`s&6J[ x+bO`s&
# 5 52 72 6J[nx+bO`s&6J[n!+bO`s&6J[n!1bO`s&6J[n!1EO`s&6J[n!1E<is&6J[n!1E<iV&6J[n!1E
# 5 53 72 <iV
# 6J[n!1E<iV
# zJ[n!1E<iV
# z-[n!1E<iV
# z-dn!1E<iV
# z-dQ!1E<iV
# z-dQ|uE<iV
# z-d
# 5 54 72 Q|u(<iV
# z-dQ|u(8iV
# z-dQ|u(8LV
# z-dQ|u(8L]
# z-dQ|u(8L]pz-dQ|u(8L]p#-dQ|u(8L]
# 5 55 72 p#3dQ|u(8L]p#3G>|u(8L]p#3G>ku(8L]p#3G>kX(8L]p#3G>kX8L]p#3G>kXBL]p#3G>kX
# 5 56 72 B/]p#3G>kXB/fp#3G>kXB/fS~3G>kXB/fS~wG>kXB/fS~w*>kXB/fS~w*akXB/fS~w
# 5 57 72 *aNXB/fS~w*aN_B/fS~w*aN_rB/fS~w*aN_r%5fS~w*aN_r%5IS~w*aN_r%5I@~w*aN_r%5
# 5 58 72 I@mw*aN_r%5I@mZ*aN_r%5I@mZ0aN_r%5I@mZ0DN_r%5I@mZ0D;hr%5I@mZ0D;hU%5I@mZ0D;
# 5 59 72 hU	5I@mZ0D;hU	yI@mZ0D;hU	y,@mZ0D;hU	y,cmZ0D;hU	y,cPZ0D;hU	y,cP{tD;hU	y,cP
# 5 60 72 {t';hU	y,cP{t'7hU	y,cP{t'7KU	y,cP{t'7K\	y,cP{t'7K\oy,cP{t'7K\o",cP{t'7K\o
# AK\o"2F=jW
# A.eR}v)
# A.eR}v)9M^qA.eR}v)9M^q$4eR}v)9M^q$4HR}v)9M^q$4H?}v)9M^q$4H
# 5 64 72 ?lv)9M^q$4H?lY)9M^q$4H?lY9M^q$4H?lYCM^q$4H?lYC:gq$4H?lYC:gT$4H?lYC:g
# 5 65 72 T 4H?lYC:gT xH?lYC:gT x+?lYC:gT x+blYC:gT x+bOYC:gT x+bO`sC:gT x+bO`
# 5 66 72 s&:gT x+bO`s&6gT x+bO`s&6JT x+bO`s&6J[ x+bO`s&6J[nx+bO`s&6J[n!+bO`s&6J[n!
# 5 67 72 1bO`s&6J[n!1E<`s&6J[n!1E<is&6J[n!1E<iV&6J[n!1E<iV
# 6J[n!1E<iV
# zJ[n!1E<iV
# z
# 5 68 72 -[n!1E<iV
# z-dn!1E<iV
# z-dQ|1E<iV
# z-dQ|uE<iV
# z-dQ|u(<iV
# z-dQ|u(8iV
# z-dQ|u(8
# 5 69 72 LV
# z-dQ|u(8L]
# z-dQ|u(8L]pz-dQ|u(8L]p#3dQ|u(8L]p#3GQ|u(8L]p#3G>|u(8L]p#3G>
# 5 70 72 ku(8L]p#3G>kX(8L]p#3G>kX8L]p#3G>kXBL]p#3G>kXB/fp#3G>kXB/fS#3G>kXB/fS
# 5 71 72 ~3G>kXB/fS~wG>kXB/fS~w*>kXB/fS~w*akXB/fS~w*aNXB/fS~w*aN_rB/fS~w*aN_r
# 5 72 72 %/fS~w*aN_r%5fS~w*aN_r%5IS~w*aN_r%5I@~w*aN_r%5I@mw*aN_r%5I@mZ*aN_r%5I@mZ0
# 9}4gsEQ#/_0
# =}4gsEQ#/_*@	7jvHT&<!-]amyKW)?$:`1dpBNZ,
# 6 2 72 U'=}4gsEQ#/X*@	7jvHT&O!-]amyKWFR$:`1dpBNZIU'=}4gsEQzLX*@	7jvHTCO!-]amyK
# 6 3 72 tFR$:`1dpBkwIU'=}4gsEnzLX*@	7jveqCO!-]amyhtFR$:`1dp8kwIU'=}4gsbnzLX*@	7j
# 6 4 72 2eqCO!-]a~5htFR$:`1d
# 8kwIU'=}4^bnzLX*@	7{2eqCO!-]>~5htFR$:`+[
# 8kwIU'=}
# 6 5 72 .^bnzLX*@%;{2eqCO!-](>~5htFR$:Y+[
# 8kwIU'P".^bnzLX*S%;{2eqCO!JV(>~5htFR$
# 6 6 72 MY+[
# 8kwIUDP".^bnzLuGS%;{2eqCOxJV(>~5htFoAMY+[
# 8kwIrDP".^bnziuGS%;{2eqC
# 6 7 72 lxJV(>~5htcoAMY+[
# 9lxJV(>~5h0coAMY+[
# 8|3frDP".^?
# 9lxJV(>~/_0coAMY+[
# 9lxJV(>#/_0coAMY+T
# 9lxJs
# 9lxgsEQ#/_0co7jvHT&<|3framyKW)? 6i1
# =}4gsEQ#/_*@	7jvHT&<|-
# 6 12 72 ]amyKW)?$:`1dpBNZ,\'=}4gsEQ#/X*@	7jvHT&O!-]amyKW)R$:`1dpBNZIU'=}4gsEQ#L
# 6 13 72 X*@	7jvHTCO!-]amyKtFR$:`1dpBNwIU'=}4gsEnzLX*@	7jvHqCO!-]amyhtFR$:`1dpBk
# 6 14 72 wIU'=}4gsbnzLX*@	7j2eqCO!-]am5htFR$:`1d
# 8kwIU'=}4gbnzLX*@	7{2eqCO!-]>~
# 6 15 72 5htFR$:`1[
# 8kwIU'=}.^bnzLX*@	;{2eqCO!-](>~5htFR$:Y+[
# 8kwIU'=".^bnzLX*S%
# 6 16 72 ;{2eqCO!-V(>~5htFR$MY+[
# 8kwIUDP".^bnzLXGS%;{2eqCOxJV(>~5htFRAMY+[
# 8kwIrD
# 6 17 72 P".^bnziuGS%;{2eqClxJV(>~5htcoAMY+[
# 8kwfrDP".^bn6iuGS%;{2eq9lxJV(>~5h0c
# 6 18 72 oAMY+[
# 9lxJV(>~5_0coAMY+[
# <|3frDP".^)? 6iuGS%;{,\
# 9lxJV(Q#/_0coAMYHT&<|3frDP"KW
# 9lxgsEQ#/_0coAjv
# =}4
# 6 22 72 gsEQ#/_0@	7jvHT&<|-]amyKW)? :`1dpBNZ,\'=}4gsEQ#/X*@	7jvHT&<!-]amyKW)R$:
# 6 23 72 `1dpBNZ,U'=}4gsEQ#LX*@	7jvHTCO!-]amyKWFR$:`1dpBNwIU'=}4gsEQzLX*@	7jvHqCO
# 6 24 72 !-]amyhtFR$:`1dpBkwIU'=}4gsbnzLX*@	7jveqCO!-]am5htFR$:`1dp8kwIU'=}4gbn
# 6 25 72 zLX*@	7{2eqCO!-]a~5htFR$:`1[
# 8kwIU'=}4^bnzLX*@	;{2eqCO!-](>~5htFR$:`+[
#
# 6 26 72 8kwIU'=".^bnzLX*@%;{2eqCO!-V(>~5htFR$MY+[
# 8kwIU'P".^bnzLXGS%;{2eqCO!JV(
# 6 27 72 >~5htFRAMY+[
# 8kwIrDP".^bnzLuGS%;{2eqClxJV(>~5htFoAMY+[
# 8kwfrDP".^bnziuG
# 6 28 72 S%;{2eq9lxJV(>~5h0coAMY+[
# 9lxJV(>~5_0coAMY+[
# <|3f
# 9lxJV(Q#/_
# 9lxJVEQ#/_0coAMvHT&<|3frDPyKW)? 6iuGpBNZ
# 9l4gsEQ#/_0co7jvHT&<|3famy
# 9}4gsEQ#/_0@	7jvHT&<|3]amyKW)? :`1dpBNZ,\'=}4gsEQ#/_*@	7
# 6 33 72 jvHT&<!-]amyKW)?$:`1dpBNZ,U'=}4gsEQ#LX*@	7jvHT&O!-]amyKWFR$:`1dpBNZIU'=
# 6 34 72 }4gsEQzLX*@	7jvHqCO!-]amyKtFR$:`1dpBkwIU'=}4gsEnzLX*@	7jveqCO!-]amyhtFR
# 6 35 72 $:`1dp8kwIU'=}4gbnzLX*@	7j2eqCO!-]a~5htFR$:`1d
# 8kwIU'=}4^bnzLX*@	;{2eq
# 6 36 72 CO!-]>~5htFR$:`+[
# 8kwIU'=}.^bnzLX*@%;{2eqCO!-V(>~5htFR$:Y+[
# 8kwIU'P".^
# 6 37 72 bnzLX*S%;{2eqCO!JV(>~5htFRAMY+[
# 8kwIUDP".^bnzLuGS%;{2eqCOxJV(>~5htFoAMY+
# 6 38 72 [
# 8kwfrDP".^bnziuGS%;{2eq9lxJV(>~5htcoAMY+[
# 9lxJ
# 6 39 72 V(>~5_0coAMY+[
# 9lxJV(>~/_0coAMY+[&<|3frDP".^)? 6i
# 9lxJVEQ#/_0coAMYHT&<|
# 9lxgsEQ#
# 9}4gsEQ#/_0c	7jvHT&<|3]amyKW)? :`1dpB
# =}4gsEQ#/_*@	7jvHT&<|-]amyKW)?$:`1dpBNZ,U'=}4gsEQ#/X*@	7jvHT&O!-]a
# 6 44 72 myKW)R$:`1dpBNZIU'=}4gsEQzLX*@	7jvHTCO!-]amyKtFR$:`1dpBNwIU'=}4gsEnzLX*@
# 6 45 72 	7jveqCO!-]amyhtFR$:`1dp8kwIU'=}4gsbnzLX*@	7j2eqCO!-]am5htFR$:`1d
# 8kwIU
# 6 46 72 '=}4^bnzLX*@	7{2eqCO!-]>~5htFR$:`1[
# 8kwIU'=}.^bnzLX*@%;{2eqCO!-](>~5ht
# 6 47 72 FR$:Y+[
# 8kwIU'=".^bnzLX*S%;{2eqCO!JV(>~5htFR$MY+[
# 8kwIUDP".^bnzLXGS%;{2
# 6 48 72 eqCOxJV(>~5htFoAMY+[
# 8kwIrDP".^bnziuGS%;{2eqClxJV(>~5htcoAMY+[
# 8kwfrDP".
# 9lxJV(>~5h0coAMY+[
# 9lxJV(>~/_0coAM
# 6 50 72 Y+[
# 9l
# 9lxJsEQ#/_0coAMvHT&<|3frDmyKW)?
# 9l4gsEQ#/_0c	7jvHT&
# =}4gsEQ#/_0@	7jvHT&<|-]amyKW)?$:`1dpBNZ,\'=}4gsE
# 6 54 72 Q#/X*@	7jvHT&<!-]amyKW)R$:`1dpBNZIU'=}4gsEQ#LX*@	7jvHTCO!-]amyKWFR$:`1d
# 6 55 72 pBNwIU'=}4gsEnzLX*@	7jvHqCO!-]amyhtFR$:`1dpBkwIU'=}4gsbnzLX*@	7jveqCO!-]
# 6 56 72 am5htFR$:`1d
# 8kwIU'=}4gbnzLX*@	7{2eqCO!-]a~5htFR$:`1[
# 8kwIU'=}.^bnzLX
# 6 57 72 *@	;{2eqCO!-](>~5htFR$:`+[
# 8kwIU'=".^bnzLX*S%;{2eqCO!-V(>~5htFR$MY+[
# 8kw
# 6 58 72 IU'P".^bnzLXGS%;{2eqCOxJV(>~5htFRAMY+[
# 8kwIrDP".^bnzLuGS%;{2eqClxJV(>~5
# 6 59 72 htcoAMY+[
# 8kwfrDP".^bn6iuGS%;{2eq9lxJV(>~5h0coAMY+[
# 8k3frDP".^b 6iuGS%;
# 9lxJV(>~5_0coAMY+[
# 9lxJV(>#/_0coAMY+[&<|3frDP
# 9lxJVEQ#/_0co
# 9lxgsEQ#/_0coAjvHT&<|3framyKW)? 6iudpBNZ,\
# 9}4gsEQ#/_0@	7jvHT&<|-]amyKW)
# 6 64 72 ? :`1dpBNZ,\'=}4gsEQ#/_*@	7jvHT&<!-]amyKW)R$:`1dpBNZ,U'=}4gsEQ#LX*@	7jvH
# 6 65 72 T&O!-]amyKWFR$:`1dpBNwIU'=}4gsEQzLX*@	7jvHqCO!-]amyKtFR$:`1dpBkwIU'=}4g
# 6 66 72 sbnzLX*@	7jveqCO!-]am5htFR$:`1dp8kwIU'=}4gbnzLX*@	7j2eqCO!-]a~5htFR$:`
# 6 67 72 1[
# 8kwIU'=}4^bnzLX*@	;{2eqCO!-]>~5htFR$:`+[
# 8kwIU'=".^bnzLX*@%;{2eqCO!
# 6 68 72 -V(>~5htFR$:Y+[
# 8kwIU'P".^bnzLXGS%;{2eqCO!JV(>~5htFRAMY+[
# 8kwIUDP".^bnz
# 6 69 72 LuGS%;{2eqClxJV(>~5htFoAMY+[
# 8kwfrDP".^bnziuGS%;{2eq9lxJV(>~5htcoAMY+[
# 8
# 9lxJV(>~5_0coAMY+[
# 9lxJV(>
# 9lxJV(Q#/_0coAMY+T&<|3frDP"KW)? 6iuGS
# 9lxJsEQ#/_0coAjvHT&<|3fr
# 7 0 72 a	=$Ozk5{.vg1]*UFqb&QBm7}:!L3_,WHsd@Do9 <#Nyj.YJuf0\)Tb
# >%PAl6|Lwh2^+VGr
# ?&QBm7}Mxi3_,WHs[(SDo9 <#k5{.YJuf0
# 7 2 72 UFqb
# ?&QB~;"Mxi3_,
# 7 3 72 te[(SDo9$Ozk5{.YJ1]*UFqb
# >Bm7}:!Lwh2WHsd@'RC <#Nyj4`-uf0\)TEpa%PAl6|/ZK
# ?Cn8~;"Mxi-XIte[(Sa	=$Ozk5{Kvg1]*UFqb&QBm7}:!L3_,WHsd@Do9 <#Nyj
# 7 5 72 .YJuf0\)Tb
# ?&QBm7}
# 7 6 72 Mxi3_,WHs[(SDo9 <#k5{.YJuf0UFqb
# >%PA}:!Lwh2^+sd@'RCn8#Nyj4`-XIt\)TEpa	=$
# ?&QB~;"Mxi3_,te[(SDo9$Ozk5{.YJ1]*UFqb
# >Bm7}:!Lwh,WHsd@'RC
# ?Cn8~;"Mxi-XIte[(Sa	=$Ozk5{Kvg1]*UFq?
# 7 9 72 &QBm7}:!i3_,WHsd@Do9 <#Nyj.YJuf0\)Tb
# >%PAl6|Lwh2^+VGr@'RCn8~;"j4`-XIteT
# ?&QBm7}Mxi3_,WHs[(SDo9 <#k5{.YJuf0UFqb
# >%PA}:!Lwh2^+s
# ?&QB~;"Mxi3_,te[(SDo9$Ozk5{.YJ1
# 7 12 72 ]*UFqb
# ?Cn8~;"Mxi-
# 7 13 72 XIte[(Sa	=$Ozk5{Kvg1]*UFq?&QBm7}:!i3_,WHsdSDo9 <#Nyj.YJuf0\)Tb
# >%PAl6|L
# ?&QBm7"Mxi3_,WHs[(SDo9 <#k
# 7 15 72 5{.YJuf0UFqb
# ?&QB~
# 7 16 72 ;"Mxi3_,te[(SDo9$Ozk5{.YJ1]*UFqb
# >Bm7}:!Lwh,WHsd@'R9 <#Nyj4`Juf0\)TEp>%
# ?Cn8~;"Mxi-XIte[(Sa	=$Ozk5{Kvg1]*UFq?&QBm7}:!i3_,WHsdSD
# 7 18 72 o9 <#Ny{.YJuf0\)qb
# >%PAl6|Lwh2^+VGr@'RCn8~;"j4`-XIteTEpa	=$Oz|/ZKvg1]*rc
# ?&QBm7"Mxi3_,WH[(SDo9 <zk5{.YJuf0UFqb
# >%PA}:!Lwh2^+sd@'RCn8#Nyj4`-XI0\
# ?&Q8~;"Mxi3_Ite[(SDo9$Ozk5{.YJ1]*UFqb
# >Bm7}:!Lwh,W
# RCn8~;"Mxi-XIte[(Sa	=$Ozk5{Kv
# 7 22 72 g1]*UFq?&QBm7}:!i3_,WHsdSDo9 <#Ny{.YJuf0\)qb
# >%PAl6!Lwh2^+VGr@'RCn8~;"j4
# ?&QBm7"Mxi3_,WH[(SDo9 <zk5{.YJuf*UFqb
# >%PA}:
# ?&Q8~;"Mxi3_Ite[(SDo=$O
# 7 25 72 zk5{.Yg1]*UFqb
# RCn
# 7 26 72 8~;"Mx`-XIte[(pa	=$Ozk5{Kvg1]*UFq?&QBm7}:!i3_,WHsdSDo9 <#Ny{.YJuf0\)qb
#
# ?&QBm7"Mxi3_,WH[(
# 7 28 72 SDo9 <zk5{.YJuf*UFqb
# >%P7}:!Lwh2^Hsd@'RCn8#Nyj4`-XI0\)TEpa	=Al6|/ZKvg+VG
# ?&Q8~;"Mxi3_Ite[(SDo=$Ozk5{.Yg1]*UFqb
# QBm7}:!Lwh,WHsd@'R9 <#Nyj4`Juf
# RCn8~;"Mx`-XIte[(pa	=$Ozk5ZKvg1]*UFq?&QBm7}:!i3_
# 7 31 72 ,WHsdSDo9 <#Ny{.YJuf0\)qb
# >%PAl6!Lwh2^+VG@'RCn8~;yj4`-XIte)TEpa	=$Oz|/Z
# ?&QBm7"Mxi3_,WH[(SDo9 <zk5{.YJuf*UFqb
# >%P7}:!Lwh2^Hsd@'RCn<#Ny
# ?&Q8~;"Mxi3_Ite[(SDo=$Ozk5{.Yg1]*UFqb
# QBm7
# RCn8~;"Mx`-XIte[(pa	=
# ?&QBm7}:xi3_,WHsdSDo9 <#Ny{.YJuf0\)qb
# >%PAl6!Lwh2^+VG@'R
# ?&QBm7"Mxi3_,WH[(SDo9 <zk5{.YJuf*UFq
# 7 37 72 b
# ?&Q8~;"Mxi3_Ite
# 7 38 72 [(SDo=$Ozk5{.Yg1]*UFqb
# QBm7}:!Lw_,WHsd@'o9 <#Nyj4YJuf0\)TEp>%PAl6|/Zh2^+
# ?&QBm7}:xi3_,WHsd(SDo9 <#Ny{.YJ
# 7 40 72 uf0\)qb
# ?&QBm;"Mxi
# 7 41 72 3_,We[(SDo9 <zk5{.YJuf*UFqb
# >%P7}:!Lwh2^Hsd@'RCn<#Nyj4`-Xf0\)TEpa	PAl6|
# ?&n8~;"Mxi3_Ite[(SDo=$Ozk5{.Yg1]*UFqb
# QBm7}:!Lw_,WHsd@'o9 <#
# 7 43 72 Nyj4YJuf0\)TE
# ?&QB
# 7 44 72 m7}:xi3_,WHsd(SDo9 <#N5{.YJuf0\Fqb
# >%PAl6!Lwh2^+VG@'RCn8~;yj4`-XIte)TEpa
# ?&QBm;"Mxi3_,We[(SDo9 Ozk5{.YJuf*UFqb
# >%P7}:!Lwh2^Hsd@
# ?&n8~;"Mxi3XIte[(SDo=$Ozk5{.Yg1]*U
# 7 47 72 Fqb
# QBm7}:!Lw_,WHsd@'o9 <#Nyj4YJuf0\)TE
# >%PAl6|/wh2^+VGrc'RCn8~;"Mx`-XIt
# ?&QBm7}:xi3_,WHsd(SDo9 <#N5{.YJuf0\Fqb
# >%PAl:!Lwh2
# ?&QBm;"Mxi3_,We[(SDo9 Ozk5{.
# 7 50 72 YJu]*UFqb
# ?&n8~;"M
# 7 51 72 xi3XIte[(SD	=$Ozk5{.vg1]*UFqb
# QBm7}:!Lw_,WHsd@'o9 <#Nyj4YJuf0\)TE
# >%PAl
# ?&QBm7}:xi3_,WHsd(SDo9
# 7 53 72 <#N5{.YJuf0\Fqb
# ?&
# 7 54 72 QBm;"Mxi3_,We[(SDo9 Ozk5{.YJu]*UFqb
# >%m7}:!Lwh2WHsd@'RCn<#Nyj4`-Xf0\)TE
# ?&n8~;"Mxi3XIte[(SD	=$Ozk5{.vg1]*UFqb&QBm7}:!Lw_,WHsd
# 7 56 72 @'o9 <#Nyj4YJuf0\)TE
# >%PAl6|/wh2^+VGrc'RCn8~;"M4`-XIte[Epa	=$Ozk/ZKvg1]
# ?&QBm7}:xi3_,WHsd(SDo9 <#N5{.YJuf0\Fqb
# >%PAl:!Lwh2^+Vd@'RCn8~Nyj4`-X
# ?&QBm;"Mxi3_,We[(SDo9 Ozk5{.YJu]*UFqb
# >%m7}:!Lw
# ?&n8~;"Mxi3XIte[(SD	=$Ozk5
# 7 60 72 {.vg1]*UFqb&QBm7}:!L3_,WHsd@Do9 <#Nyj4YJuf0\)TE
# >%PAl6|/wh2^+VGrc'RCn8~;
# ?&QBm7}Mxi3_,WHsd(SDo9 <#N5{.YJuf0\Fqb
# >%P
# ?&QBm;"Mxi3_,We[(SDo
# 7 63 72 9 Ozk5{.YJu]*UFqb
# >%m7}:!Lwh2WHsd@'RC <#Nyj4`-uf0\)TEpa%PAl6|/ZKv^+VGrc
# 7 64 72 ?&n8~;"Mxi3XIte[(SD	=$Ozk5{.vg1]*UFqb&QBm7}:!L3_,WHsd@Do9 <#Nyj.YJuf0\)
# 7 65 72 Tb
# ?&QBm7}Mxi3_,WH
# 7 66 72 s[(SDo9 <#k5{.YJuf0\Fqb
# >%PAl:!Lwh2^+Vd@'RCn8~Nyj4`-XIt\)TEpa	=$l6|/ZKvg
# ?&QB~;"Mxi3_,te[(SDo9 Ozk5{.YJu]*UFqb
# >%m7}:!Lwh2WHsd@'RC <#Nyj4`
# ?Cn8~;"Mxi3XIte[(SD	=$Ozk5{.vg1]*UFqb&QBm7}:!
# 7 69 72 L3_,WHsd@Do9 <#Nyj.YJuf0\)Tb
# >%PAl6|Lwh2^+VGrc'RCn8~;"M4`-XIte[Epa	=$Oz
# ?&QBm7}Mxi3_,WHs[(SDo9 <#k5{.YJuf0UFqb
# >%PAl:!Lwh2^+Vd@'RCn8
# ?&QB~;"Mxi3_,te[(SDo9$Ozk5{.YJu]*UFqb
# >
# ?Cn8~;"Mxi-XIte[(S
# 8 0 72 a'q[G0Wg-3Zj:z~P9C
# Sc)s]I,v`L5"l<8%o?EUeH1Xh.x|N;A Qa'q[d*t^J3ZjM6#m=C
# S
# Td*t^g-w{M6#mP9&p@FV]I2Yi/y}l<B	Rb(r
# q[G0Wg-w{j:z~P9&pSc)s]I2Y`L5"l<B	o?EUe+uXh.x|N7$ Qa'q[G0
# 8 3 72 t^J3Zj:z#m=C
# Td*t^J3w{M6#m=C&p@FVf,
# TdG0Wg-w{M6z~P9&p@F)s]I2Yi/5"l<B	RbEUe+u_K
# 8 5 72 .x|N7$n>a'q[G0WgJ3Zj:z~P=C
# Sc)s]f,v`L5"lO8%o?EUeH1Xh.x|N;A Qa'q[d*t^J3Zj
# 8 6 72 M6#m=C
# Td*tWg-w{M6#mP9&p@FV]I2Yi/y}
# q[G0Wg-wZj:z~P9&
# Sc)s]I2v`L5"l<B%o?EUe+uXh.x|N7$
# 8 8 72  Qa'q[G0t^J3Zj:z#m=C
# Td*t^J-w{M6#m=C
# TdG0Wg-w{M:z~P9&p@c)s]I2YiL5"l<B	R?
# 8 10 72 EUe+u_h.x|N7$n>a'q[G0WgJ3Zj:z~P=C
# Sc)s]f,v`L5"lO8%o?EU\H1Xh.x|k;A Qa'qT
# 8 11 72 d*t^J3Z{M6#m=C
# Td*tWg-w{M6#~P9&p@Fs
# q[G0Wg-wZj:z~P9&
# Sc)s]I2v`L5"l<B%o?EUe+1
# 8 13 72 Xh.x|N7A Qa'q[G*t^J3Zj:6#m=C
# Td*t^J-
# TdG0Wg-w{M:z~P9&p@c)s]I2YiL
# 8 15 72 5"l<B	R?EUe+u_h.x|N7$nQa'q[G0W^J3Zj:z~m=C
# Sc)sVf,v`L5"lO8%o?EU\H1Xh.x|k
# 8 16 72 ;A Qa'qTd*t^J3Z{M6#m=C
# Td*tWg-w{M6#~
# 8 17 72 P9&p@Fs]I2Yi/y"l<B	Rb(Ue+u_K4x|N7$n>D'q[G0Wg-3Zj:z~P9C
# Sc)s]I,v`L5"l<B%
# 8 18 72 o?EUe+1Xh.x|N7A Qa'q[G*t^J3Zj:6#m=C
# ScFVf,v`L/y}O8%o?b(r\H1XhK4!k;A Q>D
# T[G0Wg-w{j:z~P9&pSc
# 8 20 72 )s]I2Y`L5"l<B	o?EUe+u_h.x|N7$nQa'q[G0W^J3Zj:z~m=C
# Sc)sVf,v`L5"}O8%o?Er\
# Td*t^J3w{M6#m=C
# Td*0W
# 8 22 72 g-w{M6z~P9&p@F)s]I2Yi/5"l<B	RbEUe+u_K4x|N7$n>D'q[G0Wg-3Zj:z~P9C
# Sc)s]I,v
# 8 23 72 `L5"l<8%o?EUeH1Xh.x|N;A Qa'q[d*t^J3ZjM6#m=C
# ScFVf,v`L/y}O8%o?b(r\H1XhK4
# T[G0Wg-w{j:
# 8 25 72 z~P9&pSc)s]I2Y`L5"l<B	o?EUe+uXh.x|N7$ Qa'q[G0t^J3Zj:z#m=C
# Sc)sVf,v`L5"}O
# Td*t^J3w{M6#m=C&p@FVf,2Yi/y}O8B	Rb(r\H+u_K4!k;A$n
# Td*0Wg-w{M6z~P9&p@F)s]I2Yi/5"l<B	RbEUe+u_K.x|N7$n>a'q[G0WgJ3Zj:z~P=C
#
# 8 28 72 Sc)s]f,v`L5"l<8%o?EUeH1Xh.x|N;A Qa'q[d*t^J3ZjM6#m=C
# S@FVf,v`i/y}O8%oRb(
# q[G
# 8 30 72 0Wg-wZj:z~P9&
# Sc)s]I2v`L5"l<B	o?EUe+uXh.x|N7$ Qa'q[G0t^J3Zj:z#m=C
# Sc)Vf
# Td*t^J3w{M6#m=C&p@FVf,2Yi/y}O8B	Rb(r\H+u_
# TdG0Wg-w{M:z~P9&p@c)s]I2YiL5"l<B	RbEUe+u_K.x|N7$n>a'q[G0WgJ3Z
# 8 33 72 j:z~P=C
# Sc)s]f,v`L5"lO8%o?EU\H1Xh.x|k;A Qa'qTd*t^J3ZjM6#m=C
# S@FVf,v`i/y
# Td*tWg-w{M6#~P9&p@Fs]I2Yi/y"l<B	Rb(rUe+u_K4!|N7
# q[G0Wg-wZj:z~P9&
# Sc)s]I2v`L5"l<B%o?EUe+1Xh.x|N7A Qa'q[G*t^J3Zj:z#m=
# 8 36 72 C
# Td*t^J-w{M6#m=9&p@FVfI2Yi/y}O<B	R
# TdG0Wg-w{M:z~P9&p@c)s]I2YiL5"l<B	R?EUe+u_h.x|N7$nQa'q
# 8 38 72 [G0W^J3Zj:z~m=C
# Sc)s]f,v`L5"lO8%o?EU\H1Xh.x|k;A Qa'qTd*t^J3Z{M6#m=C
# p@F
# Td*tWg-w{M6#~P9&p@Fs]I2Yi/y"l<B	Rb(Ue+
# 8 40 72 u_K4x|N7$n>D'q[G0Wg-3Zj:z~P9C
# Sc)s]I2v`L5"l<B%o?EUe+1Xh.x|N7A Qa'q[G*t^J
# 8 41 72 3Zj:6#m=C
# Td*t^J-w{M6#m=9&p@FVfI2Yi
# T[G0Wg-w{j:z~P9&pSc)s]I2YiL5"l<B	R?EUe+u_h.x|
# 8 43 72 N7$nQa'q[G0W^J3Zj:z~m=C
# Sc)sVf,v`L5"}O8%o?Er\H1Xh.x!k;A Qa'qTd*t^J3Z{M6#
# 8 44 72 m=C
# Td*0Wg-w{M6z~P9&p@F)s]I2Yi/y"l<B
# 8 45 72 	Rb(Ue+u_K4x|N7$n>D'q[G0Wg-3Zj:z~P9C
# Sc)s]I,v`L5"l<8%o?EUeH1Xh.x|N;A Qa
# 8 46 72 'q[d*t^J3Zj:6#m=C
# Td*t^g-w{M6#mP9&p@
# T[G0Wg-w{j:z~P9&pSc)s]I2Y`L5"l<B	o?EU
# 8 48 72 e+uXh.x|N7$ Qa'q[G0t^J3Zj:z~m=C
# Td*t
# Td*0Wg-w{M6z~P9&p@F)s]I2
# 8 50 72 Yi/5"l<B	RbEUe+u_K.x|N7$n>a'q[G0WgJ3Zj:z~P9C
# Sc)s]I,v`L5"l<8%o?EUeH1Xh.
# 8 51 72 x|N;A Qa'q[d*t^J3ZjM6#m=C
# Td*t^g-w{M
# q[G0Wg-wZj:z~P9&pSc)s]I2Y`L5"l
# 8 53 72 <B	o?EUe+uXh.x|N7$ Qa'q[G0t^J3Zj:z#m=C
# Sc)Vf,v`L5y}O8%o?E(r\H1Xh.x!k;A
# TdG0Wg-w{M:z~P9&
# 8 55 72 p@c)s]I2Yi/5"l<B	RbEUe+u_K.x|N7$n>a'q[G0WgJ3Zj:z~P=C
# Sc)s]f,v`L5"lO8%o?E
# 8 56 72 U\H1Xh.x|k;A Qa'q[d*t^J3ZjM6#m=C
# Td
# q[G0Wg-wZj:z~P9&
# Sc)s]
# 8 58 72 I2v`L5"l<B%o?EUe+1Xh.x|N7A Qa'q[G0t^J3Zj:z#m=C
# Sc)Vf,v`L5y}O8%o?E(r\H1X
# TdG0Wg-w
# 8 60 72 {M:z~P9&p@c)s]I2YiL5"l<B	R?EUe+u_h.x|N7$nQa'q[G0WgJ3Zj:z~P=C
# Sc)s]f,v`L5
# 8 61 72 "lO8%o?EU\H1Xh.x|k;A Qa'qTd*t^J3Z{M6#m=C
# p@FVf,vYi/y}O8%oRb(r\H1X_K4!k;
# Td*tWg-w{M6#~P9&p@Fs]I2Yi/y"l<B	Rb(Ue+u_K4x|N7$n>D'q[G0Wg-wZj:z~P
# 8 63 72 9&
# Sc)s]I2v`L5"l<B%o?EUe+1Xh.x|N7A Qa'q[G*t^J3Zj:6#m=C
# ScFVf,v`L/y}O8%o
# Td*t^J-w{M6#m=9&p@FVfI2Yi/y}O<B	Rb(r\e+u_K4!kN7$n>D
# 8 65 72 T[G0Wg-w{j:z~P9&p@c)s]I2YiL5"l<B	R?EUe+u_h.x|N7$nQa'q[G0W^J3Zj:z~m=C
# Sc)
# 8 66 72 sVf,v`L5"}O8%o?Er\H1Xh.x|k;A Qa'qTd*t^J3Z{M6#m=C
# p@FVf,vYi/y}O8%	Rb(r\H
# Td*0Wg-w{M6z~P9&p@Fs]I2Yi/y"l<B	Rb(Ue+u_K4x|N7$n>D'q[G0Wg
# 8 68 72 -3Zj:z~P9C
# Sc)s]I,v`L5"l<8%o?EUeH1Xh.x|N7A Qa'q[G*t^J3Zj:6#m=C
# ScFVf,v`
# Td*t^g-w{M6#mP9&p@FVfI2Yi/y}O<B	Rb(r\e+u_K4!
# T[G0Wg-w{j:z~P9&pSc)s]I2Y`L5"l<B	o?EUe+uXh.x|N7$nQa'q[G0W^J3Zj:z
# 8 71 72 ~m=C
# Td*t^J3w{M6#m=C&p@FVf,vYi/y}O8
# Td*0Wg-w{M6z~P9&p@F)s]I2Yi/5"l<B	RbEUe+u_K.x|N7$n>
# 9 0 72 aF+3y$
# rtY|mR[fhM<aF+35A&tY|moT]hM<acH-5A&0v!~oT]hjO>cH-57C(0v!~	qV_jO>
# sXZ}nS\gL;=bG,4z%'uZ}nS
# 9 2 72 U^iN=bG,.6B'uZ" pU^iNP?dI.6BD)1w" pUW`kP?dIK:8D)1wy$
# rW`kPR[fK:8DF+3y$
# r
# 9 3 72 tY|mR[fhM<aF+3yA&tY|moT]hM<acH-5A&tv!~oT]hjO>cH-57C(0v!~oqV_jO>ceJ/7C(0
# sX{}nS\gL;=bG,4z%'uZ}nS\^iN=bG,
# 9 5 72 .6B'uZ" pU^iN=?dI.6B')1w" pUW`kP?dIK:8D)1w"$
# rW`kPR[fK:8DF+3y$
# rWY|mR[fK
# 9 6 72 M<aF+3yA&tY|moT]hM<aFH-5A&tv!~oT]hjO>cH-5AC(0v!~oqV_jO>ceJ/7C(0vx#	qV_j
# uZ}nS\^iN=bG,.6B'uZ}
# 9 8 72  pU^iN=?dI.6B')1w" pU^`kP?dI.:8D)1w"$
# rW`kPR[fK:8D)+3y$
# rWY|mR[fKM<aF+3y$
# 9 9 72 &tY|mRT]hM<aFH-5A&tv!~oT]hMO>cH-5AC(0v!~oqV_jO>cHJ/7C(0vx#	qV_jlQ@eJ/7C
# uZ}nS\giN=bG,46B'uZ} pU^iN=?
# 9 11 72 dI.6B'1w" pU^`kP?dI.:8D)1w"
# rW`kP?[fK:8D)+3y$
# rWY|mR[fK:<aF+3y$&tY|mRT
# 9 12 72 ]hM<aF+-5A&tY!~oT]hMO>cH-5AC(0v!~oTV_jO>cHJ/7C(0vx#	qV_jOQ@eJ/7CE*2x#	qs
# suZ}nS\giN=bG,46B'uZ}npU^iN=bdI.6B'1
# 9 14 72 w" pU^`kP?dI.68D)1w"
# rW`kP?[fK:8D)13y$
# rW`|mR[fK:<aF+3y$&tY|mR[]hM<aF+-
# 9 15 72 5A&tY!~oT]hM<>cH-5A&(0v!~oTV_jO>cHJ/7C(0v!#	qV_jOQ@eJ/7CE*2x#	qVX{lQ@eJL
# suZ}nS\giN=bG,4zB'uZ}npU^iN=bdI.6B'uw" pU^ik
# 9 17 72 P?dI.68D)1w"
# rW`kP?dfK:8D)13y$
# rW`|mR[fK:8aF+3y$
# tY|mR[]hM<aF+-5A&tY|~
# 9 18 72 oT]hM<>cH-5A&(0v!~oT]_jO>cH-/7C(0v!#	qV_jOQ@eJ/7C(*2x#	qVX{lQ@eJL;9E*2x#%
# suZ}nS\gLN=bG,4zB'uZ}npU^iN=bGI.6B'uw" pU^ikP?dI.6BD
# 9 20 72 )1w" prW`kP?dfK:8D)13y$
# rW`kmR[fK:8aF+3y$
# tY|mR[fhM<aF+35A&tY|~oT]hM<>c
# sX{lQS\
# sXZ}nS\gLN=bG,4zB'uZ}nSU^iN=bGI.6B'uw" pU^iNP?dI.6BD)1w" prW
# 9 23 72 `kP?dfK:8D)1wy$
# rW`kmR[fK:8aF+3y$
# rtY|mR[fhM<aF+35A&tY|moT]hM<acH-5A&0v
# sX{lQ@\gL;9E*,4
# sXZ}nS\gL;=bG,4z%'uZ}nSU^iN=bGI.6B'uZ" pU^iNP?dI.6BD)1w" pUW`kP?dIK:
# 9 26 72 8D)1wy$
# rW`kmR[fK:8DF+3y$
# rtY|mR[fhM<aF+3yA&tY|moT]hM<acH-5A&tv!~oT]hjO
# sX{}n
# 9 28 72 S\gL;=bG,4z%'uZ}nS\^iN=bG,.6B'uZ" pU^iNP?dI.6B')1w" pUW`kP?dIK:8D)1w"$
#
# 9 29 72 rW`kPR[fK:8DF+3y$
# rtY|mR[fKM<aF+3yA&tY|moT]hM<aFH-5A&tv!~oT]hjO>cH-5AC(
# sX{}nS\gL;=bG
# uZ}nS\^iN=bG,.6B'uZ} pU^iN=?dI.6B')1w" pUW`kP?dI.:8D)1w"$
# rW`kPR[f
# 9 32 72 K:8D)+3y$
# rWY|mR[fKM<aF+3yA&tY|mRT]hM<aFH-5A&tv!~oT]hMO>cH-5AC(0v!~oqV_
# uZ
# 9 34 72 }nS\^iN=bG,46B'uZ} pU^iN=?dI.6B'1w" pU^`kP?dI.:8D)1w"$
# rW`kP?[fK:8D)+3y
# 9 35 72 $
# rWY|mR[fK:<aF+3y$&tY|mRT]hM<aFH-5A&tY!~oT]hMO>cH-5AC(0v!~oTV_jO>cHJ/7
# suZ}nS\giN=
# 9 37 72 bG,46B'uZ} pU^iN=bdI.6B'1w" pU^`kP?dI.68D)1w"
# rW`kP?[fK:8D)+3y$
# rW`|mR
# 9 38 72 [fK:<aF+3y$&tY|mR[]hM<aF+-5A&tY!~oT]hMO>cH-5A&(0v!~oTV_jO>cHJ/7C(0v!#	q
# suZ}nS\giN=bG,4zB'
# 9 40 72 uZ}npU^iN=bdI.6B'1w" pU^ikP?dI.68D)1w"
# rW`kP?dfK:8D)13y$
# rW`|mR[fK:<aF+
# 9 41 72 3y$
# tY|mR[]hM<aF+-5A&tY|~oT]hM<>cH-5A&(0v!~oTV_jO>cH-/7C(0v!#	qV_jOQ@eJ
# suZ}nS\gLN=bG,4zB'uZ}npU^i
# 9 43 72 N=bdI.6B'uw" pU^ikP?dI.68D)1w" prW`kP?dfK:8D)13y$
# rW`kmR[fK:8aF+3y$
# tY|
# 9 44 72 mR[]hM<aF+35A&tY|~oT]hM<>cH-5A&0v!~oT]_jO>cH-/7C(0v!#	qV_jO>@eJ/7C(*2x#
# sXZ}nS\gLN=bG,4zB'uZ}nSU^iN=bGI.6B
# 9 46 72 'uw" pU^ikP?dI.6BD)1w" prW`kP?dfK:8D)1wy$
# rW`kmR[fK:8aF+3y$
# rtY|mR[fhM<a
# 9 47 72 F+35A&tY|~oT]hM<acH-5A&0v!~oT]_jO>cH-57C(0v!~	qV_jO>@eJ/7C(*2x#	qV_{lQ@
# sXZ}nS\gLN=bG,4z%'uZ}nSU^iN=bGI.6B'uZ" pU
# 9 49 72 ^iNP?dI.6BD)1w" prW`kP?dIK:8D)1wy$
# rW`kmR[fK:8DF+3y$
# rtY|mR[fhM<aF+3yA&t
# 9 50 72 Y|moT]hM<acH-5A&0v!~oT]hjO>cH-57C(0v!~	qV_jO>ceJ/7C(02x#	qV_{lQ@eJ/;9E*2
# sX{}nS\gL;=bG,4z%'uZ}nSU^iN=bG,.6B'uZ" pU^iNP?dI.
# 9 52 72 6B')1w" pUW`kP?dIK:8D)1wy$
# rW`kPR[fK:8DF+3y$
# rtY|mR[fKM<aF+3yA&tY|moT]hM
# sX{l
# uZ}nS\^iN=bG,.6B'uZ" pU^iN=?dI.6B')1w"
# 9 55 72 pUW`kP?dI.:8D)1w"$
# rW`kPR[fK:8DF+3y$
# rWY|mR[fKM<aF+3yA&tY|mRT]hM<aFH-5A&
# 9 56 72 tv!~oT]hjO>cH-5AC(0v!~oqV_jO>ceJ/7C(0vx#	qV_jlQ@eJ/79E*2x#	qsX{lQ@egL;9E
# uZ}nS\^iN=bG,46B'uZ} pU^iN=?dI.6B')1w" pU^`kP?d
# 9 58 72 I.:8D)1w"$
# rW`kP?[fK:8D)+3y$
# rWY|mR[fKM<aF+3y$&tY|mRT]hM<aFH-5A&tY!~oT]
# sX
# uZ}nS\giN=bG,46B'uZ} pU^iN=bdI.6B'1w" pU^`kP?dI.:8D)1w
# 9 61 72 "
# rW`kP?[fK:8D)+3y$
# rW`|mR[fK:<aF+3y$&tY|mRT]hM<aF+-5A&tY!~oT]hMO>cH-5
# sX{lnS\gL;
# suZ}nS\giN=bG,46B'uZ}npU^iN=bdI.6B'1w" pU^ikP?dI.68D)1w"
# rW`kP
# 9 64 72 ?[fK:8D)13y$
# rW`|mR[fK:<aF+3y$
# tY|mR[]hM<aF+-5A&tY!~oT]hM<>cH-5A&(0v!~o
# sX{lQS\gL;9EG,4z%
# 9 66 72 suZ}nS\giN=bG,4zB'uZ}npU^iN=bdI.6B'uw" pU^ikP?dI.68D)1w" prW`kP?dfK:8D)
# 9 67 72 13y$
# rW`|mR[fK:8aF+3y$
# tY|mR[]hM<aF+35A&tY|~oT]hM<>cH-5A&(0v!~oT]_jO>cH
# sXZ}nS\g
# 9 69 72 LN=bG,4zB'uZ}npU^iN=bGI.6B'uw" pU^ikP?dI.6BD)1w" prW`kP?dfK:8D)1wy$
# rW`
# 9 70 72 kmR[fK:8aF+3y$
# tY|mR[fhM<aF+35A&tY|~oT]hM<acH-5A&0v!~oT]_jO>cH-/7C(0v!
# sXZ}nS\gLN=bG,4z
# 9 72 72 %'uZ}nSU^iN=bGI.6B'uw" pU^iNP?dI.6BD)1w" prW`kP?dIK:8D)1wy$
# rW`kmR[fK:8
# 10 0 72 aeimquy9dhlptx8cgkos37bfjnr26aeimq159dhl
# 159d_}
# 048
# 1/=[_}
# 0.<@^|	-;?]{ (,:>\`~'+/=[_"&*.<@^!%)-;?]Z$(,:>
# 10 2 72 UY#'+/=TX"&*.<SW!%)-NRVZ$(,MQUY#'HLPTX"&GKOSW!%FJNRVZAEIMQUYzDHLPTXyCGKOS
# 10 3 72 txBFJNRswAEIMnrvzDHLmquyCGKlptxBFgkoswAEfjnrvzDeimquy9dhlptx8cgkosw7bfjnr
# 10 4 72 26aeimq159dhl
# 159d_}
# 1/=[_}
# 0
# 10 5 72 .<@^|	-;?]{ (,:>\`~'+/=[_}&*.<@^!%)-;?]Z$(,:>UY#'+/=TX"&*.<SW!%)-NRVZ$(,
# 10 6 72 MQUY#'+LPTX"&GKOSW!%FJNRVZAEIMQUYzDHLPTXyCGKOStxBFJNRswAEIMQrvzDHLmquyCGK
# 10 7 72 lptxBFgkoswAEfjnrvzDeimquy9dhlptx8cgkosw7bfjnr26aeimq159dhlp048cgk	37bfj
# 159d_}
# 15=[_}
# 0.<@^|	-;?]{ (,:>\`~'+/=[_}
# 10 9 72 &*.<@^!%)-;?]Z$(,:>\Y#'+/=TX"&*.<SW!%)-NRVZ$(,MQUY#'+LPTX"&GKOSW!%FJNRVZ$
# 10 10 72 EIMQUYzDHLPTXyCGKOStxBFJNRswAEIMQrvzDHLmquyCGKlptxBFJkoswAEfjnrvzDeimquyC
# 159d_}
# 048c^|	37?
# 15=[_}
# 0.<@^|	-;?]{ ,:>\`~'+/=[_}&*.<@^!%)-;?]Z$(,:>\Y#'+/=T
# 10 13 72 X"&*.<SW!%)-;RVZ$(,MQUY#'+LPTX"&GKOSW!%FJNRVZ$EIMQUYzDHLPTXyCGKOSWxBFJNRs
# 10 14 72 wAEIMQrvzDHLmquyCGKlptxBFJkoswAEfjnrvzDeimquyCdhlptx8cgkosw7bfjnrv6aeimq1
# 159d_}
# 15=[_}
# 0.<@^|	-
# 10 16 72 ;?]{ ,:>\`~'+/=[_}&*.<@^|%)-;?]Z$(,:>\Y#'+/=TX"&*.<SW!%)-;RVZ$(,MQUY#'+L
# 10 17 72 PTX"&*KOSW!%FJNRVZ$EIMQUYzDHLPTXyCGKOSWxBFJNRswAEIMQrvzDHLPquyCGKlptxBFJk
# 10 18 72 oswAEfjnrvzDeimquyCdhlptx8cgkosw7bfjnrv6aeimq159dhlp048cgko37bfj 26aei~
# 159d_}
# 15=[_}
# 04<@^|	-;?]{ ,:>\`~'+/=[_}&*.<@^|%
# 10 20 72 )-;?]Z$(,:>\Y#'+/=[X"&*.<SW!%)-;RVZ$(,MQUY#'+LPTX"&*KOSW!%FJNRVZ$EIMQUY#D
# 10 21 72 HLPTXyCGKOSWxBFJNRswAEIMQrvzDHLPquyCGKlptxBFJkoswAEIjnrvzDeimquyCdhlptxBc
# 159dh}
# 048c^|	37b]{ 26>\
# 15=[_}
# +/=[_}&*.<@^|%)-;?]Z$(,:>\Y#'+/=[X"&*.<SW
# 10 24 72 !%)-;RVZ$(,:QUY#'+LPTX"&*KOSW!%FJNRVZ$EIMQUY#DHLPTXyCGKOSWxBFJNRVwAEIMQrv
# 10 25 72 zDHLPquyCGKlptxBFJkoswAEIjnrvzDeimquyCdhlptxBcgkosw7bfjnrv6aeimqu59dhlp04
# 159dh}
# 15=[_}
# 04<@^|	-;?]{ ,:
# +/=[_}&*.<@^|%)-;?]{$(,:>\Y#'+/=[X"&*.<SW!%)-;RVZ$(,:QUY#'+LPTX"&*KO
# 10 28 72 SW!%)JNRVZ$EIMQUY#DHLPTXyCGKOSWxBFJNRVwAEIMQrvzDHLPquyCGKOptxBFJkoswAEIjn
# 159dh}
#
# 15=[_}
# +/=[_}&*.<@^|%)-;?]{$(
# 10 31 72 ,:>\Y#'+/=[X"&*.<@W!%)-;RVZ$(,:QUY#'+LPTX"&*KOSW!%)JNRVZ$EIMQUY#DHLPTX"CG
# 10 32 72 KOSWxBFJNRVwAEIMQrvzDHLPquyCGKOptxBFJkoswAEIjnrvzDHimquyCdhlptxBcgkoswAbf
# 159dh}
# 15=[_
# 10 34 72 }
# +/=[_}
# *.<@^|%)-;?]{$(,:>\Y#'+/=[X"&*.<@W!%)-;RVZ
# 10 35 72 $(,:QUY#'+/PTX"&*KOSW!%)JNRVZ$EIMQUY#DHLPTX"CGKOSWxBFJNRVwAEIMQUvzDHLPquy
# 10 36 72 CGKOptxBFJkoswAEIjnrvzDHimquyCdhlptxBcgkoswAbfjnrv6aeimqu59dhlpt48cgko37
# 159dh}
# 159[_}
# +/=
# 10 38 72 [_}
# *.<@^|%)-;?]{$(,:>\`#'+/=[X"&*.<@W!%)-;RVZ$(,:QUY#'+/PTX"&*KOSW!%)JNR
# 10 39 72 VZ$(IMQUY#DHLPTX"CGKOSWxBFJNRVwAEIMQUvzDHLPquyCGKOptxBFJNoswAEIjnrvzDHimq
# 159dh}
# 048cg|
# 159[_}
# +/=[_}
# *.<@^|%)-;?]{$(,:>\`#'+
# 10 42 72 /=[X"&*.<@W!%)-;?VZ$(,:QUY#'+/PTX"&*KOSW!%)JNRVZ$(IMQUY#DHLPTX"CGKOSW!BFJ
# 10 43 72 NRVwAEIMQUvzDHLPquyCGKOptxBFJNoswAEIjnrvzDHimquyCGhlptxBcgkoswAbfjnrvzaei
# 159dh}
# 159[_}
# 04<@^|
# +/=[_}
# *.<@^|	)-;?]{$(,:>\`#'+/=[X"&*.<@W!%)-;?VZ$(,:QUY#
# 10 46 72 '+/PTX"&*.OSW!%)JNRVZ$(IMQUY#DHLPTX"CGKOSW!BFJNRVwAEIMQUvzDHLPTuyCGKOptxB
# 10 47 72 FJNoswAEIjnrvzDHimquyCGhlptxBcgkoswAbfjnrvzaeimqu59dhlpt48cgkos37bfjn26a
# 159dh}
# 159[_}
# +/=[_}
# *.<@
# 10 49 72 ^|	)-;?]{$(,:>\`#'+/=[_"&*.<@W!%)-;?VZ$(,:QUY#'+/PTX"&*.OSW!%)JNRVZ$(IMQU
# 10 50 72 Y#'HLPTX"CGKOSW!BFJNRVwAEIMQUvzDHLPTuyCGKOptxBFJNoswAEIMnrvzDHimquyCGhlpt
# 159dhl
# 048cg|	37bf{ 2
# 159[_}
# 1/=[_}
# *.<@^|	)-;?]{$(,:>\`#'+/=[_"&*.
# 10 53 72 <@W!%)-;?VZ$(,:>UY#'+/PTX"&*.OSW!%)JNRVZ$(IMQUY#'HLPTX"CGKOSW!BFJNRVZAEIM
# 10 54 72 QUvzDHLPTuyCGKOptxBFJNoswAEIMnrvzDHimquyCGhlptxBFgkoswAbfjnrvzaeimquy9dhl
# 159dhl
# 159[_}
# 048@^|	3;?]{
# 1/=[_}
# *.<@^|	)-;?]{ (,:>\`#'+/=[_"&*.<@W!%)-;?VZ$(,:>UY#'+/PTX"&
# 10 57 72 *.OSW!%)-NRVZ$(IMQUY#'HLPTX"CGKOSW!BFJNRVZAEIMQUvzDHLPTuyCGKOStxBFJNoswAE
# 159d
# 10 59 72 hl
# 159[_}
# 1/=[_}
# *.<@^|	)-;?]
# 10 60 72 { (,:>\`#'+/=[_"&*.<@^!%)-;?VZ$(,:>UY#'+/PTX"&*.OSW!%)-NRVZ$(IMQUY#'HLPTX
# 10 61 72 "&GKOSW!BFJNRVZAEIMQUvzDHLPTuyCGKOStxBFJNoswAEIMnrvzDHLmquyCGhlptxBFgkosw
# 159dhl
# 15
# 10 63 72 9[_}
# 1/=[_}
# 0.<@^|	)-;?]{ (,:>\`#'+/=[_"&*.<@^!%)-;
# 10 64 72 ?VZ$(,:>UY#'+/=TX"&*.OSW!%)-NRVZ$(IMQUY#'HLPTX"&GKOSW!BFJNRVZAEIMQUYzDHLP
# 10 65 72 TuyCGKOStxBFJNoswAEIMnrvzDHLmquyCGhlptxBFgkoswAEfjnrvzaeimquy9dhlptx8cgko
# 159dhl
# 159d_}
# 048@^|	37?]{ 2:>\`~
# 10 67 72 1/=[_}
# 0.<@^|	)-;?]{ (,:>\`~'+/=[_"&*.<@^!%)-;?VZ$(,:>UY#'+/=TX"&*.OSW!%)
# 10 68 72 -NRVZ$(,MQUY#'HLPTX"&GKOSW!BFJNRVZAEIMQUYzDHLPTuyCGKOStxBFJNRswAEIMnrvzDH
# 10 69 72 LmquyCGhlptxBFgkoswAEfjnrvzaeimquy9dhlptx8cgkos37bfjnr26aeimq159dhl
# 048cg
# 159d_}
# 1/=[_}
# 0.<@^|	)-;?]{ (,:>\`
# 10 71 72 ~'+/=[_"&*.<@^!%)-;?]Z$(,:>UY#'+/=TX"&*.OSW!%)-NRVZ$(,MQUY#'HLPTX"&GKOSW!
# 10 72 72 %FJNRVZAEIMQUYzDHLPTuyCGKOStxBFJNRswAEIMnrvzDHLmquyCGKlptxBFgkoswAEfjnrvz
# -Ps5Ru7[ZC]"Eh *j
# ,Or4Qt6@YB\!Dg~)i	+Nq3Ps5?XA[ZCf}(h *Mp2Or4>Wz
# 11 1 72 @YBe|'g~)Lo1;q3=VybXAd{&I}(Kn0:p2<UxaWzc`%H|'Jm/o1;Tw9Vyb_$G{&Il.n0:Sv8
# -m/Ru7[w9]"Eh$Gj
# -Ps5?u7[ZCf"Eh *M
# ,Or4>
# 11 3 72 t6@YBe!Dg~)L	+Nq3=s5?XAd{Cf}(Kn*Mp2<U4>Wzc`Be|'Jm)Lo1;T3=Vyb_Ad{&Il(Kn0:S
# 11 4 72 2<Uxa^zc`%Hk'Jm/R1;Tw9]yb_$Gj
# -Ps/Ru7[Z9]"Eh Gj
# ,Or
# 11 5 72 .Qt6@Y8\!Dg~Fi	+Nq-Ps5?X7[ZCf}Eh *Mp2Or4>Wz@YBe|'g~)Lo1Nq3=Vy?XAd{&f}(Kn0
# -m/Ru7Tw9]"E_$Gj
# ,
# -Ps5Ru7[ZC]"Eh *j
# ,Or4Qt6@YBe!Dg~)L	+Nq3=s5?XAdZCf}(K
# 11 8 72  *Mp2<r4>WzcYBe|'J~)Lo1;q3=VybXAd{&I}(Kn0:p2<UxaWzc`%Hk'Jm/R1;Tw9]yb_$Gj
# -P/Ru7[w9]"Eh$Gj
# ,O.Qt6@v8\!Dg#Fi	+Nq-Ps5?X7[ZCf}
# 11 10 72 Eh *Mp,Or4>W6@YBe|Dg~)Lo+Nq3=V5?XAd{Cf}(Kn*Mp2<U4>Wzc`Be|'Jm)Lo1;Tw=Vyb_$
# Jm/Ru;Tw9]"b_$Gj
# -Ps/Ru7[ZC
# 11 12 72 ]"Eh *j
# ,Or4Qt6@YB\!Dg~)i	+Nq3Ps5?XA[ZCf}(h *Mp2Or4>Wz@YBe|'g~)Lo1Nq3=Vy?
# -m/Ru7T
# 11 14 72 w9]"E_$Gj
# -Ps5?u7[ZCf"Eh *M
# ,Or4>t6@YBe!Dg~)L	+Nq3=s
# 11 15 72 5?XAdZCf}(K *Mp2<r4>Wzc`Be|'Jm)Lo1;T3=Vyb_Ad{&Il(Kn0:S2<Uxa^zc`%Hk'Jm/R1
# -Ps/Ru7[Z9]"Eh Gj
# ,Or.Qt6@Y8\!Dg~Fi	+Nq-
# 11 17 72 Ps5?X7[ZCf}Eh *Mp,Or4>W6@YBe|Dg~)Lo1Nq3=Vy?XAd{&f}(Kn0Mp2<Ux>Wzc`%e|'JmL
# Jm/Ru7Tw9]"E_$Gj
# ,l.Qt6Sv8\!D^#Fi	+k
# -Ps5Ru7[ZC]"Eh *j
# ,Or4Qt6@YB\!Dg~)i	+Nq3Ps5?XAdZCf}(K *Mp2<r4>WzcYBe|'J~
# 11 20 72 )Lo1;q3=VybXAd{&I}(Kn0:p2<UxaWzc`%H|'Jm/o1;Tw9Vyb_$Gj&Il.Q0:Sv8\xa^#Fi%
# -P/Ru7[w9]"Eh$Gj
# -Ps5?u7[ZCf"Eh *Mp,Or4>W6@YBe|D
# 11 22 72 g~)Lo+Nq3=V5?XAd{Cf}(Kn*Mp2<U4>Wzc`Be|'Jm)Lo1;T3=Vyb_Ad{&Il(Kn0:Sv<Uxa^#c
# Jm/Ru;Tw9]"b_$Gj
# -Ps/Ru7[Z9]"Eh Gj
# ,Or.Qt6@YB\
# 11 24 72 !Dg~)i	+Nq3Ps5?XA[ZCf}(h *Mp2Or4>Wz@YBe|'g~)Lo1Nq3=Vy?XAd{&f}(Kn0Mp2<Ux>W
# -m/Ru7Tw9]"E_$Gj
# ,l.Qt6Sv
# -Ps5?u7[ZCf"Eh *M
# ,Or4>t6@YBe!Dg~)L	+Nq3=s5?XAdZCf}(K *Mp2<r4
# 11 27 72 >WzcYBe|'J~)Lo1;q3=Vyb_Ad{&Il(Kn0:S2<Uxa^zc`%Hk'Jm/R1;Tw9]yb_$Gj&Il.Q0:
# -P/Ru7[w9]"Eh Gj
# ,Or.Qt6@Y8\!Dg~Fi	+Nq-Ps5?X7[ZCf}Eh *Mp,O
# 11 29 72 r4>W6@YBe|Dg~)Lo+Nq3=V5?XAd{Cf}(Kn0Mp2<Ux>Wzc`%e|'JmLo1;Tw=Vyb_$d{&IlKn
# Jm/Ru;Tw9]"b_$Gj
# -Ps5Ru7[ZC]"Eh *j
#
# 11 31 72 ,Or4Qt6@YB\!Dg~)i	+Nq3Ps5?XA[ZCf}(h *Mp2Or4>WzcYBe|'J~)Lo1;q3=VybXAd{&I}(
# -P/Ru7[w9]"Eh$G
# 11 33 72 j
# -Ps5?u7[ZCf"Eh *M
# ,Or4>t6@YBe!Dg~)Lo+Nq3=V5?XAd{Cf
# 11 34 72 }(Kn*Mp2<U4>Wzc`Be|'Jm)Lo1;T3=Vyb_Ad{&Il(Kn0:S2<Uxa^zc`%Hk'Jm/Ru;Tw9]"b_
# 11 35 72 $Gj
# -Ps/Ru7[Z9]"Eh Gj
# ,Or.Qt6@Y8\!Dg~Fi	+Nq-Ps5?XA[Z
# 11 36 72 Cf}(h *Mp2Or4>Wz@YBe|'g~)Lo1Nq3=Vy?XAd{&f}(Kn0Mp2<Ux>Wzc`%e|'JmLo1;Tw=Vy
# -m/Ru7Tw9]"E_$Gj
# -Ps5Ru7
# 11 38 72 [ZC]"Eh *j
# ,Or4>t6@YBe!Dg~)L	+Nq3=s5?XAdZCf}(K *Mp2<r4>WzcYBe|'J~)Lo1;q3=
# -P/R
# 11 40 72 u7[w9]"Eh$Gj
# ,O.Qt6@v8\!Dg~Fi	+Nq-Ps5?X7[ZCf}Eh *Mp,Or4>W6@YBe|Dg~)Lo+Nq
# Jm
# 11 42 72 /Ru;Tw9]"b_$Gj
# -Ps5Ru7[ZC]"Eh *j
# ,Or4Qt6@YB\!Dg~)i	+
# 11 43 72 Nq3Ps5?XA[ZCf}(h *Mp2Or4>Wz@YBe|'g~)Lo1Nq3=VybXAd{&I}(Kn0:p2<UxaWzc`%H|'J
# -m/Ru7Tw9]"Eh$Gj
# ,O.Qt6@v8\!Dg#Fi
# -Ps5?u7[ZCf"Eh *M
# ,Or4>t6@YBe!Dg~)L	+Nq3=s5?XAdZCf}(Kn*Mp2<U4>Wzc`Be|
# 11 46 72 'Jm)Lo1;T3=Vyb_Ad{&Il(Kn0:S2<Uxa^zc`%Hk'Jm/R1;Tw9]yb_$Gj&Il.Qt:Sv8\!a^#
# -Ps/Ru7[Z9]"Eh Gj
# ,Or.Qt6@Y8\!Dg~Fi	+Nq-Ps5?X7[ZCf}Eh *Mp,Or4>Wz@YB
# 11 48 72 e|'g~)Lo1Nq3=Vy?XAd{&f}(Kn0Mp2<Ux>Wzc`%e|'JmLo1;Tw=Vyb_$d{&IlKn0:Sv<Uxa
# -m/Ru7Tw9]"E_$Gj
# -Ps5Ru7[ZC]"Eh *j
# ,Or4Qt6@
# 11 50 72 YB\!Dg~)i	+Nq3=s5?XAdZCf}(K *Mp2<r4>WzcYBe|'J~)Lo1;q3=VybXAd{&I}(Kn0:p2<U
# -P/Ru7[w9]"Eh$Gj
# ,O.Qt
# -Ps5?u7[ZCf}Eh *Mp,Or4>W6@YBe|Dg~)Lo+Nq3=V5?XAd{Cf}(Kn*Mp2
# Jm/Ru;Tw9]"b_$Gj
# Il.
# -Ps/Ru7[Z9]"Eh Gj
# ,Or4Qt6@YB\!Dg~)i	+Nq3Ps5?XA[ZCf}(h *M
# 11 55 72 p2Or4>Wz@YBe|'g~)Lo1Nq3=Vy?XAd{&f}(Kn0Mp2<UxaWzc`%H|'Jm/o1;Tw9Vyb_$G{&Il
# -m/Ru7Tw9]"E_$Gj
# -Ps5?u7[ZCf"Eh
# 11 57 72 *M
# ,Or4>t6@YBe!Dg~)L	+Nq3=s5?XAdZCf}(K *Mp2<r4>WzcYBe|'Jm)Lo1;T3=Vyb_Ad{&
# -Ps/Ru7[Z9]"E
# 11 59 72 h Gj
# ,Or.Qt6@Y8\!Dg~Fi	+Nq-Ps5?X7[ZCf}Eh *Mp,Or4>W6@YBe|Dg~)Lo+Nq3=Vy?XAd
# Jm/Ru;Tw9]
# 11 61 72 "b_$Gj
# -Ps5Ru7[ZC]"Eh *j
# ,Or4Qt6@YB\!Dg~)i	+Nq3Ps5?X
# 11 62 72 A[ZCf}(h *Mp2<r4>WzcYBe|'J~)Lo1;q3=VybXAd{&I}(Kn0:p2<UxaWzc`%H|'Jm/o1;Tw
# -P/Ru7[w9]"Eh$Gj
# -Ps5
# 11 64 72 ?u7[ZCf"Eh *M
# ,Or4>t6@YBe|Dg~)Lo+Nq3=V5?XAd{Cf}(Kn*Mp2<U4>Wzc`Be|'Jm)Lo1;
# Jm/Ru;Tw9]"b_$Gj
# -P
# 11 66 72 s/Ru7[Z9]"Eh Gj
# ,Or.Qt6@Y8\!Dg~Fi	+Nq3Ps5?XA[ZCf}(h *Mp2Or4>Wz@YBe|'g~)Lo
# 11 67 72 1Nq3=Vy?XAd{&f}(Kn0Mp2<Ux>Wzc`%e|'JmLo1;Tw9Vyb_$G{&Il.n0:Sv8Uxa^#F`%Hk
# 11 68 72 -m/Ru7Tw9]"E_$Gj
# -Ps5Ru7[ZCf"Eh *M
# ,Or4>t6@YBe!Dg~)
# 11 69 72 L	+Nq3=s5?XAdZCf}(K *Mp2<r4>WzcYBe|'J~)Lo1;q3=VybXAd{&Il(Kn0:S2<Uxa^zc`%H
# -P/Ru7[w9]"Eh$Gj
# ,Or.Qt6@Y8\!Dg
# 11 71 72 ~Fi	+Nq-Ps5?X7[ZCf}Eh *Mp,Or4>W6@YBe|Dg~)Lo+Nq3=V5?XAd{Cf}(Kn*Mp2<Ux>Wzc`
# Jm/Ru;Tw9]"b_$Gj
# Il.Qt:Sv8\!
# 12 0 72 aYaYaY>v>v>vQ2Q2Q,n,n,nI I I f$f$fA]A]A]7V7V7s;s;s;NNN)k)k)|F|F|F!c!c!
# 12 1 72 @x@x@xS4S4S4p.p.pK
# K
# K
# h&h&hC_C_C_9X9X9X=u=u=1P1P1P+m+m+mH~H~H#e#e#ez\z\z
# 12 2 72 U6U6U6r:r:r:MMj(j(j({E{E{bZbZbZ?w?w?wR3R3R-o-o-oJ	J	J%g%g%gB^B^B^8W8W8
# i'i'iD`D`D`aYaYaY>v>v>
# 12 4 72 2Q2Q2Q,n,n, I I I$f$f$fA]A]AV7V7V7s;s;sNNNk)k)k)|F|F|c!c!c!@x@x@xS4S4S
# 12 5 72 .p.p.pK
# K
# K&h&h&hC_C_C_9X9X9u=u=u=1P1P1m+m+m+~H~H~H#e#e#\z\z\zU6U6U:r:r:r
# 12 6 72 MMMj(j(jE{E{E{bZbZbw?w?w?3R3R3R-o-o-	J	J	J%g%g%gB^B^BW8W8W8t<t<tO0O0O0
# L'i'i'iD`D`DYaYaYav>v>v>2Q2Q2n,n,n,
# 12 8 72  I I f$f$f$]A]A]AV7V7V;s;s;sNNNk)k)kF|F|F|c!c!cx@x@x@4S4S4S.p.p.
# K
# K
# K
# 12 9 72 &h&h&_C_C_CX9X9X9u=u=uP1P1P1m+m+mH~H~H~e#e#e#\z\z\6U6U6U:r:r:rMMM(j(j(j
# 12 10 72 E{E{EZbZbZbw?w?w?3R3R3o-o-o-	J	J	g%g%g%^B^B^BW8W8W<t<t<tO0O0O*l*l*lG}G}G}
# L'i'i'`D`D`DYaYaYav>v>vQ2Q2Q2n,n,nI I I f$f$f$
# 12 12 72 ]A]A]7V7V7V;s;s;NNN)k)k)kF|F|F!c!c!cx@x@xS4S4S4p.p.p.
# K
# K
# h&h&h&_C_C_C
# 12 13 72 X9X9X=u=u=uP1P1P+m+m+mH~H~H~e#e#ez\z\z\6U6U6r:r:r:MMM(j(j({E{E{EZbZbZ?
# 12 14 72 w?w?wR3R3R3o-o-oJ	J	J	g%g%gB^B^B^8W8W8W<t<t<0O0O0O*l*l*lG}G}G"d"d"dy[y[yT
# i'i'i'`D`D`aYaYaY>v>v>vQ2Q2Q,n,n,nI I I$f$f$fA]A]A]7V7V7s
# 12 16 72 ;s;s;NNk)k)k)|F|F|F!c!c!@x@x@xS4S4S4p.p.pK
# K
# K
# h&h&hC_C_C_9X9X9X=u=u=1
# 12 17 72 P1P1P+m+m+~H~H~H#e#e#ez\z\zU6U6U6r:r:rMMMj(j(j({E{E{bZbZbZ?w?w?wR3R3R-
# 12 18 72 o-o-oJ	J	J%g%g%gB^B^B^8W8W8t<t<t<0O0O0l*l*l*}G}G}G"d"d"[y[y[yT5T5T/q/q/qL
# i'i'iD`D`D`aYaYav>v>v>2Q2Q2Q,n,n, I I I$f$f$fA]A]AV7V7V7s;s;sNNNk
# 12 20 72 )k)k)|F|F|c!c!c!@x@x@4S4S4S.p.p.pK
# K
# K&h&h&hC_C_CX9X9X9u=u=u=1P1P1m+m+m+~
# 12 21 72 H~H~e#e#e#\z\z\zU6U6U:r:r:rMMMj(j(jE{E{E{bZbZbw?w?w?3R3R3R-o-o-	J	J	J%
# L'i'i'iD
# 12 23 72 `D`DYaYaYav>v>v>2Q2Q2n,n,n, I I f$f$f$]A]A]AV7V7V;s;s;sNNN)k)k)kF|F|F|c
# 12 24 72 !c!cx@x@x@4S4S4p.p.p.
# K
# K
# K&h&h&_C_C_CX9X9X9u=u=uP1P1P1m+m+mH~H~H~e#e#e#\
# 12 25 72 z\z\6U6U6U:r:r:MMM(j(j(jE{E{EZbZbZbw?w?wR3R3R3o-o-o-	J	J	g%g%g%^B^B^BW
# L'i'i'`D`D`DYaYaY>v
# 12 27 72 >v>vQ2Q2Q2n,n,nI I I f$f$fA]A]A]7V7V7V;s;s;NNN)k)k)kF|F|F!c!c!cx@x@xS4
# 12 28 72 S4S4p.p.p.
# K
# K
# h&h&h&_C_C_9X9X9X=u=u=uP1P1P+m+m+mH~H~H#e#e#ez\z\z\6U6U6r:
# 12 29 72 r:r:MMj(j(j({E{E{EZbZbZ?w?w?wR3R3R3o-o-oJ	J	J	g%g%gB^B^B^8W8W8W<t<t<0O
# i'i'i'`D`D`aYaYaY>v>v>vQ2Q2Q,n
# 12 31 72 ,n,nI I I$f$f$fA]A]A]7V7V7s;s;s;NNk)k)k)|F|F|F!c!c!@x@x@xS4S4S.p.p.pK
#
# 12 32 72 K
# K
# h&h&hC_C_C_9X9X9u=u=u=1P1P1P+m+m+~H~H~H#e#e#ez\z\zU6U6U6r:r:rMMMj(
# 12 33 72 j(j({E{E{bZbZbZ?w?w?3R3R3R-o-o-oJ	J	J%g%g%gB^B^BW8W8W8t<t<t<0O0O0l*l*l*}G
# i'i'iD`D`D`aYaYav>v>v>2Q2Q2Q,n,n, I I I$f
# 12 35 72 $f$]A]A]AV7V7V7s;s;sNNNk)k)kF|F|F|c!c!c!@x@x@4S4S4S.p.p.pK
# K
# K&h&h&hC_
# 12 36 72 C_CX9X9X9u=u=u=1P1P1m+m+m+~H~H~e#e#e#\z\z\zU6U6U:r:r:rMMM(j(j(jE{E{E{bZ
# 12 37 72 bZbw?w?w?3R3R3o-o-o-	J	J	J%g%g%^B^B^BW8W8W8t<t<tO0O0O0l*l*lG}G}G}d"d"d"[y
# L'i'i'iD`D`DYaYaYav>v>vQ2Q2Q2n,n,n, I I f$f$f$]A]A]AV7
# 12 39 72 V7V;s;s;sNNN)k)k)kF|F|F|c!c!cx@x@x@4S4S4p.p.p.
# K
# K
# K&h&h&_C_C_CX9X9X=u=
# 12 40 72 u=uP1P1P1m+m+mH~H~H~e#e#ez\z\z\6U6U6U:r:r:MMM(j(j(jE{E{EZbZbZbw?w?wR3R
# 12 41 72 3R3o-o-o-	J	J	g%g%g%^B^B^8W8W8W<t<t<tO0O0O*l*l*lG}G}G"d"d"dy[y[y[5T5T5q/q
# i'i'i'`D`D`DYaYaY>v>v>vQ2Q2Q2n,n,nI I I f$f$fA]A]A]7V7V7V;s;s;N
# 12 43 72 NN)k)k)|F|F|F!c!c!cx@x@xS4S4S4p.p.pK
# K
# K
# h&h&h&_C_C_9X9X9X=u=u=uP1P1P+m+
# 12 44 72 m+mH~H~H#e#e#ez\z\z\6U6U6r:r:r:MMj(j(j({E{E{EZbZbZ?w?w?wR3R3R-o-o-oJ	J
# i'i
# 12 46 72 'i'`D`D`aYaYaY>v>v>2Q2Q2Q,n,n,nI I I$f$f$fA]A]AV7V7V7s;s;s;NNk)k)k)|F|
# 12 47 72 F|c!c!c!@x@x@xS4S4S.p.p.pK
# K
# K
# h&h&hC_C_C_9X9X9u=u=u=1P1P1P+m+m+~H~H~H#e#
# 12 48 72 e#\z\z\zU6U6U6r:r:rMMMj(j(jE{E{E{bZbZbZ?w?w?3R3R3R-o-o-oJ	J	J%g%g%gB^B
# L'i'i'iD`D`D`aYa
# 12 50 72 Yav>v>v>2Q2Q2n,n,n, I I I$f$f$]A]A]AV7V7V7s;s;sNNNk)k)kF|F|F|c!c!c!@x@
# middle chapters of pools 1073
# number of pools:  1000
# pool size: 73
# dilution-dependent false negative rate 0.01

# %%
#check the extent of overlap between our pools
check_intersections = np.zeros((max_pools,max_pools))
for i in range(0, max_pools):
    for j in range(0, max_pools):
        check_intersections[i,j] = len(list(set(pools[i]) & set(pools[j])))
#         if check_intersections[i, j] > 1:
#             print(small_code_pools[i], small_code_pools[j],i,j)
#             print(set(small_code_pools[i]))
#             print(set(pools[i]))
            
#             print(set(small_code_pools[j]))
#             print(set(pools[j]), "\n \n \n")
# #             print(len(list(set(pools[i]) & set(pools[j]))))
        
plt.figure(figsize=(10,10))        
plt.imshow(check_intersections,cmap="prism")  
plt.xlabel("pool i [number of overlapping samples in pool]")
plt.ylabel("pool j [number of overlapping samples in pool]")
plt.show()
plt.close()

# %%
def run_test(samples, pool_dictionary):
    pool_result = 0
    false_positive = 0
    false_negative = 0
    for ID in samples:
        if pool_dictionary[ID] == 1:
            if random.random() < false_negative_rate:
                false_negative = 1
            else:
                pool_result = 1
        else:
            if random.random() < false_positive_rate:
                pool_result = 1 
                false_positive = 1
        if pool_result == 1 and false_negative == 1:
            false_negative = 0 #silent false negative since some other sample tested positive in the pool
    return pool_result, false_negative, false_positive


# conduct the tests now on each pool - sort them into negative and positive groups
positive_pools = []
negative_pools = []
for pool in pools:
    if run_test(pool, pool_dictionary)[0] == 1:
        positive_pools.append(list(pool))
    else:
        negative_pools.append(list(pool))        
        
flat_pos_pools = [val for sublist in positive_pools for val in sublist]
flat_neg_pools = [val for sublist in negative_pools for val in sublist]

# %%
# assess the accuracy by comparing with the dictionary of true positives
errors = 0
correctly_identified = 0
correctly_identidied_positives = 0
correctly_identidied_negatives = 0
false_pos_errors = 0
false_neg_errors = 0
final_positives = list(set(flat_pos_pools) - set(flat_neg_pools))
for i in set(final_positives):
    if pool_dictionary[i] != 1:
        errors += 1
        false_pos_errors += 1
    else :
        correctly_identified += 1
        correctly_identidied_positives += 1
for i in set(flat_neg_pools):
    if pool_dictionary[i] != 0:
        errors += 1
        false_neg_errors += 1
    else :
        correctly_identified += 1  
        correctly_identidied_negatives += 1
#print("errors/sample", errors/patient_samples)        
print("false pos/ neg sample", false_pos_errors/true_negatives)        
print("false neg/pos sample", false_neg_errors/true_positives)  
print("fold efficiency: ", patient_samples/number_of_pools,"samples/test")
print("coverage (redundancy):  pools*size / samples: ", (number_of_pools*pool_size)/patient_samples, "x")
print("correctly identified rate", correctly_identified/patient_samples, "correct results/sample")


sizes = [correctly_identidied_positives, correctly_identidied_negatives, false_pos_errors, false_neg_errors]
# print(np.sum(sizes))
labels = ["correctly ID'd +","correctly ID'd -","false +","false -"]
explode = (0.1, 0 , .2,.7)
plt.figure(figsize=(10,10))        
plt.pie(sizes, labels=labels, explode = explode,colors=["c","b","grey","r"],
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()
plt.close()



# sizes = [correctly_identidied_positives, false_pos_errors]
# # print(np.sum(sizes))
# labels = ["correctly identified positives","false +"]
# explode = (0.1, 0)
# plt.figure(figsize=(10,10))        
# plt.pie(sizes, labels=labels, explode = explode,colors=["b","grey"],
# autopct='%1.1f%%', shadow=True, startangle=140)
# plt.axis('equal')
# plt.show()
# plt.close()

# sizes = [correctly_identidied_negatives, false_neg_errors]
# # print(np.sum(sizes))
# labels = ["correctly identified negatives","false -"]
# explode = (0.1, 0)
# plt.figure(figsize=(10,10))        
# plt.pie(sizes, labels=labels, explode = explode,colors=["b","r"],
# autopct='%1.1f%%', shadow=True, startangle=140)
# plt.axis('equal')
# plt.show()
# plt.close()
# Out:
# false pos/ neg sample 0.19962085308056873
# false neg/pos sample 0.018518518518518517
# fold efficiency:  13.877604166666666 samples/test
# coverage (redundancy):  pools*size / samples:  5.260273972602739 x
# correctly identified rate 0.8022142991180334 correct results/sample

# %%
# show intersection between positive pools
max_pos_pools = len(positive_pools)
intersect_final = []
check_pos_intersections = np.zeros((max_pos_pools,max_pos_pools))
for i in range(0, max_pos_pools):
    for j in range(0, max_pos_pools):
        current_intersect = list(set(positive_pools[i]) & set(positive_pools[j]))
        check_pos_intersections[i,j] = len(current_intersect)
                
plt.imshow(check_pos_intersections,cmap="jet")   
plt.show()
plt.close()
