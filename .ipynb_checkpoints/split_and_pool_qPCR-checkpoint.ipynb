# %% [markdown]
# # pooling simulation
# ## model assumptions
# - basic idea is to pool samples, test a pool, and then divide the pool into smaller pools
# - if a pool tests positive, it is kept in the queue and split into two smaller pools
# - if a pool tests negative, it and all its constituents are removed from the testing queue
# - if a pool is reduced to a single sample, it is a terminal test, its result is taken to be the patient result
#
# - a false positive rate of 1.0 relative to f and false negative rate of 0.1 are assumed
#
# - assumed perfect apriori knowledge of the average rate of positive tests
# - used this number to compute the expected number of positive samples in the total sample population
# - this is necessary to determine the initial pool size, each pool should have on average 1 positive sample
# - thus a population rate of 0.5 positive or higher will likely be super-critical, leading to more tests with the pooling method than simply testing every sample individually, since tests will be wasted on pools with many positive samples in each fraction
# - basic binary division followed for each splitting

# %%
def split_pool(pool):
    pool_size = len(pool)
    split_1 = pool[0:int(pool_size/2)]
    split_2 = pool[int(pool_size/2):]
    #print(len(split_1), len(split_2))
    return(split_1, split_2)

def run_test(samples, pool_dictionary):
    pool_result = 0
    false_positive = 0
    false_negative = 0
    for ID in samples:
        if pool_dictionary[ID] == 1:
            if random.random() < false_negative_rate:
                false_negative = 1
            else:
                pool_result = 1
        else:
            if random.random() < false_positive_rate:
                pool_result = 1 
                false_positive = 1
        if pool_result == 1 and false_negative == 1:
            false_negative = 0 #silent false negative since some other sample tested positive in the pool
    return pool_result, false_negative, false_positive

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import uuid
### initialize test pool ###

sizes = list(range(10,200,10))
false_negatives = np.zeros(len(sizes))
false_positives = np.zeros(len(sizes))
numbers_of_samples = np.zeros(len(sizes))
numbers_of_tests = np.zeros(len(sizes))
tests_to_samples = np.zeros(len(sizes))
true_positive_rate = 0.01345

global false_negative_rate

global false_positive_rate
# false_positive_rate = 0.01345
false_positive_rate = 0.1
false_negative_rates = np.linspace(0.1, 0.1,1)

for fp in range(0, len(false_negative_rates)):
    false_negative_rate = false_negative_rates[fp]
    print("false_neg_rate ",false_negative_rate)
    true_positive_rates = np.linspace(0.01, 0.2,50)
    test_efficiencies = np.zeros(len(true_positive_rates))
    for rate in range(0,len(true_positive_rates)):
        true_positive_rate = true_positive_rates[rate]
        print("true pos rate", true_positive_rate)
        for condition in range(0, len(sizes)):
            patient_samples = sizes[condition]**2

            

            grand_test_pool = np.zeros((patient_samples))
            ids_grand_pool = np.zeros((patient_samples),uuid.UUID)
            pool_dictionary = {}


            true_positives = 0
            positive_patients= []
            # positive_patients = random.choices(range(0,patient_samples),k=int(true_positive_rate*patient_samples))
            for i in range(0,patient_samples):
                ID = uuid.uuid4()
                ids_grand_pool[i] = ID
                if random.random() <= true_positive_rate:
                    true_positives += 1
                    grand_test_pool[i] = 1
                    pool_dictionary[ID] =1
                    positive_patients.append(i)
                else:
                    pool_dictionary[ID] =0

            #initial split
            guess_rate = true_positive_rate
            guess_average_multiplicity = patient_samples*guess_rate
            shannon_information = guess_rate * np.log2(guess_rate) 
    #         print(-2/shannon_information, " necessary binary divisions per positive case")


            main_queue = []
            split_size = int(1/guess_rate)
            for multiple in range(0, int(guess_average_multiplicity)):
                main_queue.append(ids_grand_pool[split_size*multiple:split_size*multiple+split_size])

    #         print("split size", split_size)
    #         print("average multiplicity", guess_average_multiplicity)
    #         print("initial queue size", len(main_queue))


            total_false_negatives, total_false_positives = 0,0
            MASTER_TEST_COUNTER = 0
            POSITIVE_IDS = 0
            while len(main_queue) > 0:

                if len(main_queue[0]) > 1:
                    pool_a, pool_b = split_pool(main_queue[0])    


                    MASTER_TEST_COUNTER += 1
                    main_queue.remove(main_queue[0])
                    A, afalse_positive, afalse_negative = run_test(pool_a, pool_dictionary)
                    if A == 1:
                        main_queue.append(pool_a)
                        if len(pool_a) == 1:
                            POSITIVE_IDS += 1
                            total_false_negatives += afalse_negative
                            total_false_positives += afalse_positive
                    else:
                        if len(pool_a) == 1:
                            total_false_negatives += afalse_negative
                            total_false_positives += afalse_positive


                    MASTER_TEST_COUNTER += 1
                    B, bfalse_positive, bfalse_negative = run_test(pool_b, pool_dictionary)
                    if B == 1:
                        main_queue.append(pool_b)
                        if len(pool_b) == 1:
                            POSITIVE_IDS += 1
                            total_false_negatives += bfalse_negative
                            total_false_positives += bfalse_positive
                    else:
                        if len(pool_b) == 1:
                            total_false_negatives += bfalse_negative
                            total_false_positives += bfalse_positive


                else:
                    MASTER_TEST_COUNTER += 1
                    C, cfalse_positive, cfalse_negative = run_test(main_queue[0], pool_dictionary)
                    total_false_negatives += cfalse_negative
                    total_false_positives += cfalse_positive
                    if C == 1:
                        POSITIVE_IDS += 1
        #                 print("+")
                    main_queue.remove(main_queue[0])
    #         print("total positive IDs: ", POSITIVE_IDS)        
    #         print("true positives: ", true_positives)
    #         print("number of tests: ", MASTER_TEST_COUNTER)
    #         print("number of samples: ", patient_samples)
    #         print("false positives: ", total_false_positives)
    #         print("false negatives: ", total_false_negatives)

            false_negatives[condition] = total_false_negatives
            false_positives[condition] = total_false_positives
            numbers_of_samples[condition] = patient_samples
            numbers_of_tests[condition] = MASTER_TEST_COUNTER
            tests_to_samples[condition] = MASTER_TEST_COUNTER/patient_samples

        test_efficiencies[rate] = np.mean(tests_to_samples)

    plt.plot(true_positive_rates, test_efficiencies)

plt.xlabel("true positive rate")
plt.ylabel("ratio of tests/samples" )
plt.show()
plt.close()
# Out:
# false_neg_rate  0.1
# true pos rate 0.01
# true pos rate 0.013877551020408163
# true pos rate 0.017755102040816328
# true pos rate 0.021632653061224492
# true pos rate 0.025510204081632654
# true pos rate 0.029387755102040815
# true pos rate 0.03326530612244898
# true pos rate 0.037142857142857144
# true pos rate 0.041020408163265305
# true pos rate 0.04489795918367347
# true pos rate 0.048775510204081635
# true pos rate 0.052653061224489796
# true pos rate 0.056530612244897964
# true pos rate 0.060408163265306125
# true pos rate 0.06428571428571428
# true pos rate 0.06816326530612245
# true pos rate 0.07204081632653062
# true pos rate 0.07591836734693877
# true pos rate 0.07979591836734694
# true pos rate 0.08367346938775509
# true pos rate 0.08755102040816326
# true pos rate 0.09142857142857143
# true pos rate 0.09530612244897958
# true pos rate 0.09918367346938775
# true pos rate 0.10306122448979592
# true pos rate 0.10693877551020407
# true pos rate 0.11081632653061224
# true pos rate 0.11469387755102041
# true pos rate 0.11857142857142856
# true pos rate 0.12244897959183673
# true pos rate 0.1263265306122449
# true pos rate 0.13020408163265307
# true pos rate 0.13408163265306122
# true pos rate 0.1379591836734694
# true pos rate 0.14183673469387756
# true pos rate 0.1457142857142857
# true pos rate 0.1495918367346939
# true pos rate 0.15346938775510205
# true pos rate 0.1573469387755102
# true pos rate 0.16122448979591839
# true pos rate 0.16510204081632654
# true pos rate 0.1689795918367347
# true pos rate 0.17285714285714288
# true pos rate 0.17673469387755103
# true pos rate 0.18061224489795918
# true pos rate 0.18448979591836737
# true pos rate 0.18836734693877552
# true pos rate 0.19224489795918367
# true pos rate 0.19612244897959186
# true pos rate 0.2

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import uuid
### initialize test pool ###

sizes = list(range(10,200,10))
false_negatives = np.zeros(len(sizes))
false_positives = np.zeros(len(sizes))
numbers_of_samples = np.zeros(len(sizes))
numbers_of_tests = np.zeros(len(sizes))
tests_to_samples = np.zeros(len(sizes))
true_positive_rate = 0.01345

global false_negative_rate

global false_positive_rate
# false_positive_rate = 0.01345
false_positive_rate = 0.1

false_negative_rate = .1
print("false_neg_rate ",false_negative_rate)

true_positive_rate = .01
print("true pos rate", true_positive_rate)
patient_samples = 100**2



grand_test_pool = np.zeros((patient_samples))
ids_grand_pool = np.zeros((patient_samples),uuid.UUID)
pool_dictionary = {}


true_positives = 0
positive_patients= []
# positive_patients = random.choices(range(0,patient_samples),k=int(true_positive_rate*patient_samples))
for i in range(0,patient_samples):
    ID = uuid.uuid4()
    ids_grand_pool[i] = ID
    if random.random() <= true_positive_rate:
        true_positives += 1
        grand_test_pool[i] = 1
        pool_dictionary[ID] =1
        positive_patients.append(i)
    else:
        pool_dictionary[ID] =0

#initial split
guess_rate = true_positive_rate
guess_average_multiplicity = patient_samples*guess_rate
shannon_information = guess_rate * np.log2(guess_rate) 
#         print(-2/shannon_information, " necessary binary divisions per positive case")


main_queue = []
split_size = int(1/guess_rate)
for multiple in range(0, int(guess_average_multiplicity)):
    main_queue.append(ids_grand_pool[split_size*multiple:split_size*multiple+split_size])

#         print("split size", split_size)
#         print("average multiplicity", guess_average_multiplicity)
#         print("initial queue size", len(main_queue))


total_false_negatives, total_false_positives = 0,0
MASTER_TEST_COUNTER = 0
POSITIVE_IDS = 0
while len(main_queue) > 0:

    if len(main_queue[0]) > 1:
        pool_a, pool_b = split_pool(main_queue[0])    


        MASTER_TEST_COUNTER += 1
        main_queue.remove(main_queue[0])
        A, afalse_positive, afalse_negative = run_test(pool_a, pool_dictionary)
        if A == 1:
            main_queue.append(pool_a)
            if len(pool_a) == 1:
                POSITIVE_IDS += 1
                total_false_negatives += afalse_negative
                total_false_positives += afalse_positive
        else:
            if len(pool_a) == 1:
                total_false_negatives += afalse_negative
                total_false_positives += afalse_positive


        MASTER_TEST_COUNTER += 1
        B, bfalse_positive, bfalse_negative = run_test(pool_b, pool_dictionary)
        if B == 1:
            main_queue.append(pool_b)
            if len(pool_b) == 1:
                POSITIVE_IDS += 1
                total_false_negatives += bfalse_negative
                total_false_positives += bfalse_positive
        else:
            if len(pool_b) == 1:
                total_false_negatives += bfalse_negative
                total_false_positives += bfalse_positive


    else:
        MASTER_TEST_COUNTER += 1
        C, cfalse_positive, cfalse_negative = run_test(main_queue[0], pool_dictionary)
        total_false_negatives += cfalse_negative
        total_false_positives += cfalse_positive
        if C == 1:
            POSITIVE_IDS += 1
#                 print("+")
        main_queue.remove(main_queue[0])
#         print("total positive IDs: ", POSITIVE_IDS)        
#         print("true positives: ", true_positives)
#         print("number of tests: ", MASTER_TEST_COUNTER)
#         print("number of samples: ", patient_samples)
#         print("false positives: ", total_false_positives)
#         print("false negatives: ", total_false_negatives)

#     false_negatives[condition] = total_false_negatives
#     false_positives[condition] = total_false_positives
#     numbers_of_samples[condition] = patient_samples
#     numbers_of_tests[condition] = MASTER_TEST_COUNTER
#     tests_to_samples[condition] = MASTER_TEST_COUNTER/patient_samples

# test_efficiencies[rate] = np.mean(tests_to_samples)

# plt.plot(true_positive_rates, test_efficiencies)

# plt.xlabel("true positive rate")
# plt.ylabel("ratio of tests/samples" )
# plt.show()
# plt.close()
# Out:
# false_neg_rate  0.1
# true pos rate 0.01

# %%
plt.imshow(np.reshape(grand_test_pool,[int(np.sqrt(len(grand_test_pool))),int(np.sqrt(len(grand_test_pool)))]))

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import uuid
from itertools import combinations
### initialize test pool ###

true_positive_rate = 0.1

global false_negative_rate
global false_positive_rate
# false_positive_rate = 0.01345
false_positive_rate = 0
false_negative_rate = 0.1
true_positive_rate = .03
patient_samples = 10**2


grand_test_pool = np.zeros((patient_samples))
ids_grand_pool = np.zeros((patient_samples),uuid.UUID)
pool_dictionary = {}


true_positives = 0
positive_patients= []
# positive_patients = random.choices(range(0,patient_samples),k=int(true_positive_rate*patient_samples))
for i in range(0,patient_samples):
    ID = uuid.uuid4()
    ids_grand_pool[i] = ID
    if random.random() <= true_positive_rate:
        true_positives += 1
        grand_test_pool[i] = 1
        pool_dictionary[ID] =1
        positive_patients.append(i)
    else:
        pool_dictionary[ID] =0




#tally true positive IDs, false positive IDs, score accuracy
#minimization with constraints, accuracy must be 90% with minimization on number of tests

# %%
combos = list(combinations(ids_grand_pool, 3))
numberofcombos = len(combos)
print(numberofcombos)
number_of_pools = 100
pools = []
pools.append(combos[0])
for pool in range(0, number_of_pools):
    for i in range(0,numberofcombos):
        if len(list(set(combos[0]) & set(combos[i]))) == 0:
            pools.append(combos[i])
            break
# Out:
# 161700

# %%
#uniform split
def divide_list(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]


        
pool_size = int(np.sqrt(patient_samples))

max_pools = int(patient_samples)
number_of_pools = 0
pools = []


for i in range(0, len(ids_grand_pool), pool_size):
    pools.append(list(ids_grand_pool[i:i+pool_size]))
        
        
# # pools = list(divide_list(ids_grand_pool, pool_size))
number_of_pools += len(pools)
chapter_size = len(pools)
chapter = 0
while number_of_pools < max_pools:
    for page in range(0,chapter_size):
        next_pool = []
        for item in range(0,pool_size):
            next_pool.append(pools[chapter_size*chapter+(page+item)%chapter_size][item])
        pools.append(next_pool)
        number_of_pools += 1
        if number_of_pools >= max_pools: break
    chapter += 1

# %%
check_intersections = np.zeros((max_pools,max_pools))
for i in range(0, max_pools):
    for j in range(0, max_pools):
        check_intersections[i,j] = len(list(set(pools[i]) & set(pools[j])))
plt.imshow(check_intersections,cmap="Greys")   
plt.show()
plt.close()

# %%
positive_pools = []
negative_pools = []
for pool in pools:
    if run_test(pool, pool_dictionary)[0] == 1:
        positive_pools.append(list(pool))
    else:
        negative_pools.append(list(pool))

# %%
flat_pos_pools = [val for sublist in positive_pools for val in sublist]
flat_neg_pools = [val for sublist in negative_pools for val in sublist]

# %%
errors = 0
final_positives = list(set(flat_pos_pools) - set(flat_neg_pools))
for i in final_positives:
    if pool_dictionary[i] != 1:
        errors += 1
for i in flat_neg_pools:
    if pool_dictionary[i] != 0:
        errors += 1
print(errors)
# Out:
# 2

# %%
max_pos_pools = len(positive_pools)
intersect_final = []
check_pos_intersections = np.zeros((max_pos_pools,max_pos_pools))
for i in range(0, max_pos_pools):
    for j in range(0, max_pos_pools):
        current_intersect = list(set(positive_pools[i]) & set(positive_pools[j]))
        check_pos_intersections[i,j] = len(current_intersect)
                
plt.imshow(check_pos_intersections,cmap="Greys")   
plt.show()
plt.close()

# %%
[val for sublist in intersect_final[cluster] for val in sublist]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-8161e95ceb1e> in <module>
# ----> 1 [val for sublist in intersect_final[cluster] for val in sublist]
#
# <ipython-input-175-8161e95ceb1e> in <listcomp>(.0)
# ----> 1 [val for sublist in intersect_final[cluster] for val in sublist]
#
# TypeError: 'UUID' object is not iterable

# %%
[val for sublist in positive_pools for val in sublist]
# Out:
# [UUID('557fd84e-e3d6-458b-9953-b24b1a93ff9a'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('1418f6a9-be26-4dfd-9f12-d5d53f3d49fb'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('1981cc90-f8b3-4ddb-ba45-debf8c2a83b8'),
#  UUID('c5d6c4a3-8367-46e6-9aeb-883430de7a1c'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('b4b9d1ac-8617-4f97-95a5-6bf653d49a3f'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('58bfe86f-ada2-4091-aad3-8f9347c54b6e'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('30f21c66-ed3d-4305-b6de-86a6033eb9b5'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('392ce536-aeaf-42da-bc58-39bc83daf173'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('03943303-065c-4a11-8bee-e62b46cc90ad'),
#  UUID('c1d28700-c837-4548-8121-1d71356b7949'),
#  UUID('7706fdce-c5e1-4a56-910c-b9391722c2e4'),
#  UUID('4af53356-0927-49fe-a206-0fb706daa4a7'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('42ed156e-3ca7-4872-9630-5148623cf1d0'),
#  UUID('266ed1ce-932a-4060-aac1-de33e13e27a4'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('e8cac908-99e2-486a-831e-ad0f23a7af01'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('20a8355f-a771-4bd1-99d7-126e38701e0f'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('cc4423f7-a1b7-4551-8ebc-0bc062a19bc6'),
#  UUID('99795850-4676-49ba-819b-c4db9f43050e'),
#  UUID('220eea77-bcb0-40ac-b4eb-de380125e616'),
#  UUID('7e30ca6a-9f82-4ac5-8ff1-57ecd50c4db9'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('0ca19315-b147-4cc9-a9ed-6fef3a978395'),
#  UUID('e8a4e9e8-216a-4645-bc3a-b0769133cd85'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('4da669e1-72a7-40dd-b0b1-d47518a482d4'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('abad3b10-ae48-443b-9929-a39838c5e50d'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('6ab5c4a9-366e-47c2-9ae5-3568c42a6231'),
#  UUID('70743eeb-bac5-4d7f-b338-dee00391feb5'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('d3cff3ea-7556-408d-9458-dc65f0889b43'),
#  UUID('311dc442-b45c-495c-b46d-42c5c601ed28'),
#  UUID('a8c1f20c-0371-4331-85fd-bfbbc212e54f'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('3fa99cc8-6f10-488e-af7b-bf70ca8e224d'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('454e2574-c86b-4166-8daa-0d49e5eeb4c7'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('82b14db6-023f-4e08-95e3-1bb0d873c474'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('cc4423f7-a1b7-4551-8ebc-0bc062a19bc6'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('82b14db6-023f-4e08-95e3-1bb0d873c474'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('387c0e68-c240-4f41-b1a4-2441bc3eb2e8'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f'),
#  UUID('392ce536-aeaf-42da-bc58-39bc83daf173'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('7f35d4a5-6c7c-4a11-aec5-477c985e6549'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('6ab5c4a9-366e-47c2-9ae5-3568c42a6231'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('ad37042d-a227-4eed-8e62-7d946c4134e2'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('dbb5b763-f914-479d-b86d-3866a35b5ca1'),
#  UUID('43459dc8-6f71-40a3-9226-6c8685b6bdd5'),
#  UUID('c5d6c4a3-8367-46e6-9aeb-883430de7a1c'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('e8a4e9e8-216a-4645-bc3a-b0769133cd85'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('a8fa62a7-f798-4c72-96b6-6ec072cf2e0c'),
#  UUID('0d69f677-7c10-4e07-b68e-d3ae0f879af6'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('4af53356-0927-49fe-a206-0fb706daa4a7'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('1d20d06d-2805-4a0c-b621-81f8742ba010'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('c1d28700-c837-4548-8121-1d71356b7949'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('220eea77-bcb0-40ac-b4eb-de380125e616'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('311dc442-b45c-495c-b46d-42c5c601ed28'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('f27a49e9-2949-4185-afa5-e354b1fe005f'),
#  UUID('557fd84e-e3d6-458b-9953-b24b1a93ff9a'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('70743eeb-bac5-4d7f-b338-dee00391feb5'),
#  UUID('ad37042d-a227-4eed-8e62-7d946c4134e2'),
#  UUID('c5d6c4a3-8367-46e6-9aeb-883430de7a1c'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('a8c1f20c-0371-4331-85fd-bfbbc212e54f'),
#  UUID('f27a49e9-2949-4185-afa5-e354b1fe005f'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('4da669e1-72a7-40dd-b0b1-d47518a482d4'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('43459dc8-6f71-40a3-9226-6c8685b6bdd5'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('abad3b10-ae48-443b-9929-a39838c5e50d'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('b0ea73d5-8eae-477b-8049-031441b32ac8'),
#  UUID('266ed1ce-932a-4060-aac1-de33e13e27a4'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('e8cac908-99e2-486a-831e-ad0f23a7af01'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('387c0e68-c240-4f41-b1a4-2441bc3eb2e8'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('1404a72d-af7c-4bff-ba57-86471fa61092'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('7706fdce-c5e1-4a56-910c-b9391722c2e4'),
#  UUID('220eea77-bcb0-40ac-b4eb-de380125e616'),
#  UUID('d3cff3ea-7556-408d-9458-dc65f0889b43'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('42ed156e-3ca7-4872-9630-5148623cf1d0'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('95b94843-c428-492e-af64-ed6c1a6dc0b9'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('b471c9f6-1787-4343-9f0b-ab5cfb7e55c8'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('d15efeb8-85c6-4dba-a290-6c76258e6704'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('03943303-065c-4a11-8bee-e62b46cc90ad'),
#  UUID('cc4423f7-a1b7-4551-8ebc-0bc062a19bc6'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('8e567567-05b3-4a8b-a990-3df9592fd7e9'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('0ca19315-b147-4cc9-a9ed-6fef3a978395'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('1d20d06d-2805-4a0c-b621-81f8742ba010'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('454e2574-c86b-4166-8daa-0d49e5eeb4c7'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('557fd84e-e3d6-458b-9953-b24b1a93ff9a'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('6ab5c4a9-366e-47c2-9ae5-3568c42a6231'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('7706fdce-c5e1-4a56-910c-b9391722c2e4'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('7f35d4a5-6c7c-4a11-aec5-477c985e6549'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('0ca19315-b147-4cc9-a9ed-6fef3a978395'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('20a8355f-a771-4bd1-99d7-126e38701e0f'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('b471c9f6-1787-4343-9f0b-ab5cfb7e55c8'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('f27a49e9-2949-4185-afa5-e354b1fe005f'),
#  UUID('392ce536-aeaf-42da-bc58-39bc83daf173'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('1404a72d-af7c-4bff-ba57-86471fa61092'),
#  UUID('58bfe86f-ada2-4091-aad3-8f9347c54b6e'),
#  UUID('99795850-4676-49ba-819b-c4db9f43050e'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('a8c1f20c-0371-4331-85fd-bfbbc212e54f'),
#  UUID('b0ea73d5-8eae-477b-8049-031441b32ac8'),
#  UUID('266ed1ce-932a-4060-aac1-de33e13e27a4'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('0d69f677-7c10-4e07-b68e-d3ae0f879af6'),
#  UUID('c1d28700-c837-4548-8121-1d71356b7949'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('8e567567-05b3-4a8b-a990-3df9592fd7e9'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('3fa99cc8-6f10-488e-af7b-bf70ca8e224d'),
#  UUID('1418f6a9-be26-4dfd-9f12-d5d53f3d49fb'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('abad3b10-ae48-443b-9929-a39838c5e50d'),
#  UUID('5dd1ddd8-94cd-4af3-9418-18e5e058bb07'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('95b94843-c428-492e-af64-ed6c1a6dc0b9'),
#  UUID('03943303-065c-4a11-8bee-e62b46cc90ad'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('ad37042d-a227-4eed-8e62-7d946c4134e2'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('7e30ca6a-9f82-4ac5-8ff1-57ecd50c4db9'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('70743eeb-bac5-4d7f-b338-dee00391feb5'),
#  UUID('43459dc8-6f71-40a3-9226-6c8685b6bdd5'),
#  UUID('4af53356-0927-49fe-a206-0fb706daa4a7'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('30f21c66-ed3d-4305-b6de-86a6033eb9b5'),
#  UUID('e8a4e9e8-216a-4645-bc3a-b0769133cd85'),
#  UUID('d15efeb8-85c6-4dba-a290-6c76258e6704'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('1981cc90-f8b3-4ddb-ba45-debf8c2a83b8'),
#  UUID('e8cac908-99e2-486a-831e-ad0f23a7af01'),
#  UUID('d3cff3ea-7556-408d-9458-dc65f0889b43'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('1d20d06d-2805-4a0c-b621-81f8742ba010'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('4da669e1-72a7-40dd-b0b1-d47518a482d4'),
#  UUID('dbb5b763-f914-479d-b86d-3866a35b5ca1'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('220eea77-bcb0-40ac-b4eb-de380125e616'),
#  UUID('82b14db6-023f-4e08-95e3-1bb0d873c474'),
#  UUID('b4b9d1ac-8617-4f97-95a5-6bf653d49a3f'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('557fd84e-e3d6-458b-9953-b24b1a93ff9a'),
#  UUID('20a8355f-a771-4bd1-99d7-126e38701e0f'),
#  UUID('1404a72d-af7c-4bff-ba57-86471fa61092'),
#  UUID('c1d28700-c837-4548-8121-1d71356b7949'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('c5d6c4a3-8367-46e6-9aeb-883430de7a1c'),
#  UUID('7e30ca6a-9f82-4ac5-8ff1-57ecd50c4db9'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('0d69f677-7c10-4e07-b68e-d3ae0f879af6'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('454e2574-c86b-4166-8daa-0d49e5eeb4c7'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('95b94843-c428-492e-af64-ed6c1a6dc0b9'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('b471c9f6-1787-4343-9f0b-ab5cfb7e55c8'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('dbb5b763-f914-479d-b86d-3866a35b5ca1'),
#  UUID('7706fdce-c5e1-4a56-910c-b9391722c2e4'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('5dd1ddd8-94cd-4af3-9418-18e5e058bb07'),
#  UUID('42ed156e-3ca7-4872-9630-5148623cf1d0'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('4da669e1-72a7-40dd-b0b1-d47518a482d4'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('abad3b10-ae48-443b-9929-a39838c5e50d'),
#  UUID('387c0e68-c240-4f41-b1a4-2441bc3eb2e8'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('d15efeb8-85c6-4dba-a290-6c76258e6704'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('6ab5c4a9-366e-47c2-9ae5-3568c42a6231'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('99795850-4676-49ba-819b-c4db9f43050e'),
#  UUID('8e567567-05b3-4a8b-a990-3df9592fd7e9'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('311dc442-b45c-495c-b46d-42c5c601ed28'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('e8a4e9e8-216a-4645-bc3a-b0769133cd85'),
#  UUID('1d20d06d-2805-4a0c-b621-81f8742ba010'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('58bfe86f-ada2-4091-aad3-8f9347c54b6e'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('30f21c66-ed3d-4305-b6de-86a6033eb9b5'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('557fd84e-e3d6-458b-9953-b24b1a93ff9a'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('1418f6a9-be26-4dfd-9f12-d5d53f3d49fb'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('1981cc90-f8b3-4ddb-ba45-debf8c2a83b8'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('abad3b10-ae48-443b-9929-a39838c5e50d'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('70743eeb-bac5-4d7f-b338-dee00391feb5'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('311dc442-b45c-495c-b46d-42c5c601ed28'),
#  UUID('30f21c66-ed3d-4305-b6de-86a6033eb9b5'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('392ce536-aeaf-42da-bc58-39bc83daf173'),
#  UUID('3fa99cc8-6f10-488e-af7b-bf70ca8e224d'),
#  UUID('03943303-065c-4a11-8bee-e62b46cc90ad'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('7706fdce-c5e1-4a56-910c-b9391722c2e4'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('266ed1ce-932a-4060-aac1-de33e13e27a4'),
#  UUID('a8fa62a7-f798-4c72-96b6-6ec072cf2e0c'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('dbb5b763-f914-479d-b86d-3866a35b5ca1'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('8e567567-05b3-4a8b-a990-3df9592fd7e9'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('f27a49e9-2949-4185-afa5-e354b1fe005f'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('95b94843-c428-492e-af64-ed6c1a6dc0b9'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('99795850-4676-49ba-819b-c4db9f43050e'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('7e30ca6a-9f82-4ac5-8ff1-57ecd50c4db9'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('0ca19315-b147-4cc9-a9ed-6fef3a978395'),
#  UUID('b0ea73d5-8eae-477b-8049-031441b32ac8'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('4da669e1-72a7-40dd-b0b1-d47518a482d4'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('c5d6c4a3-8367-46e6-9aeb-883430de7a1c'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('b4b9d1ac-8617-4f97-95a5-6bf653d49a3f'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('6ab5c4a9-366e-47c2-9ae5-3568c42a6231'),
#  UUID('58bfe86f-ada2-4091-aad3-8f9347c54b6e'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('d3cff3ea-7556-408d-9458-dc65f0889b43'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('a8c1f20c-0371-4331-85fd-bfbbc212e54f'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('c1d28700-c837-4548-8121-1d71356b7949'),
#  UUID('454e2574-c86b-4166-8daa-0d49e5eeb4c7'),
#  UUID('4af53356-0927-49fe-a206-0fb706daa4a7'),
#  UUID('82b14db6-023f-4e08-95e3-1bb0d873c474'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('42ed156e-3ca7-4872-9630-5148623cf1d0'),
#  UUID('d15efeb8-85c6-4dba-a290-6c76258e6704'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('1404a72d-af7c-4bff-ba57-86471fa61092'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('ad37042d-a227-4eed-8e62-7d946c4134e2'),
#  UUID('e8cac908-99e2-486a-831e-ad0f23a7af01'),
#  UUID('7f35d4a5-6c7c-4a11-aec5-477c985e6549'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('5dd1ddd8-94cd-4af3-9418-18e5e058bb07'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('3fa99cc8-6f10-488e-af7b-bf70ca8e224d'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('82b14db6-023f-4e08-95e3-1bb0d873c474'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('387c0e68-c240-4f41-b1a4-2441bc3eb2e8'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('392ce536-aeaf-42da-bc58-39bc83daf173'),
#  UUID('a8fa62a7-f798-4c72-96b6-6ec072cf2e0c'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('4af53356-0927-49fe-a206-0fb706daa4a7'),
#  UUID('7f35d4a5-6c7c-4a11-aec5-477c985e6549'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('43459dc8-6f71-40a3-9226-6c8685b6bdd5'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('b0ea73d5-8eae-477b-8049-031441b32ac8'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('1404a72d-af7c-4bff-ba57-86471fa61092'),
#  UUID('cc4423f7-a1b7-4551-8ebc-0bc062a19bc6'),
#  UUID('1981cc90-f8b3-4ddb-ba45-debf8c2a83b8'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('0ca19315-b147-4cc9-a9ed-6fef3a978395'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('0d69f677-7c10-4e07-b68e-d3ae0f879af6'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('1d20d06d-2805-4a0c-b621-81f8742ba010'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('557fd84e-e3d6-458b-9953-b24b1a93ff9a'),
#  UUID('3fa99cc8-6f10-488e-af7b-bf70ca8e224d'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('58bfe86f-ada2-4091-aad3-8f9347c54b6e'),
#  UUID('ad37042d-a227-4eed-8e62-7d946c4134e2'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('a8c1f20c-0371-4331-85fd-bfbbc212e54f'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('392ce536-aeaf-42da-bc58-39bc83daf173'),
#  UUID('95b94843-c428-492e-af64-ed6c1a6dc0b9'),
#  UUID('6ab5c4a9-366e-47c2-9ae5-3568c42a6231'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('1981cc90-f8b3-4ddb-ba45-debf8c2a83b8'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('7e30ca6a-9f82-4ac5-8ff1-57ecd50c4db9'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('5dd1ddd8-94cd-4af3-9418-18e5e058bb07'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('266ed1ce-932a-4060-aac1-de33e13e27a4'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('cc4423f7-a1b7-4551-8ebc-0bc062a19bc6'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('8e567567-05b3-4a8b-a990-3df9592fd7e9'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('387c0e68-c240-4f41-b1a4-2441bc3eb2e8'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('1404a72d-af7c-4bff-ba57-86471fa61092'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('7706fdce-c5e1-4a56-910c-b9391722c2e4'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('d3cff3ea-7556-408d-9458-dc65f0889b43'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('0d69f677-7c10-4e07-b68e-d3ae0f879af6'),
#  UUID('70743eeb-bac5-4d7f-b338-dee00391feb5'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('c5d6c4a3-8367-46e6-9aeb-883430de7a1c'),
#  UUID('82b14db6-023f-4e08-95e3-1bb0d873c474'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('30f21c66-ed3d-4305-b6de-86a6033eb9b5'),
#  UUID('f27a49e9-2949-4185-afa5-e354b1fe005f'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('1418f6a9-be26-4dfd-9f12-d5d53f3d49fb'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('99795850-4676-49ba-819b-c4db9f43050e'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('7f35d4a5-6c7c-4a11-aec5-477c985e6549'),
#  UUID('abad3b10-ae48-443b-9929-a39838c5e50d'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('b0ea73d5-8eae-477b-8049-031441b32ac8'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('20a8355f-a771-4bd1-99d7-126e38701e0f'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('dbb5b763-f914-479d-b86d-3866a35b5ca1'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('4af53356-0927-49fe-a206-0fb706daa4a7'),
#  UUID('b471c9f6-1787-4343-9f0b-ab5cfb7e55c8'),
#  UUID('311dc442-b45c-495c-b46d-42c5c601ed28'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f'),
#  UUID('d15efeb8-85c6-4dba-a290-6c76258e6704'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('03943303-065c-4a11-8bee-e62b46cc90ad'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('e8cac908-99e2-486a-831e-ad0f23a7af01'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('0ca19315-b147-4cc9-a9ed-6fef3a978395'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('1d20d06d-2805-4a0c-b621-81f8742ba010'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('454e2574-c86b-4166-8daa-0d49e5eeb4c7'),
#  UUID('220eea77-bcb0-40ac-b4eb-de380125e616'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('42ed156e-3ca7-4872-9630-5148623cf1d0'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('95b94843-c428-492e-af64-ed6c1a6dc0b9'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('b471c9f6-1787-4343-9f0b-ab5cfb7e55c8'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('266ed1ce-932a-4060-aac1-de33e13e27a4'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('0d69f677-7c10-4e07-b68e-d3ae0f879af6'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('e8cac908-99e2-486a-831e-ad0f23a7af01'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('1418f6a9-be26-4dfd-9f12-d5d53f3d49fb'),
#  UUID('dbb5b763-f914-479d-b86d-3866a35b5ca1'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('220eea77-bcb0-40ac-b4eb-de380125e616'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('b4b9d1ac-8617-4f97-95a5-6bf653d49a3f'),
#  UUID('5dd1ddd8-94cd-4af3-9418-18e5e058bb07'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('454e2574-c86b-4166-8daa-0d49e5eeb4c7'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('387c0e68-c240-4f41-b1a4-2441bc3eb2e8'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('20a8355f-a771-4bd1-99d7-126e38701e0f'),
#  UUID('03943303-065c-4a11-8bee-e62b46cc90ad'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('ad37042d-a227-4eed-8e62-7d946c4134e2'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('7e30ca6a-9f82-4ac5-8ff1-57ecd50c4db9'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('f27a49e9-2949-4185-afa5-e354b1fe005f'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('58bfe86f-ada2-4091-aad3-8f9347c54b6e'),
#  UUID('43459dc8-6f71-40a3-9226-6c8685b6bdd5'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('30f21c66-ed3d-4305-b6de-86a6033eb9b5'),
#  UUID('b0ea73d5-8eae-477b-8049-031441b32ac8'),
#  UUID('d15efeb8-85c6-4dba-a290-6c76258e6704'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('c1d28700-c837-4548-8121-1d71356b7949'),
#  UUID('1981cc90-f8b3-4ddb-ba45-debf8c2a83b8'),
#  UUID('8e567567-05b3-4a8b-a990-3df9592fd7e9'),
#  UUID('d3cff3ea-7556-408d-9458-dc65f0889b43'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f'),
#  UUID('557fd84e-e3d6-458b-9953-b24b1a93ff9a'),
#  UUID('95b94843-c428-492e-af64-ed6c1a6dc0b9'),
#  UUID('1404a72d-af7c-4bff-ba57-86471fa61092'),
#  UUID('f54319ab-aed7-4028-b302-7f2db68b7761'),
#  UUID('715fb19e-942b-4ffd-b03b-066e0d47d05c'),
#  UUID('cef4e92f-34d1-496f-a4e8-47026d1cc6de'),
#  UUID('7e30ca6a-9f82-4ac5-8ff1-57ecd50c4db9'),
#  UUID('60fbe71c-9a0d-40db-aa54-1275f10596aa'),
#  UUID('bb8d24f5-5d51-441a-a829-652be1509b1e'),
#  UUID('4770dff4-2a64-46a5-8cc1-84cbb6442acc'),
#  UUID('59ae81a5-c0e2-4f5b-a15b-ed5eab30ad4d'),
#  UUID('c0602303-83aa-4f97-aa56-068c1f95abd1'),
#  UUID('0d69f677-7c10-4e07-b68e-d3ae0f879af6'),
#  UUID('dbb5b763-f914-479d-b86d-3866a35b5ca1'),
#  UUID('454e2574-c86b-4166-8daa-0d49e5eeb4c7'),
#  UUID('69b70eae-1844-46eb-8c86-ab630f3fff6e'),
#  UUID('78d0c847-64b8-4a36-9bdf-e88dc6d62957'),
#  UUID('bad0f54d-90a2-418a-9e48-43cdfbb5c9d1'),
#  UUID('f51af927-214f-4b2d-acfd-2e20a7253db2'),
#  UUID('42ed156e-3ca7-4872-9630-5148623cf1d0'),
#  UUID('392ce536-aeaf-42da-bc58-39bc83daf173'),
#  UUID('925597d5-2964-4400-b456-48b30d0cbf93'),
#  UUID('1418f6a9-be26-4dfd-9f12-d5d53f3d49fb'),
#  UUID('445ecd04-964c-425f-a5f0-ac120e5f430a'),
#  UUID('ad37042d-a227-4eed-8e62-7d946c4134e2'),
#  UUID('a7cfa5a9-8451-4ea9-8509-0e8ca6313953'),
#  UUID('d3cff3ea-7556-408d-9458-dc65f0889b43'),
#  UUID('abad3b10-ae48-443b-9929-a39838c5e50d'),
#  UUID('0ca19315-b147-4cc9-a9ed-6fef3a978395'),
#  UUID('00a06bfc-00fb-4131-ac82-b36bc60bfdb2'),
#  UUID('266ed1ce-932a-4060-aac1-de33e13e27a4'),
#  UUID('6d7bf3c9-d0e2-4d46-817b-99af3509fd62'),
#  UUID('11566a4a-9d6f-4fe5-ac3b-6636d4cfb71a'),
#  UUID('b2982980-1a2f-4353-82b0-ba763395d157'),
#  UUID('43459dc8-6f71-40a3-9226-6c8685b6bdd5'),
#  UUID('8e567567-05b3-4a8b-a990-3df9592fd7e9'),
#  UUID('82b14db6-023f-4e08-95e3-1bb0d873c474'),
#  UUID('311dc442-b45c-495c-b46d-42c5c601ed28'),
#  UUID('e16f0ed3-3fe0-4b3e-847d-e6cc9b6bdd9e'),
#  UUID('e8a4e9e8-216a-4645-bc3a-b0769133cd85'),
#  UUID('a03ff22a-ff1e-41ec-9ba0-79274bf178d2'),
#  UUID('50e83691-cc8b-4303-b536-ca7139440410'),
#  UUID('03943303-065c-4a11-8bee-e62b46cc90ad'),
#  UUID('58bfe86f-ada2-4091-aad3-8f9347c54b6e'),
#  UUID('1981cc90-f8b3-4ddb-ba45-debf8c2a83b8'),
#  UUID('f83cda3b-207d-4b63-9b57-7de89f878208'),
#  UUID('7f35d4a5-6c7c-4a11-aec5-477c985e6549'),
#  UUID('bf229ad5-8928-4827-a931-5995601f281a'),
#  UUID('a8c1f20c-0371-4331-85fd-bfbbc212e54f'),
#  UUID('288352fc-7dc1-4f72-aabe-e30a6a5f6bc5'),
#  UUID('631dd85f-b606-45f4-8754-a7c9f452cd8c'),
#  UUID('20a8355f-a771-4bd1-99d7-126e38701e0f'),
#  UUID('1d77b2b4-9cb9-4e73-99fc-69335dcc5eff'),
#  UUID('c1d28700-c837-4548-8121-1d71356b7949'),
#  UUID('b48b682e-8770-48fc-b659-5cf4a6232700'),
#  UUID('c5d6c4a3-8367-46e6-9aeb-883430de7a1c'),
#  UUID('b471c9f6-1787-4343-9f0b-ab5cfb7e55c8'),
#  UUID('a8c44472-1764-4af8-bf87-ec9184610aaa'),
#  UUID('f7b2c6cd-840a-43c7-a3f4-17de5bfe8171'),
#  UUID('7e4be309-e2bd-45dd-bc03-1c738b67b4cc'),
#  UUID('d9472ccb-67da-4a1d-8387-a6bf29c84bbf'),
#  UUID('0b19fcab-c8c4-4725-be47-0568c7e3c980'),
#  UUID('3ae95bf5-3fc0-440c-9111-2e8bb6853d12'),
#  UUID('b243e22e-ea58-48e9-a77d-5b0d7d58b6ad'),
#  UUID('7706fdce-c5e1-4a56-910c-b9391722c2e4'),
#  UUID('77ce9f80-4bf9-4dbf-8cea-c5c6a281b859'),
#  UUID('a6e9d526-1ff8-4cb6-9938-b3953dbf766b'),
#  UUID('9b5a1920-ddf0-4647-ac57-80948381a27d'),
#  UUID('5dd1ddd8-94cd-4af3-9418-18e5e058bb07'),
#  UUID('918df476-a1fc-4438-bdcd-3241558b9f9f'),
#  UUID('ae26a870-6ed4-4c82-ba6e-c7e5a1023662'),
#  UUID('3e253ca6-1f7e-4463-a692-094286b9847f'),
#  UUID('4da669e1-72a7-40dd-b0b1-d47518a482d4'),
#  UUID('cc4423f7-a1b7-4551-8ebc-0bc062a19bc6'),
#  UUID('1cdb503e-6c5d-4d98-ba59-b4176afe84c5'),
#  UUID('4af53356-0927-49fe-a206-0fb706daa4a7'),
#  UUID('b5f5010c-f49e-4af6-ad36-32742b6e564d'),
#  UUID('b4b9d1ac-8617-4f97-95a5-6bf653d49a3f'),
#  UUID('387c0e68-c240-4f41-b1a4-2441bc3eb2e8'),
#  UUID('f27a49e9-2949-4185-afa5-e354b1fe005f'),
#  UUID('d15efeb8-85c6-4dba-a290-6c76258e6704'),
#  UUID('3fa99cc8-6f10-488e-af7b-bf70ca8e224d'),
#  UUID('6ab5c4a9-366e-47c2-9ae5-3568c42a6231'),
#  UUID('524e4577-7f70-439e-8e2b-2b31b5ca02b7'),
#  UUID('99795850-4676-49ba-819b-c4db9f43050e'),
#  UUID('e8cac908-99e2-486a-831e-ad0f23a7af01'),
#  UUID('7572fbd3-ce33-4b39-9c3e-0242d6b8b434'),
#  UUID('0c68134f-9668-48b7-94e4-a46e2c5370eb'),
#  UUID('138a6a63-b4ef-448b-aa9f-3dc3202a38c3'),
#  UUID('b0ea73d5-8eae-477b-8049-031441b32ac8'),
#  UUID('1d20d06d-2805-4a0c-b621-81f8742ba010'),
#  UUID('a8fa62a7-f798-4c72-96b6-6ec072cf2e0c'),
#  UUID('3fe0ef9b-a475-46f7-8451-17cec713dc28'),
#  UUID('70743eeb-bac5-4d7f-b338-dee00391feb5'),
#  UUID('78374d96-84bd-4dbd-9a38-d9d615db40ad'),
#  UUID('220eea77-bcb0-40ac-b4eb-de380125e616'),
#  UUID('cb16e59a-d297-4932-b519-0658e1749826'),
#  UUID('98194ba9-2504-4c4c-a6d3-c915f70dab81'),
#  UUID('30f21c66-ed3d-4305-b6de-86a6033eb9b5'),
#  UUID('e6ddde79-debe-4f3a-9c2f-a450ccf9845f')]

# %%
positive_pools
# Out:
# []

# %%
pool_dictionary[uuid.UUID('3b7ca273-3bf6-4b0a-8262-a85b3d9cc07c')]
# Out:
# 1

# %%
run_test([uuid.UUID('3b7ca273-3bf6-4b0a-8262-a85b3d9cc07c')], pool_dictionary)
# Out:
# (1, 0, 0)

# %%
list(set(positive_pools[0]) & set(positive_pools[1]))
# Out:
# [UUID('b2d0fb60-1050-4466-b941-5b275b9f0357')]

# %%
set.intersection([set(i) for i in positive_pools])
# set.intersection(set(positive_pools[0]),  set(positive_pools[8]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-84c134084d44> in <module>
# ----> 1 set.intersection([set(i) for i in positive_pools])
#       2 # set.intersection(set(positive_pools[0]),  set(positive_pools[8]))
#
# TypeError: descriptor 'intersection' requires a 'set' object but received a 'list'

# %%
pool_dictionary
# Out:
# {UUID('b1a8e495-f61a-43fc-ab95-b06aeef83e20'): 0,
#  UUID('c56d6a8a-5a1b-4416-ab6c-eee013cf5150'): 0,
#  UUID('715039ec-1808-4fd3-80d3-4a726eee475c'): 0,
#  UUID('ac9561c6-5143-4069-a6e8-57035f2a23ba'): 0,
#  UUID('4b4233c6-08e6-42be-b157-d9ab99f6558d'): 0,
#  UUID('f5a7c39d-5fe7-4bf5-925b-8677c666ccc4'): 0,
#  UUID('e279681a-e041-4592-9d2c-495ace313067'): 0,
#  UUID('f46dd45b-f297-4ab8-b723-da046c8e2148'): 1,
#  UUID('5343cee8-d09c-4a23-bfc2-d64ea779179b'): 0,
#  UUID('1ee8d43b-8d60-48bc-b877-ff15d1ae3b68'): 0,
#  UUID('4ede5c73-381e-49ff-85aa-76b5b97ba7a3'): 0,
#  UUID('d8e3d39b-3816-4171-b3a1-aa0de7652819'): 0,
#  UUID('e86c0869-bbbc-4c7b-87fb-5908b0273d7a'): 0,
#  UUID('b27592a5-44fb-4f12-ab89-309912428ee4'): 0,
#  UUID('01b1e928-b769-4d4a-926e-4b974fbfd772'): 0,
#  UUID('8903bce1-5929-4c81-8025-12e1d28cd4f1'): 0,
#  UUID('a93b49e9-62a9-4d90-bb16-aaa6e21c3e74'): 0,
#  UUID('ddf2a4c6-0420-48a5-86cd-de72f8df1634'): 0,
#  UUID('c8787fde-8d94-4891-836a-4cfa80e9192f'): 0,
#  UUID('39292e37-a60b-4f21-89d0-df70d56abc90'): 0,
#  UUID('389f7899-2995-4a4f-b183-734ea9991b04'): 1,
#  UUID('72482a24-649e-44c9-95cd-eaa380122f43'): 0,
#  UUID('a774237b-bf98-4921-88ee-5081aa091cef'): 0,
#  UUID('1042d4f2-b527-4202-9dd8-c15f96f3bb9c'): 0,
#  UUID('39d52b7f-a4e9-4029-a655-621b4cfd4526'): 0,
#  UUID('e442b647-6733-4e5a-ab5d-ff3a99272131'): 0,
#  UUID('cc4836c1-b89a-4688-9535-198ff94a779b'): 0,
#  UUID('77d962ab-3107-491b-bc90-2525bdc0a6a4'): 0,
#  UUID('86cc7614-2920-4599-aac6-7986ff29c6d8'): 0,
#  UUID('31adf9bf-96f2-4a82-84e1-378e610cfc18'): 0,
#  UUID('cfd3c7fe-5bef-4d9d-b234-a5879f40bd8a'): 0,
#  UUID('2520eb56-755a-4727-90c4-9b4444fddbae'): 0,
#  UUID('20df9222-729f-4d1e-a7a6-30dea9a813db'): 0,
#  UUID('2ed971dc-7573-4053-897a-4ac5aefad57f'): 0,
#  UUID('6fb45720-23fb-403e-b7f2-e2fb6a508e4a'): 0,
#  UUID('54f34a18-0d3e-412b-b6a4-6547a41f6612'): 0,
#  UUID('0d3fe644-09e6-4693-bd73-dbc3ea4958ed'): 0,
#  UUID('4e2a821b-5ecf-4463-a0d9-51e992e15a7c'): 0,
#  UUID('71813531-8dd0-4bb3-bb78-aee674746707'): 0,
#  UUID('735783e1-32ed-470e-9769-e1607969fdca'): 0,
#  UUID('168eaf8c-50bd-4ba8-9f4c-1d416ce471cf'): 0,
#  UUID('304285b0-0b88-4c56-986a-dec5c1416cdd'): 0,
#  UUID('ec191d31-e8c7-407e-ac2d-e10ddec80bac'): 0,
#  UUID('b3f11c1b-31ac-41bb-b20d-a751f50761a0'): 0,
#  UUID('3d103337-8d3c-49e1-8340-843c5b0d8f5e'): 0,
#  UUID('05ea4f87-47c7-428d-9b5b-962f51e23695'): 0,
#  UUID('92e3d3ea-b459-40fd-b562-8638efba43f0'): 0,
#  UUID('0f000ec2-d493-4225-b02e-131fa7fd7ac0'): 0,
#  UUID('f3a4908a-cd2c-49bf-9f31-a7bcbf10386a'): 0,
#  UUID('7e83fe65-15f5-4942-b268-7a1ab63c2a32'): 0,
#  UUID('52d9ac4e-da5c-4c67-930e-7326e7f58580'): 0,
#  UUID('603b97e5-00d3-472c-82ca-ba75ec79f10f'): 1,
#  UUID('cc708394-b26c-4be8-9848-9637003c612a'): 0,
#  UUID('89ac7cb9-6bae-4e60-b287-d2c9070386f8'): 0,
#  UUID('8d926c3f-0419-44c5-813b-e94c9c5470c4'): 0,
#  UUID('52668b25-e752-42ae-9197-ddf8e476bc5c'): 0,
#  UUID('8e6f499c-b5dd-47ed-bb9f-f92bb32961aa'): 0,
#  UUID('2a51c7ea-ad01-42eb-b9a9-2ae771575953'): 0,
#  UUID('74679ce6-f5e9-4828-9245-d179113ef06c'): 0,
#  UUID('1a5b2520-83a9-4d49-9524-4f63044b7b8c'): 0,
#  UUID('680689d3-7cf0-4179-845d-3c3a85c93a46'): 0,
#  UUID('73ac0da8-492f-4168-85f2-cdb623c4339b'): 0,
#  UUID('f72de282-3c05-4111-a08c-53a55811371c'): 0,
#  UUID('6091f4ba-748f-4b9b-a0ad-5c882a752d2c'): 0,
#  UUID('23d71bec-c663-4ab7-97b2-a83adb53c4ba'): 0,
#  UUID('626990c7-2176-4abc-b9d6-b357c1f5f4e2'): 1,
#  UUID('4f124707-7e39-4cf9-be4c-120b55dd6778'): 0,
#  UUID('4b3335b7-7d35-442a-9cdd-d4b32776e3eb'): 0,
#  UUID('3777ba25-5a31-4923-8a9c-7878e9aef1bf'): 0,
#  UUID('30eb2a5c-f790-4cbf-a9d7-05998a35a14f'): 0,
#  UUID('b1ce5c61-f050-4d30-86a8-af713ee5ed64'): 0,
#  UUID('3ad1de18-10a9-48ff-9134-6bcdfaa09204'): 0,
#  UUID('4852bd35-2e1e-435f-9c7a-e1468b557126'): 1,
#  UUID('852c0f04-570a-41a9-8e76-23902741852a'): 0,
#  UUID('ef0b6977-4ffe-4760-8490-b9531809a453'): 0,
#  UUID('00a3d1b2-e4fe-4232-b718-4d1b41c0f3f7'): 0,
#  UUID('3a2250bf-de21-4b22-8cba-cc43c97b0aac'): 0,
#  UUID('d6d7ceb1-08ac-4108-a75a-3c5ce3c26392'): 0,
#  UUID('30a58070-0810-459e-9498-bdf6e61d0188'): 0,
#  UUID('470c2763-42b7-44ce-a8c7-791ef163a2d5'): 0,
#  UUID('74b7ca4d-3f54-40a4-b932-71f4d7db01ec'): 0,
#  UUID('bae33552-0df5-44bb-a99c-2b0baa9d0549'): 0,
#  UUID('2eebd97e-613c-4875-bfcd-bd31e36dcda3'): 0,
#  UUID('e56f2440-663e-4b5e-b42e-054f6d1eca31'): 0,
#  UUID('2f402219-7f24-4a5a-af1c-256e2c8c06c7'): 0,
#  UUID('3fe5c6f8-cecc-4703-8e8c-4ca91f5c65df'): 0,
#  UUID('1f925abc-ad22-4566-9f81-7ed6d56d1349'): 0,
#  UUID('1255919a-41fe-4784-bf3d-ecad04f2b2df'): 0,
#  UUID('7891aa34-cde3-4e6f-a79e-177266bcd40e'): 0,
#  UUID('f70e489b-45f7-43ca-add5-6d19c4c559ba'): 0,
#  UUID('ee3e9941-8791-4fb4-9fa9-e17eb9295291'): 0,
#  UUID('eb98a532-3704-467e-8e58-f3e0713578dd'): 0,
#  UUID('718e9ee1-de6e-4397-9aac-62cd90501a49'): 0,
#  UUID('afd29b97-b8c1-4a34-9396-ae6774f9fe82'): 0,
#  UUID('49cd04a0-030e-4359-a90e-e7f18e8776a6'): 0,
#  UUID('70c3bcfb-14ec-4220-afd4-73f5df999e29'): 0,
#  UUID('cd4c1ab4-1940-49b6-91f6-089e38e1a346'): 0,
#  UUID('c15152b1-a9e5-45de-973c-467df7a61845'): 0,
#  UUID('03573f3e-4ec0-471d-b896-fff3091cb41b'): 0,
#  UUID('5b2dd9a7-f3a5-4f32-83cb-6b1cf2b2a723'): 0}
